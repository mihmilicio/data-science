# %% [markdown]
# # Limpeza de dados

# %%
import numpy as np
import pandas as pd
import re

# %%
df = pd.read_csv('dataset/survey_results_public.csv', sep=',', encoding='utf-8')

# %%
df.head()
# Out:
#    ResponseId                                         MainBranch  \
# 0           1                                      None of these
# 1           2                     I am a developer by profession
# 2           3  I am not primarily a developer, but I write co...
# 3           4                     I am a developer by profession
# 4           5                     I am a developer by profession
#
#             Employment                            RemoteWork  \
# 0                  NaN                                   NaN
# 1  Employed, full-time                          Fully remote
# 2  Employed, full-time  Hybrid (some remote, some in-person)
# 3  Employed, full-time                          Fully remote
# 4  Employed, full-time  Hybrid (some remote, some in-person)
#
#                            CodingActivities  \
# 0                                       NaN
# 1  Hobby;Contribute to open-source projects
# 2                                     Hobby
# 3              I don’t code outside of work
# 4                                     Hobby
#
#                                            EdLevel  \
# 0                                              NaN
# 1                                              NaN
# 2  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 3     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                            LearnCode  \
# 0                                                NaN
# 1                                                NaN
# 2  Books / Physical media;Friend or family member...
# 3  Books / Physical media;School (i.e., Universit...
# 4  Other online resources (e.g., videos, blogs, f...
#
#                                      LearnCodeOnline LearnCodeCoursesCert  \
# 0                                                NaN                  NaN
# 1                                                NaN                  NaN
# 2  Technical documentation;Blogs;Programming Game...                  NaN
# 3                                                NaN                  NaN
# 4  Technical documentation;Blogs;Stack Overflow;O...                  NaN
#
#   YearsCode  ... TimeSearching TimeAnswering Onboarding ProfessionalTech  \
# 0       NaN  ...           NaN           NaN        NaN              NaN
# 1       NaN  ...           NaN           NaN        NaN              NaN
# 2        14  ...           NaN           NaN        NaN              NaN
# 3        20  ...           NaN           NaN        NaN              NaN
# 4         8  ...           NaN           NaN        NaN              NaN
#
#   TrueFalse_1 TrueFalse_2 TrueFalse_3           SurveyLength  \
# 0         NaN         NaN         NaN                    NaN
# 1         NaN         NaN         NaN               Too long
# 2         NaN         NaN         NaN  Appropriate in length
# 3         NaN         NaN         NaN  Appropriate in length
# 4         NaN         NaN         NaN               Too long
#
#                    SurveyEase ConvertedCompYearly
# 0                         NaN                 NaN
# 1                   Difficult                 NaN
# 2  Neither easy nor difficult             40205.0
# 3                        Easy            215232.0
# 4                        Easy                 NaN
#
# [5 rows x 79 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73268 entries, 0 to 73267
# Data columns (total 79 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   ResponseId                      73268 non-null  int64
#  1   MainBranch                      73268 non-null  object
#  2   Employment                      71709 non-null  object
#  3   RemoteWork                      58958 non-null  object
#  4   CodingActivities                58899 non-null  object
#  5   EdLevel                         71571 non-null  object
#  6   LearnCode                       71580 non-null  object
#  7   LearnCodeOnline                 50685 non-null  object
#  8   LearnCodeCoursesCert            29389 non-null  object
#  9   YearsCode                       71331 non-null  object
#  10  YearsCodePro                    51833 non-null  object
#  11  DevType                         61302 non-null  object
#  12  OrgSize                         51039 non-null  object
#  13  PurchaseInfluence               50969 non-null  object
#  14  BuyNewTool                      67963 non-null  object
#  15  Country                         71771 non-null  object
#  16  Currency                        51264 non-null  object
#  17  CompTotal                       38422 non-null  float64
#  18  CompFreq                        44425 non-null  object
#  19  LanguageHaveWorkedWith          70975 non-null  object
#  20  LanguageWantToWorkWith          67027 non-null  object
#  21  DatabaseHaveWorkedWith          60121 non-null  object
#  22  DatabaseWantToWorkWith          51014 non-null  object
#  23  PlatformHaveWorkedWith          49924 non-null  object
#  24  PlatformWantToWorkWith          40415 non-null  object
#  25  WebframeHaveWorkedWith          53544 non-null  object
#  26  WebframeWantToWorkWith          46122 non-null  object
#  27  MiscTechHaveWorkedWith          44992 non-null  object
#  28  MiscTechWantToWorkWith          36810 non-null  object
#  29  ToolsTechHaveWorkedWith         54171 non-null  object
#  30  ToolsTechWantToWorkWith         46566 non-null  object
#  31  NEWCollabToolsHaveWorkedWith    70347 non-null  object
#  32  NEWCollabToolsWantToWorkWith    64108 non-null  object
#  33  OpSysProfessional use           65503 non-null  object
#  34  OpSysPersonal use               70963 non-null  object
#  35  VersionControlSystem            71379 non-null  object
#  36  VCInteraction                   68156 non-null  object
#  37  VCHostingPersonal use           0 non-null      float64
#  38  VCHostingProfessional use       0 non-null      float64
#  39  OfficeStackAsyncHaveWorkedWith  46223 non-null  object
#  40  OfficeStackAsyncWantToWorkWith  32072 non-null  object
#  41  OfficeStackSyncHaveWorkedWith   62128 non-null  object
#  42  OfficeStackSyncWantToWorkWith   47688 non-null  object
#  43  Blockchain                      71071 non-null  object
#  44  NEWSOSites                      71365 non-null  object
#  45  SOVisitFreq                     70961 non-null  object
#  46  SOAccount                       71572 non-null  object
#  47  SOPartFreq                      58229 non-null  object
#  48  SOComm                          71408 non-null  object
#  49  Age                             70946 non-null  object
#  50  Gender                          70853 non-null  object
#  51  Trans                           70315 non-null  object
#  52  Sexuality                       66565 non-null  object
#  53  Ethnicity                       69474 non-null  object
#  54  Accessibility                   67244 non-null  object
#  55  MentalHealth                    66447 non-null  object
#  56  TBranch                         52670 non-null  object
#  57  ICorPM                          36283 non-null  object
#  58  WorkExp                         36769 non-null  float64
#  59  Knowledge_1                     35804 non-null  object
#  60  Knowledge_2                     34973 non-null  object
#  61  Knowledge_3                     35133 non-null  object
#  62  Knowledge_4                     35097 non-null  object
#  63  Knowledge_5                     35014 non-null  object
#  64  Knowledge_6                     34991 non-null  object
#  65  Knowledge_7                     34977 non-null  object
#  66  Frequency_1                     35371 non-null  object
#  67  Frequency_2                     35344 non-null  object
#  68  Frequency_3                     34515 non-null  object
#  69  TimeSearching                   36198 non-null  object
#  70  TimeAnswering                   36022 non-null  object
#  71  Onboarding                      35679 non-null  object
#  72  ProfessionalTech                34906 non-null  object
#  73  TrueFalse_1                     35819 non-null  object
#  74  TrueFalse_2                     35715 non-null  object
#  75  TrueFalse_3                     35749 non-null  object
#  76  SurveyLength                    70444 non-null  object
#  77  SurveyEase                      70508 non-null  object
#  78  ConvertedCompYearly             38071 non-null  float64
# dtypes: float64(5), int64(1), object(73)
# memory usage: 44.2+ MB

# %% [markdown]
# Sabemos pelo schema que o ResponseId é exatamente o que o nome dá a entender. Então o usaremos como index do DataFrame.

# %%
df.set_index('ResponseId')
print()

# %% [markdown]
# ## Primeira seção
#
# Questões 1 a 18

# %% [markdown]
# Então avançamos para a próxima coluna: MainBranch. Ela demostra de que forma o respondente se relaciona com desenvolvimento. Vamos aproveitar para substituir os valores por termos mais simples.

# %%
print(df['MainBranch'].unique())
# Out:
# ['None of these' 'I am a developer by profession'
#  'I am not primarily a developer, but I write code sometimes as part of my work'
#  'I code primarily as a hobby' 'I am learning to code'
#  'I used to be a developer by profession, but no longer am']

# %%
df['MainBranch'] = df['MainBranch'].replace({
  'None of these': 'none',
  'I am a developer by profession': 'dev',
  'I am not primarily a developer, but I write code sometimes as part of my work': 'part_dev',
  'I code primarily as a hobby': 'hobbist',
  'I am learning to code': 'learner',
  'I used to be a developer by profession, but no longer am': 'ex_dev',
})
print(df['MainBranch'].unique())
# Out:
# ['none' 'dev' 'part_dev' 'hobbist' 'learner' 'ex_dev']

# %% [markdown]
# Partindo para a próxima coluna (Employment), podemos notar pela forma que ela está formatada que era uma questão com múltiplas seleções. Para facilitar o gerenciamento futuro, optamos por reduzir os nomes.

# %%
print(df['Employment'].unique())
# Out:
# [nan 'Employed, full-time' 'Student, full-time' 'Student, part-time'
#  'Not employed, but looking for work'
#  'Independent contractor, freelancer, or self-employed'
#  'Employed, full-time;Independent contractor, freelancer, or self-employed'
#  'Employed, part-time' 'Student, part-time;Employed, part-time'
#  'Not employed, and not looking for work'
#  'Student, full-time;Employed, part-time'
#  'Employed, full-time;Student, part-time'
#  'Employed, full-time;Student, full-time'
#  'Student, part-time;Independent contractor, freelancer, or self-employed'
#  'Retired' 'Student, full-time;Not employed, but looking for work'
#  'I prefer not to say'
#  'Student, full-time;Independent contractor, freelancer, or self-employed'
#  'Student, full-time;Not employed, and not looking for work'
#  'Not employed, but looking for work;Independent contractor, freelancer, or self-employed'
#  'Employed, full-time;Student, part-time;Independent contractor, freelancer, or self-employed'
#  'Independent contractor, freelancer, or self-employed;Employed, part-time'
#  'Student, part-time;Independent contractor, freelancer, or self-employed;Employed, part-time'
#  'Employed, full-time;Independent contractor, freelancer, or self-employed;Employed, part-time'
#  'Independent contractor, freelancer, or self-employed;Retired'
#  'Employed, full-time;Student, full-time;Student, part-time;Independent contractor, freelancer, or self-employed;Employed, part-time'
#  'Employed, full-time;Student, part-time;Employed, part-time'
#  'Student, full-time;Student, part-time'
#  'Employed, full-time;Student, full-time;Independent contractor, freelancer, or self-employed'
#  'Student, full-time;Independent contractor, freelancer, or self-employed;Employed, part-time'
#  'Student, part-time;Not employed, and not looking for work'
#  'Student, part-time;Not employed, but looking for work;Independent contractor, freelancer, or self-employed'
#  'Employed, full-time;Employed, part-time'
#  'Student, part-time;Not employed, but looking for work'
#  'Employed, full-time;Not employed, but looking for work'
#  'Student, full-time;Student, part-time;Not employed, but looking for work;Independent contractor, freelancer, or self-employed;Not employed, and not looking for work'
#  'Employed, full-time;Student, full-time;Employed, part-time'
#  'Independent contractor, freelancer, or self-employed;Not employed, and not looking for work'
#  'Student, full-time;Not employed, but looking for work;Independent contractor, freelancer, or self-employed'
#  'Not employed, but looking for work;Not employed, and not looking for work'
#  'Employed, full-time;Student, part-time;Independent contractor, freelancer, or self-employed;Employed, part-time'
#  'Not employed, but looking for work;Independent contractor, freelancer, or self-employed;Employed, part-time'
#  'Employed, full-time;Student, full-time;Student, part-time;Not employed, but looking for work;Independent contractor, freelancer, or self-employed;Employed, part-time;Retired'
#  'Employed, full-time;Student, full-time;Student, part-time'
#  'Employed, full-time;Not employed, but looking for work;Employed, part-time'
#  'Student, part-time;Not employed, but looking for work;Employed, part-time'
#  'Employed, full-time;Student, full-time;Independent contractor, freelancer, or self-employed;Employed, part-time'
#  'Not employed, but looking for work;Employed, part-time'
#  'Employed, full-time;Not employed, but looking for work;Independent contractor, freelancer, or self-employed;Employed, part-time'
#  'Student, full-time;Independent contractor, freelancer, or self-employed;Not employed, and not looking for work'
#  'Student, part-time;Not employed, but looking for work;Independent contractor, freelancer, or self-employed;Employed, part-time'
#  'Not employed, and not looking for work;Retired'
#  'Employed, full-time;Not employed, and not looking for work'
#  'Student, full-time;Retired'
#  'Employed, full-time;Student, full-time;Student, part-time;Independent contractor, freelancer, or self-employed'
#  'Student, full-time;Student, part-time;Employed, part-time'
#  'Student, full-time;Student, part-time;Not employed, but looking for work'
#  'Student, full-time;Student, part-time;Not employed, and not looking for work'
#  'Student, full-time;Not employed, but looking for work;Independent contractor, freelancer, or self-employed;Employed, part-time'
#  'Student, full-time;Not employed, but looking for work;Not employed, and not looking for work'
#  'Employed, full-time;Not employed, but looking for work;Independent contractor, freelancer, or self-employed'
#  'Employed, part-time;Retired' 'Employed, full-time;Retired'
#  'Not employed, but looking for work;Independent contractor, freelancer, or self-employed;Retired'
#  'Employed, full-time;Student, part-time;Not employed, but looking for work;Independent contractor, freelancer, or self-employed;Employed, part-time'
#  'Student, full-time;Student, part-time;Not employed, but looking for work;Independent contractor, freelancer, or self-employed'
#  'Student, full-time;Not employed, but looking for work;Employed, part-time'
#  'Student, part-time;Not employed, but looking for work;Not employed, and not looking for work'
#  'Employed, part-time;Not employed, and not looking for work'
#  'Student, part-time;Independent contractor, freelancer, or self-employed;Not employed, and not looking for work'
#  'Student, full-time;Student, part-time;Independent contractor, freelancer, or self-employed'
#  'Not employed, but looking for work;Independent contractor, freelancer, or self-employed;Not employed, and not looking for work'
#  'Employed, full-time;Student, full-time;Student, part-time;Not employed, but looking for work;Independent contractor, freelancer, or self-employed;Employed, part-time;Not employed, and not looking for work;Retired'
#  'Employed, full-time;Not employed, but looking for work;Not employed, and not looking for work'
#  'Not employed, but looking for work;Retired'
#  'Employed, full-time;Student, full-time;Student, part-time;Employed, part-time'
#  'Employed, full-time;Student, full-time;Not employed, but looking for work'
#  'Employed, full-time;Student, full-time;Student, part-time;Not employed, but looking for work;Independent contractor, freelancer, or self-employed;Employed, part-time;Not employed, and not looking for work'
#  'Employed, full-time;Student, full-time;Not employed, but looking for work;Employed, part-time'
#  'Student, part-time;Retired'
#  'Employed, full-time;Student, full-time;Retired'
#  'Employed, full-time;Independent contractor, freelancer, or self-employed;Retired'
#  'Employed, full-time;Independent contractor, freelancer, or self-employed;Employed, part-time;Not employed, and not looking for work'
#  'Student, part-time;Independent contractor, freelancer, or self-employed;Retired'
#  'Independent contractor, freelancer, or self-employed;Employed, part-time;Retired'
#  'Employed, full-time;Student, full-time;Student, part-time;Not employed, but looking for work;Employed, part-time;Not employed, and not looking for work'
#  'Student, full-time;Student, part-time;Independent contractor, freelancer, or self-employed;Employed, part-time'
#  'Employed, full-time;Student, part-time;Not employed, but looking for work'
#  'Employed, full-time;Student, full-time;Independent contractor, freelancer, or self-employed;Employed, part-time;Not employed, and not looking for work'
#  'Student, full-time;Student, part-time;Not employed, but looking for work;Independent contractor, freelancer, or self-employed;Employed, part-time;Not employed, and not looking for work;Retired'
#  'Student, part-time;Not employed, but looking for work;Independent contractor, freelancer, or self-employed;Not employed, and not looking for work'
#  'Employed, full-time;Student, full-time;Independent contractor, freelancer, or self-employed;Not employed, and not looking for work'
#  'Employed, full-time;Student, full-time;Student, part-time;Independent contractor, freelancer, or self-employed;Retired'
#  'Student, full-time;Independent contractor, freelancer, or self-employed;Retired'
#  'Student, full-time;Student, part-time;Not employed, but looking for work;Not employed, and not looking for work'
#  'Employed, full-time;Student, full-time;Student, part-time;Not employed, but looking for work;Employed, part-time'
#  'Employed, full-time;Student, full-time;Not employed, but looking for work;Independent contractor, freelancer, or self-employed'
#  'Student, part-time;Independent contractor, freelancer, or self-employed;Employed, part-time;Not employed, and not looking for work'
#  'Employed, full-time;Independent contractor, freelancer, or self-employed;Not employed, and not looking for work'
#  'Independent contractor, freelancer, or self-employed;Not employed, and not looking for work;Retired'
#  'Not employed, but looking for work;Employed, part-time;Retired'
#  'Independent contractor, freelancer, or self-employed;Employed, part-time;Not employed, and not looking for work'
#  'Student, part-time;Not employed, but looking for work;Retired'
#  'Student, part-time;Independent contractor, freelancer, or self-employed;Employed, part-time;Retired']

# %%
df['Employment'] = df['Employment'].str.replace('Independent contractor, freelancer, or self-employed', 'independent', regex=True)
df['Employment'] = df['Employment'].str.replace('Not employed, but looking for work', 'unemployed_looking', regex=True)
df['Employment'] = df['Employment'].str.replace('Not employed, and not looking for work', 'unemployed_not_looking', regex=True)
df['Employment'] = df['Employment'].str.replace('I prefer not to say', 'opt_out', regex=True)
df['Employment'] = df['Employment'].str.lower().str.replace(', ', '_').str.replace('-', '_').str.replace(' ', '_')

# %%
df[df['Employment'].isnull()]
# Out:
#        ResponseId MainBranch Employment RemoteWork CodingActivities  \
# 0               1       none        NaN        NaN              NaN
# 30             31       none        NaN        NaN              NaN
# 86             87       none        NaN        NaN              NaN
# 98             99        dev        NaN        NaN              NaN
# 136           137    hobbist        NaN        NaN              NaN
# ...           ...        ...        ...        ...              ...
# 73109       73110       none        NaN        NaN              NaN
# 73157       73158       none        NaN        NaN              NaN
# 73201       73202       none        NaN        NaN              NaN
# 73215       73216       none        NaN        NaN              NaN
# 73243       73244       none        NaN        NaN              NaN
#
#                                                  EdLevel  \
# 0                                                    NaN
# 30                                                   NaN
# 86                                                   NaN
# 98          Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 136    Some college/university study without earning ...
# ...                                                  ...
# 73109                                                NaN
# 73157                                                NaN
# 73201                                                NaN
# 73215                                                NaN
# 73243                                                NaN
#
#                                                LearnCode  \
# 0                                                    NaN
# 30                                                   NaN
# 86                                                   NaN
# 98                                                   NaN
# 136    Friend or family member;Other online resources...
# ...                                                  ...
# 73109                                                NaN
# 73157                                                NaN
# 73201                                                NaN
# 73215                                                NaN
# 73243                                                NaN
#
#                                          LearnCodeOnline LearnCodeCoursesCert  \
# 0                                                    NaN                  NaN
# 30                                                   NaN                  NaN
# 86                                                   NaN                  NaN
# 98                                                   NaN                  NaN
# 136    Technical documentation;Blogs;Written Tutorial...                  NaN
# ...                                                  ...                  ...
# 73109                                                NaN                  NaN
# 73157                                                NaN                  NaN
# 73201                                                NaN                  NaN
# 73215                                                NaN                  NaN
# 73243                                                NaN                  NaN
#
#       YearsCode  ... TimeSearching TimeAnswering Onboarding ProfessionalTech  \
# 0           NaN  ...           NaN           NaN        NaN              NaN
# 30          NaN  ...           NaN           NaN        NaN              NaN
# 86          NaN  ...           NaN           NaN        NaN              NaN
# 98          NaN  ...           NaN           NaN        NaN              NaN
# 136          10  ...           NaN           NaN        NaN              NaN
# ...         ...  ...           ...           ...        ...              ...
# 73109       NaN  ...           NaN           NaN        NaN              NaN
# 73157       NaN  ...           NaN           NaN        NaN              NaN
# 73201       NaN  ...           NaN           NaN        NaN              NaN
# 73215       NaN  ...           NaN           NaN        NaN              NaN
# 73243       NaN  ...           NaN           NaN        NaN              NaN
#
#       TrueFalse_1 TrueFalse_2 TrueFalse_3           SurveyLength SurveyEase  \
# 0             NaN         NaN         NaN                    NaN        NaN
# 30            NaN         NaN         NaN                    NaN        NaN
# 86            NaN         NaN         NaN                    NaN        NaN
# 98            NaN         NaN         NaN                    NaN        NaN
# 136           NaN         NaN         NaN  Appropriate in length       Easy
# ...           ...         ...         ...                    ...        ...
# 73109         NaN         NaN         NaN                    NaN        NaN
# 73157         NaN         NaN         NaN                    NaN        NaN
# 73201         NaN         NaN         NaN                    NaN        NaN
# 73215         NaN         NaN         NaN                    NaN        NaN
# 73243         NaN         NaN         NaN                    NaN        NaN
#
#       ConvertedCompYearly
# 0                     NaN
# 30                    NaN
# 86                    NaN
# 98                    NaN
# 136                   NaN
# ...                   ...
# 73109                 NaN
# 73157                 NaN
# 73201                 NaN
# 73215                 NaN
# 73243                 NaN
#
# [1559 rows x 79 columns]

# %% [markdown]
# Com a impressão acima, nos chamou atenção como algumas linhas possuem muitas respostas vazias. Guardaremos essa informação para analisar depois das colunas.

# %%
df['RemoteWork'].unique()
# Out:
# array([nan, 'Fully remote', 'Hybrid (some remote, some in-person)',
#        'Full in-person'], dtype=object)

# %%
df['RemoteWork'] = df['RemoteWork'].replace({
  'Fully remote': 'remote',
  'Hybrid (some remote, some in-person)': 'hybrid',
  'Full in-person': 'in_person'
})

# %%
df['CodingActivities'].unique()
# Out:
# array([nan, 'Hobby;Contribute to open-source projects', 'Hobby',
#        'I don’t code outside of work',
#        'Hobby;Contribute to open-source projects;Bootstrapping a business',
#        'Hobby;Contribute to open-source projects;Freelance/contract work',
#        'Hobby;Freelance/contract work', 'Hobby;Bootstrapping a business',
#        'Other (please specify):', 'Contribute to open-source projects',
#        'Hobby;Other (please specify):',
#        'Hobby;Contribute to open-source projects;Bootstrapping a business;Freelance/contract work',
#        'Bootstrapping a business', 'Freelance/contract work',
#        'Hobby;Bootstrapping a business;Freelance/contract work',
#        'Bootstrapping a business;Freelance/contract work',
#        'Hobby;Contribute to open-source projects;Other (please specify):',
#        'Contribute to open-source projects;Freelance/contract work',
#        'Hobby;Freelance/contract work;Other (please specify):',
#        'Contribute to open-source projects;Bootstrapping a business',
#        'Contribute to open-source projects;Bootstrapping a business;Freelance/contract work',
#        'Hobby;Bootstrapping a business;Freelance/contract work;School or academic work',
#        'Hobby;School or academic work',
#        'Hobby;Contribute to open-source projects;Bootstrapping a business;School or academic work',
#        'Hobby;Contribute to open-source projects;Freelance/contract work;School or academic work',
#        'Hobby;Bootstrapping a business;School or academic work',
#        'Contribute to open-source projects;School or academic work',
#        'Hobby;Contribute to open-source projects;School or academic work',
#        'Hobby;Freelance/contract work;School or academic work',
#        'Contribute to open-source projects;Other (please specify):',
#        'Hobby;Contribute to open-source projects;Bootstrapping a business;Freelance/contract work;School or academic work',
#        'School or academic work',
#        'Contribute to open-source projects;Freelance/contract work;School or academic work',
#        'Bootstrapping a business;Freelance/contract work;School or academic work',
#        'Hobby;Bootstrapping a business;Other (please specify):',
#        'Bootstrapping a business;Other (please specify):',
#        'Bootstrapping a business;School or academic work',
#        'Hobby;Contribute to open-source projects;Bootstrapping a business;Other (please specify):',
#        'Freelance/contract work;School or academic work',
#        'Hobby;Other (please specify):;School or academic work',
#        'Other (please specify):;School or academic work',
#        'Freelance/contract work;Other (please specify):;School or academic work',
#        'Hobby;Contribute to open-source projects;Freelance/contract work;Other (please specify):;School or academic work',
#        'Contribute to open-source projects;Bootstrapping a business;School or academic work',
#        'Hobby;Contribute to open-source projects;Freelance/contract work;Other (please specify):',
#        'Contribute to open-source projects;Freelance/contract work;Other (please specify):',
#        'Freelance/contract work;Other (please specify):',
#        'Hobby;Contribute to open-source projects;Other (please specify):;School or academic work',
#        'Contribute to open-source projects;Bootstrapping a business;Other (please specify):',
#        'Hobby;Bootstrapping a business;Freelance/contract work;Other (please specify):',
#        'Hobby;Bootstrapping a business;Other (please specify):;School or academic work',
#        'Hobby;Bootstrapping a business;Freelance/contract work;Other (please specify):;School or academic work',
#        'Hobby;Freelance/contract work;Other (please specify):;School or academic work',
#        'Hobby;Contribute to open-source projects;Bootstrapping a business;Freelance/contract work;Other (please specify):',
#        'Bootstrapping a business;Freelance/contract work;Other (please specify):',
#        'Contribute to open-source projects;Bootstrapping a business;Freelance/contract work;School or academic work',
#        'Contribute to open-source projects;Other (please specify):;School or academic work',
#        'Hobby;Contribute to open-source projects;Bootstrapping a business;Freelance/contract work;Other (please specify):;School or academic work',
#        'Contribute to open-source projects;Bootstrapping a business;Freelance/contract work;Other (please specify):',
#        'Contribute to open-source projects;Bootstrapping a business;Other (please specify):;School or academic work',
#        'Contribute to open-source projects;Bootstrapping a business;Freelance/contract work;Other (please specify):;School or academic work',
#        'Contribute to open-source projects;Freelance/contract work;Other (please specify):;School or academic work',
#        'Bootstrapping a business;Other (please specify):;School or academic work',
#        'Hobby;Contribute to open-source projects;Bootstrapping a business;Other (please specify):;School or academic work'],
#       dtype=object)

# %%
df['CodingActivities'] = df['CodingActivities'].str.replace('Contribute to open-source projects', 'open_source', regex=True)
df['CodingActivities'] = df['CodingActivities'].str.replace('Bootstrapping a business', 'business', regex=True)
df['CodingActivities'] = df['CodingActivities'].str.replace('School or academic work', 'school', regex=True)
df['CodingActivities'] = df['CodingActivities'].str.replace('Freelance/contract work', 'freelance', regex=True)
df['CodingActivities'] = df['CodingActivities'].str.replace('Other (please specify):', 'other', regex=True)
df['CodingActivities'] = df['CodingActivities'].str.lower().str.replace(', ', '_').str.replace('-', '_').str.replace(' ', '_')

# %%
df['EdLevel'].unique()
# Out:
# array([nan, 'Master’s degree (M.A., M.S., M.Eng., MBA, etc.)',
#        'Bachelor’s degree (B.A., B.S., B.Eng., etc.)',
#        'Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)',
#        'Some college/university study without earning a degree',
#        'Something else', 'Primary/elementary school',
#        'Other doctoral degree (Ph.D., Ed.D., etc.)',
#        'Associate degree (A.A., A.S., etc.)',
#        'Professional degree (JD, MD, etc.)'], dtype=object)

# %%
df['EdLevel'] = df['EdLevel'].replace({
  "Master’s degree (M.A., M.S., M.Eng., MBA, etc.)": 'master',
  "Bachelor’s degree (B.A., B.S., B.Eng., etc.)": 'bachelor',
  "Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)": 'high_school',
  "Some college/university study without earning a degree": 'unfinished_college',
  "Something else": 'other',
  "Primary/elementary school": 'primary_school',
  "Other doctoral degree (Ph.D., Ed.D., etc.)": 'doctor',
  "Associate degree (A.A., A.S., etc.)": 'associate',
  "Professional degree (JD, MD, etc.)": 'professional'
})

# %%
df['LearnCode'].unique()
# Out:
# array([nan,
#        'Books / Physical media;Friend or family member;Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc)',
#        'Books / Physical media;School (i.e., University, College, etc)',
#        'Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);On the job training',
#        'Other online resources (e.g., videos, blogs, forum)',
#        'Online Courses or Certification',
#        'On the job training;Coding Bootcamp',
#        'Books / Physical media;Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc)',
#        'School (i.e., University, College, etc)',
#        'Books / Physical media',
#        'Books / Physical media;Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);Online Courses or Certification;Colleague',
#        'Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);On the job training;Online Courses or Certification',
#        'Books / Physical media;School (i.e., University, College, etc);Online Courses or Certification;Coding Bootcamp',
#        'Books / Physical media;Coding Bootcamp;Colleague',
#        'Books / Physical media;Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);On the job training',
#        'Other (please specify):',
#        'Other online resources (e.g., videos, blogs, forum);Colleague;Other (please specify):',
#        'Books / Physical media;Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);Online Courses or Certification',
#        'Books / Physical media;Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);On the job training;Online Courses or Certification;Colleague',
#        'Books / Physical media;Other online resources (e.g., videos, blogs, forum);On the job training;Colleague;Other (please specify):',
#        'Books / Physical media;Other online resources (e.g., videos, blogs, forum);On the job training',
#        'Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);Online Courses or Certification',
#        'Friend or family member;Other online resources (e.g., videos, blogs, forum)',
#        'Books / Physical media;Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);On the job training;Online Courses or Certification',
#        'Books / Physical media;Friend or family member;Other online resources (e.g., videos, blogs, forum)',
#        'Friend or family member;Other online resources (e.g., videos, blogs, forum);Online Courses or Certification',
#        'Books / Physical media;Other online resources (e.g., videos, blogs, forum);Online Courses or Certification',
#        'Other online resources (e.g., videos, blogs, forum);On the job training;Online Courses or Certification',
#        'Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);Online Courses or Certification;Colleague',
#        'Books / Physical media;Other online resources (e.g., videos, blogs, forum)',
#        'Other online resources (e.g., videos, blogs, forum);Online Courses or Certification',
#        'Other online resources (e.g., videos, blogs, forum);Other (please specify):',
#        'Friend or family member;Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc)',
#        'Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc)',
#        'Books / Physical media;Friend or family member;Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);On the job training;Online Courses or Certification',
#        'Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);On the job training;Online Courses or Certification;Hackathons (virtual or in-person)',
#        'Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);On the job training;Online Courses or Certification;Other (please specify):',
#        'Books / Physical media;Friend or family member;Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);On the job training;Online Courses or Certification;Colleague',
#        'Books / Physical media;Other online resources (e.g., videos, blogs, forum);Online Courses or Certification;Coding Bootcamp;Colleague;Other (please specify):',
#        'School (i.e., University, College, etc);Other (please specify):',
#        'Books / Physical media;Friend or family member;Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);Online Courses or Certification',
#        'School (i.e., University, College, etc);Colleague',
#        'Books / Physical media;Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);On the job training;Colleague',
#        'Other online resources (e.g., videos, blogs, forum);On the job training',
#        'Books / Physical media;School (i.e., University, College, etc);On the job training;Online Courses or Certification;Colleague',
#        'Books / Physical media;Friend or family member;Other online resources (e.g., videos, blogs, forum);On the job training;Online Courses or Certification;Coding Bootcamp',
#        'Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);Online Courses or Certification;Hackathons (virtual or in-person)',
#        'Books / Physical media;Friend or family member',
#        'On the job training;Online Courses or Certification;Coding Bootcamp',
#        'Books / Physical media;Other (please specify):',
#        'Books / Physical media;Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);Online Courses or Certification;Hackathons (virtual or in-person)',
#        'Books / Physical media;Friend or family member;Other (please specify):',
#        'Books / Physical media;Other online resources (e.g., videos, blogs, forum);Online Courses or Certification;Coding Bootcamp',
#        'Books / Physical media;Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);Colleague',
#        'Friend or family member;Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);On the job training;Online Courses or Certification',
#        'Books / Physical media;Friend or family member;Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);On the job training',
#        'School (i.e., University, College, etc);On the job training;Online Courses or Certification;Coding Bootcamp;Hackathons (virtual or in-person)',
#        'Books / Physical media;School (i.e., University, College, etc);On the job training',
#        'Books / Physical media;Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);On the job training;Online Courses or Certification;Hackathons (virtual or in-person)',
#        'Books / Physical media;Friend or family member;Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);On the job training;Colleague',
#        'Books / Physical media;Other online resources (e.g., videos, blogs, forum);Online Courses or Certification;Hackathons (virtual or in-person)',
#        'School (i.e., University, College, etc);On the job training',
#        'Books / Physical media;Friend or family member;School (i.e., University, College, etc)',
#        'Books / Physical media;On the job training',
#        'School (i.e., University, College, etc);Online Courses or Certification',
#        'Books / Physical media;Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);On the job training;Online Courses or Certification;Coding Bootcamp',
#        'School (i.e., University, College, etc);On the job training;Online Courses or Certification',
#        'Friend or family member;School (i.e., University, College, etc);On the job training',
#        'Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);On the job training;Colleague',
#        'Books / Physical media;On the job training;Online Courses or Certification;Colleague',
#        'Friend or family member;Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);On the job training;Online Courses or Certification;Coding Bootcamp;Colleague',
#        'Books / Physical media;Friend or family member;Online Courses or Certification;Colleague',
#        'Other online resources (e.g., videos, blogs, forum);On the job training;Coding Bootcamp',
#        'Books / Physical media;Other online resources (e.g., videos, blogs, forum);On the job training;Online Courses or Certification;Coding Bootcamp',
#        'Friend or family member',
#        'Books / Physical media;Online Courses or Certification;Coding Bootcamp',
#        'Books / Physical media;School (i.e., University, College, etc);Online Courses or Certification',
#        'Books / Physical media;Online Courses or Certification',
#        'Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);Online Courses or Certification;Coding Bootcamp',
#        'Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);Hackathons (virtual or in-person)',
#        'Friend or family member;Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);On the job training;Hackathons (virtual or in-person)',
#        'Colleague',
#        'Books / Physical media;Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);Online Courses or Certification;Coding Bootcamp',
#        'Books / Physical media;Other online resources (e.g., videos, blogs, forum);Colleague',
#        'Books / Physical media;Other online resources (e.g., videos, blogs, forum);Coding Bootcamp',
#        'Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);On the job training;Hackathons (virtual or in-person)',
#        'School (i.e., University, College, etc);Colleague;Hackathons (virtual or in-person)',
#        'Books / Physical media;School (i.e., University, College, etc);On the job training;Colleague',
#        'Books / Physical media;Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);Coding Bootcamp',
#        'Books / Physical media;School (i.e., University, College, etc);On the job training;Online Courses or Certification;Hackathons (virtual or in-person)',
#        'Books / Physical media;Friend or family member;Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);Colleague',
#        'Books / Physical media;Other online resources (e.g., videos, blogs, forum);Online Courses or Certification;Coding Bootcamp;Colleague',
#        'Other online resources (e.g., videos, blogs, forum);Coding Bootcamp;Colleague',
#        'School (i.e., University, College, etc);On the job training;Colleague',
#        'Books / Physical media;School (i.e., University, College, etc);On the job training;Online Courses or Certification',
#        'Books / Physical media;Other online resources (e.g., videos, blogs, forum);On the job training;Colleague',
#        'Friend or family member;Other online resources (e.g., videos, blogs, forum);Other (please specify):',
#        'Books / Physical media;Friend or family member;Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);Online Courses or Certification;Colleague',
#        'Friend or family member;School (i.e., University, College, etc)',
#        'Friend or family member;Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);On the job training;Colleague',
#        'Books / Physical media;Friend or family member;School (i.e., University, College, etc);On the job training;Online Courses or Certification',
#        'Books / Physical media;School (i.e., University, College, etc);On the job training;Online Courses or Certification;Colleague;Hackathons (virtual or in-person)',
#        'Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);Online Courses or Certification;Coding Bootcamp;Hackathons (virtual or in-person)',
#        'Books / Physical media;Other online resources (e.g., videos, blogs, forum);On the job training;Online Courses or Certification;Colleague;Hackathons (virtual or in-person)',
#        'Books / Physical media;Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);Online Courses or Certification;Colleague;Hackathons (virtual or in-person)',
#        'Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);Colleague',
#        'Coding Bootcamp',
#        'Books / Physical media;Other online resources (e.g., videos, blogs, forum);On the job training;Hackathons (virtual or in-person)',
#        'Books / Physical media;Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);On the job training;Coding Bootcamp',
#        'On the job training',
#        'Books / Physical media;Other online resources (e.g., videos, blogs, forum);On the job training;Online Courses or Certification',
#        'Books / Physical media;Friend or family member;Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);On the job training;Online Courses or Certification;Coding Bootcamp',
#        'Books / Physical media;Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);Hackathons (virtual or in-person)',
#        'Books / Physical media;Friend or family member;Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);On the job training;Online Courses or Certification;Coding Bootcamp;Colleague;Hackathons (virtual or in-person)',
#        'Books / Physical media;Friend or family member;Other online resources (e.g., videos, blogs, forum);On the job training',
#        'Books / Physical media;Friend or family member;School (i.e., University, College, etc);Online Courses or Certification',
#        'Books / Physical media;Friend or family member;Other online resources (e.g., videos, blogs, forum);On the job training;Colleague',
#        'Books / Physical media;Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);Other (please specify):',
#        'Books / Physical media;Friend or family member;School (i.e., University, College, etc);On the job training',
#        'Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);Other (please specify):',
#        'Other online resources (e.g., videos, blogs, forum);On the job training;Colleague',
#        'Friend or family member;Coding Bootcamp;Hackathons (virtual or in-person)',
#        'Books / Physical media;On the job training;Coding Bootcamp',
#        'Books / Physical media;Friend or family member;Other online resources (e.g., videos, blogs, forum);On the job training;Online Courses or Certification',
#        'Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);On the job training;Online Courses or Certification;Colleague',
#        'School (i.e., University, College, etc);Online Courses or Certification;Other (please specify):',
#        'Friend or family member;Coding Bootcamp',
#        'Books / Physical media;Friend or family member;School (i.e., University, College, etc);On the job training;Other (please specify):',
#        'Friend or family member;Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);On the job training',
#        'Books / Physical media;Friend or family member;Other online resources (e.g., videos, blogs, forum);Online Courses or Certification',
#        'Friend or family member;Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);On the job training;Online Courses or Certification;Colleague',
#        'Books / Physical media;Friend or family member;School (i.e., University, College, etc);On the job training;Online Courses or Certification;Coding Bootcamp',
#        'Books / Physical media;Friend or family member;Other online resources (e.g., videos, blogs, forum);On the job training;Online Courses or Certification;Colleague',
#        'Books / Physical media;Friend or family member;Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);Online Courses or Certification;Hackathons (virtual or in-person)',
#        'Friend or family member;Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);On the job training;Colleague;Hackathons (virtual or in-person)',
#        'Books / Physical media;Friend or family member;On the job training;Online Courses or Certification',
#        'Books / Physical media;On the job training;Colleague',
#        'On the job training;Online Courses or Certification;Colleague',
#        'Books / Physical media;On the job training;Online Courses or Certification',
#        'Books / Physical media;Other online resources (e.g., videos, blogs, forum);Other (please specify):',
#        'Friend or family member;On the job training',
#        'Books / Physical media;Friend or family member;Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);On the job training;Online Courses or Certification;Colleague;Hackathons (virtual or in-person)',
#        'Books / Physical media;Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);On the job training;Online Courses or Certification;Coding Bootcamp;Colleague',
#        'Books / Physical media;Other online resources (e.g., videos, blogs, forum);On the job training;Online Courses or Certification;Colleague',
#        'Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);On the job training;Other (please specify):',
#        'Books / Physical media;On the job training;Online Courses or Certification;Coding Bootcamp',
#        'Online Courses or Certification;Other (please specify):',
#        'Books / Physical media;Friend or family member;Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);On the job training;Online Courses or Certification;Colleague;Other (please specify):',
#        'Friend or family member;Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);Online Courses or Certification',
#        'School (i.e., University, College, etc);Hackathons (virtual or in-person)',
#        'Books / Physical media;Friend or family member;School (i.e., University, College, etc);Coding Bootcamp',
#        'Books / Physical media;Friend or family member;Other online resources (e.g., videos, blogs, forum);Online Courses or Certification;Coding Bootcamp;Colleague',
#        'Books / Physical media;Coding Bootcamp',
#        'Books / Physical media;School (i.e., University, College, etc);Other (please specify):',
#        'Other online resources (e.g., videos, blogs, forum);Online Courses or Certification;Coding Bootcamp',
#        'Books / Physical media;School (i.e., University, College, etc);On the job training;Colleague;Hackathons (virtual or in-person)',
#        'Other online resources (e.g., videos, blogs, forum);Colleague',
#        'Books / Physical media;School (i.e., University, College, etc);Coding Bootcamp',
#        'Books / Physical media;Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);Colleague;Hackathons (virtual or in-person)',
#        'Books / Physical media;Friend or family member;Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);Coding Bootcamp',
#        'Books / Physical media;Friend or family member;Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);Hackathons (virtual or in-person)',
#        'Books / Physical media;Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);On the job training;Hackathons (virtual or in-person)',
#        'Books / Physical media;Friend or family member;Other online resources (e.g., videos, blogs, forum);Other (please specify):',
#        'School (i.e., University, College, etc);On the job training;Coding Bootcamp',
#        'Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);On the job training;Online Courses or Certification;Colleague;Hackathons (virtual or in-person)',
#        'Friend or family member;Other online resources (e.g., videos, blogs, forum);Hackathons (virtual or in-person)',
#        'Books / Physical media;School (i.e., University, College, etc);On the job training;Hackathons (virtual or in-person)',
#        'Books / Physical media;Friend or family member;On the job training;Colleague',
#        'Books / Physical media;On the job training;Coding Bootcamp;Colleague',
#        'Books / Physical media;Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);Online Courses or Certification;Other (please specify):',
#        'Books / Physical media;Friend or family member;School (i.e., University, College, etc);On the job training;Colleague',
#        'On the job training;Online Courses or Certification',
#        'Books / Physical media;Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);On the job training;Online Courses or Certification;Colleague;Other (please specify):',
#        'Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);Colleague;Hackathons (virtual or in-person)',
#        'Books / Physical media;Other online resources (e.g., videos, blogs, forum);Online Courses or Certification;Colleague',
#        'Books / Physical media;Other online resources (e.g., videos, blogs, forum);On the job training;Online Courses or Certification;Hackathons (virtual or in-person)',
#        'Friend or family member;School (i.e., University, College, etc);Online Courses or Certification;Coding Bootcamp',
#        'Books / Physical media;Other online resources (e.g., videos, blogs, forum);Colleague;Other (please specify):',
#        'Other online resources (e.g., videos, blogs, forum);Coding Bootcamp',
#        'Books / Physical media;School (i.e., University, College, etc);On the job training;Online Courses or Certification;Coding Bootcamp',
#        'Friend or family member;School (i.e., University, College, etc);Online Courses or Certification',
#        'Books / Physical media;Other online resources (e.g., videos, blogs, forum);Hackathons (virtual or in-person)',
#        'Books / Physical media;Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);On the job training;Other (please specify):',
#        'Books / Physical media;Other online resources (e.g., videos, blogs, forum);On the job training;Coding Bootcamp;Other (please specify):',
#        'Books / Physical media;School (i.e., University, College, etc);Online Courses or Certification;Hackathons (virtual or in-person)',
#        'Books / Physical media;Friend or family member;Coding Bootcamp;Colleague;Hackathons (virtual or in-person)',
#        'Friend or family member;Other online resources (e.g., videos, blogs, forum);Online Courses or Certification;Coding Bootcamp;Colleague',
#        'Books / Physical media;Friend or family member;Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);Online Courses or Certification;Coding Bootcamp;Colleague',
#        'On the job training;Other (please specify):',
#        'Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);On the job training;Colleague;Other (please specify):',
#        'Books / Physical media;Friend or family member;Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);Online Courses or Certification;Colleague;Hackathons (virtual or in-person)',
#        'Books / Physical media;Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);On the job training;Colleague;Hackathons (virtual or in-person)',
#        'Friend or family member;Other (please specify):',
#        'Books / Physical media;Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);On the job training;Coding Bootcamp;Colleague;Hackathons (virtual or in-person)',
#        'Books / Physical media;Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);On the job training;Online Courses or Certification;Colleague;Hackathons (virtual or in-person)',
#        'Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);On the job training;Online Courses or Certification;Coding Bootcamp;Colleague;Hackathons (virtual or in-person)',
#        'Books / Physical media;Friend or family member;Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);On the job training;Colleague;Other (please specify):',
#        'Books / Physical media;Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);On the job training;Online Courses or Certification;Coding Bootcamp;Hackathons (virtual or in-person)',
#        'Other online resources (e.g., videos, blogs, forum);On the job training;Coding Bootcamp;Colleague',
#        'Books / Physical media;School (i.e., University, College, etc);Colleague',
#        'Friend or family member;Other online resources (e.g., videos, blogs, forum);Online Courses or Certification;Coding Bootcamp',
#        'School (i.e., University, College, etc);On the job training;Online Courses or Certification;Colleague',
#        'Books / Physical media;Friend or family member;Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);On the job training;Coding Bootcamp',
#        'Other online resources (e.g., videos, blogs, forum);Online Courses or Certification;Hackathons (virtual or in-person)',
#        'Friend or family member;Other online resources (e.g., videos, blogs, forum);On the job training;Colleague',
#        'Books / Physical media;Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);On the job training;Colleague;Other (please specify):',
#        'Books / Physical media;Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);On the job training;Online Courses or Certification;Coding Bootcamp;Colleague;Hackathons (virtual or in-person)',
#        'Books / Physical media;Online Courses or Certification;Hackathons (virtual or in-person)',
#        'Books / Physical media;School (i.e., University, College, etc);On the job training;Online Courses or Certification;Other (please specify):',
#        'Books / Physical media;Friend or family member;School (i.e., University, College, etc);Online Courses or Certification;Coding Bootcamp',
#        'Books / Physical media;Other online resources (e.g., videos, blogs, forum);On the job training;Coding Bootcamp;Colleague',
#        'Books / Physical media;Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);On the job training;Coding Bootcamp;Colleague',
#        'On the job training;Colleague;Other (please specify):',
#        'Books / Physical media;Friend or family member;Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);On the job training;Online Courses or Certification;Coding Bootcamp;Colleague',
#        'Books / Physical media;School (i.e., University, College, etc);On the job training;Other (please specify):',
#        'Books / Physical media;Friend or family member;Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);On the job training;Online Courses or Certification;Hackathons (virtual or in-person)',
#        'Friend or family member;Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);Colleague;Hackathons (virtual or in-person)',
#        'Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);On the job training;Colleague;Hackathons (virtual or in-person)',
#        'Books / Physical media;Other online resources (e.g., videos, blogs, forum);Other (please specify):;Hackathons (virtual or in-person)',
#        'Books / Physical media;Friend or family member;Other online resources (e.g., videos, blogs, forum);On the job training;Online Courses or Certification;Coding Bootcamp;Colleague',
#        'Books / Physical media;Other online resources (e.g., videos, blogs, forum);On the job training;Online Courses or Certification;Coding Bootcamp;Colleague',
#        'School (i.e., University, College, etc);Coding Bootcamp',
#        'Books / Physical media;Other online resources (e.g., videos, blogs, forum);On the job training;Coding Bootcamp',
#        'Friend or family member;School (i.e., University, College, etc);On the job training;Coding Bootcamp',
#        'Books / Physical media;Friend or family member;Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);On the job training;Other (please specify):',
#        'Friend or family member;Other online resources (e.g., videos, blogs, forum);On the job training',
#        'Books / Physical media;Friend or family member;Other online resources (e.g., videos, blogs, forum);Online Courses or Certification;Coding Bootcamp',
#        'Books / Physical media;Other online resources (e.g., videos, blogs, forum);Online Courses or Certification;Other (please specify):',
#        'Other online resources (e.g., videos, blogs, forum);On the job training;Online Courses or Certification;Colleague',
#        'Friend or family member;Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);Online Courses or Certification;Colleague',
#        'School (i.e., University, College, etc);On the job training;Colleague;Hackathons (virtual or in-person)',
#        'School (i.e., University, College, etc);On the job training;Online Courses or Certification;Coding Bootcamp',
#        'Books / Physical media;School (i.e., University, College, etc);Online Courses or Certification;Other (please specify):',
#        'Books / Physical media;Friend or family member;Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);On the job training;Colleague;Other (please specify):;Hackathons (virtual or in-person)',
#        'Books / Physical media;Friend or family member;School (i.e., University, College, etc);Hackathons (virtual or in-person)',
#        'Other online resources (e.g., videos, blogs, forum);On the job training;Online Courses or Certification;Hackathons (virtual or in-person)',
#        'Books / Physical media;Friend or family member;Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);On the job training;Colleague;Hackathons (virtual or in-person)',
#        'Books / Physical media;School (i.e., University, College, etc);Online Courses or Certification;Coding Bootcamp;Colleague',
#        'Friend or family member;Online Courses or Certification',
#        'Other online resources (e.g., videos, blogs, forum);On the job training;Other (please specify):',
#        'Books / Physical media;Other online resources (e.g., videos, blogs, forum);Colleague;Hackathons (virtual or in-person)',
#        'Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);Colleague;Other (please specify):',
#        'Books / Physical media;School (i.e., University, College, etc);Hackathons (virtual or in-person)',
#        'Books / Physical media;Friend or family member;Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);Other (please specify):',
#        'Friend or family member;Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);Colleague',
#        'Books / Physical media;Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);On the job training;Coding Bootcamp;Hackathons (virtual or in-person)',
#        'Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);On the job training;Online Courses or Certification;Coding Bootcamp',
#        'Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);Online Courses or Certification;Other (please specify):',
#        'School (i.e., University, College, etc);On the job training;Other (please specify):',
#        'Books / Physical media;Friend or family member;Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);On the job training;Online Courses or Certification;Coding Bootcamp;Colleague;Other (please specify):;Hackathons (virtual or in-person)',
#        'Other online resources (e.g., videos, blogs, forum);Hackathons (virtual or in-person)',
#        'Books / Physical media;Friend or family member;Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);Online Courses or Certification;Coding Bootcamp;Hackathons (virtual or in-person)',
#        'On the job training;Online Courses or Certification;Other (please specify):',
#        'Friend or family member;School (i.e., University, College, etc);On the job training;Colleague',
#        'Books / Physical media;Other online resources (e.g., videos, blogs, forum);On the job training;Other (please specify):;Hackathons (virtual or in-person)',
#        'Books / Physical media;Friend or family member;Online Courses or Certification',
#        'Online Courses or Certification;Hackathons (virtual or in-person)',
#        'Books / Physical media;Friend or family member;Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);Coding Bootcamp;Hackathons (virtual or in-person)',
#        'Other online resources (e.g., videos, blogs, forum);On the job training;Colleague;Other (please specify):',
#        'Other online resources (e.g., videos, blogs, forum);Coding Bootcamp;Other (please specify):',
#        'School (i.e., University, College, etc);On the job training;Online Courses or Certification;Colleague;Other (please specify):',
#        'Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);On the job training;Online Courses or Certification;Coding Bootcamp;Hackathons (virtual or in-person)',
#        'Books / Physical media;Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);Online Courses or Certification;Coding Bootcamp;Colleague;Hackathons (virtual or in-person)',
#        'Friend or family member;School (i.e., University, College, etc);On the job training;Online Courses or Certification',
#        'Books / Physical media;Other online resources (e.g., videos, blogs, forum);On the job training;Online Courses or Certification;Coding Bootcamp;Colleague;Hackathons (virtual or in-person)',
#        'School (i.e., University, College, etc);Other (please specify):;Hackathons (virtual or in-person)',
#        'Friend or family member;Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);Other (please specify):',
#        'Books / Physical media;Other online resources (e.g., videos, blogs, forum);On the job training;Other (please specify):',
#        'Friend or family member;Online Courses or Certification;Colleague',
#        'Books / Physical media;Friend or family member;Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);On the job training;Hackathons (virtual or in-person)',
#        'Friend or family member;School (i.e., University, College, etc);Colleague',
#        'Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);Coding Bootcamp',
#        'Books / Physical media;Colleague',
#        'Books / Physical media;On the job training;Other (please specify):',
#        'Other online resources (e.g., videos, blogs, forum);Online Courses or Certification;Other (please specify):',
#        'Friend or family member;Other online resources (e.g., videos, blogs, forum);Colleague',
#        'Books / Physical media;Friend or family member;On the job training',
#        'Books / Physical media;School (i.e., University, College, etc);Online Courses or Certification;Colleague',
#        'Books / Physical media;Friend or family member;School (i.e., University, College, etc);Online Courses or Certification;Hackathons (virtual or in-person)',
#        'Friend or family member;Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);Hackathons (virtual or in-person)',
#        'Hackathons (virtual or in-person)',
#        'Online Courses or Certification;Coding Bootcamp',
#        'School (i.e., University, College, etc);Online Courses or Certification;Coding Bootcamp',
#        'Books / Physical media;Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);Online Courses or Certification;Coding Bootcamp;Hackathons (virtual or in-person)',
#        'Books / Physical media;Friend or family member;Colleague;Hackathons (virtual or in-person)',
#        'Other online resources (e.g., videos, blogs, forum);On the job training;Online Courses or Certification;Coding Bootcamp',
#        'Friend or family member;Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);Colleague;Other (please specify):',
#        'School (i.e., University, College, etc);Online Courses or Certification;Colleague',
#        'Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);On the job training;Coding Bootcamp',
#        'Books / Physical media;Friend or family member;Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);On the job training;Online Courses or Certification;Other (please specify):',
#        'School (i.e., University, College, etc);Coding Bootcamp;Hackathons (virtual or in-person)',
#        'Books / Physical media;Friend or family member;School (i.e., University, College, etc);Colleague',
#        'Books / Physical media;Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);Online Courses or Certification;Coding Bootcamp;Colleague',
#        'Friend or family member;Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);On the job training;Online Courses or Certification;Coding Bootcamp',
#        'Books / Physical media;Friend or family member;Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);Online Courses or Certification;Other (please specify):',
#        'Online Courses or Certification;Colleague',
#        'Books / Physical media;School (i.e., University, College, etc);On the job training;Online Courses or Certification;Coding Bootcamp;Hackathons (virtual or in-person)',
#        'Other online resources (e.g., videos, blogs, forum);Online Courses or Certification;Coding Bootcamp;Colleague',
#        'Online Courses or Certification;Coding Bootcamp;Colleague',
#        'Books / Physical media;Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);On the job training;Online Courses or Certification;Coding Bootcamp;Colleague;Other (please specify):',
#        'Other online resources (e.g., videos, blogs, forum);Colleague;Hackathons (virtual or in-person)',
#        'Friend or family member;Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);On the job training;Online Courses or Certification;Colleague;Hackathons (virtual or in-person)',
#        'Friend or family member;Coding Bootcamp;Colleague',
#        'Friend or family member;Other online resources (e.g., videos, blogs, forum);On the job training;Online Courses or Certification;Coding Bootcamp',
#        'Books / Physical media;Other online resources (e.g., videos, blogs, forum);On the job training;Online Courses or Certification;Coding Bootcamp;Hackathons (virtual or in-person)',
#        'Friend or family member;Other online resources (e.g., videos, blogs, forum);Online Courses or Certification;Colleague',
#        'Friend or family member;School (i.e., University, College, etc);Other (please specify):',
#        'On the job training;Colleague;Hackathons (virtual or in-person)',
#        'Books / Physical media;Friend or family member;Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);Online Courses or Certification;Coding Bootcamp',
#        'Books / Physical media;Friend or family member;School (i.e., University, College, etc);Online Courses or Certification;Colleague;Hackathons (virtual or in-person)',
#        'Friend or family member;Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);Coding Bootcamp;Colleague;Hackathons (virtual or in-person)',
#        'Friend or family member;Other online resources (e.g., videos, blogs, forum);On the job training;Coding Bootcamp;Colleague',
#        'Books / Physical media;Friend or family member;Other online resources (e.g., videos, blogs, forum);Online Courses or Certification;Colleague',
#        'Books / Physical media;Friend or family member;Other online resources (e.g., videos, blogs, forum);Colleague',
#        'Other online resources (e.g., videos, blogs, forum);Online Courses or Certification;Colleague',
#        'Friend or family member;Other online resources (e.g., videos, blogs, forum);On the job training;Online Courses or Certification;Coding Bootcamp;Hackathons (virtual or in-person)',
#        'Other online resources (e.g., videos, blogs, forum);On the job training;Online Courses or Certification;Coding Bootcamp;Colleague',
#        'Other online resources (e.g., videos, blogs, forum);On the job training;Online Courses or Certification;Coding Bootcamp;Hackathons (virtual or in-person)',
#        'Friend or family member;Other online resources (e.g., videos, blogs, forum);On the job training;Online Courses or Certification;Colleague;Hackathons (virtual or in-person)',
#        'Books / Physical media;On the job training;Online Courses or Certification;Coding Bootcamp;Colleague',
#        'Books / Physical media;On the job training;Online Courses or Certification;Coding Bootcamp;Hackathons (virtual or in-person)',
#        'Books / Physical media;Friend or family member;Other online resources (e.g., videos, blogs, forum);On the job training;Other (please specify):',
#        'Books / Physical media;School (i.e., University, College, etc);On the job training;Coding Bootcamp;Colleague',
#        'Friend or family member;School (i.e., University, College, etc);On the job training;Online Courses or Certification;Hackathons (virtual or in-person)',
#        'Books / Physical media;Friend or family member;Other online resources (e.g., videos, blogs, forum);On the job training;Online Courses or Certification;Colleague;Hackathons (virtual or in-person)',
#        'Books / Physical media;Friend or family member;Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);On the job training;Online Courses or Certification;Coding Bootcamp;Hackathons (virtual or in-person)',
#        'School (i.e., University, College, etc);On the job training;Hackathons (virtual or in-person)',
#        'Friend or family member;Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);On the job training;Online Courses or Certification;Coding Bootcamp;Hackathons (virtual or in-person)',
#        'On the job training;Online Courses or Certification;Colleague;Hackathons (virtual or in-person)',
#        'Other online resources (e.g., videos, blogs, forum);Online Courses or Certification;Coding Bootcamp;Hackathons (virtual or in-person)',
#        'Friend or family member;On the job training;Online Courses or Certification;Coding Bootcamp;Colleague',
#        'Books / Physical media;Friend or family member;School (i.e., University, College, etc);On the job training;Online Courses or Certification;Colleague',
#        'School (i.e., University, College, etc);On the job training;Other (please specify):;Hackathons (virtual or in-person)',
#        'On the job training;Colleague',
#        'Books / Physical media;Online Courses or Certification;Colleague',
#        'Books / Physical media;Friend or family member;Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);Online Courses or Certification;Coding Bootcamp;Colleague;Hackathons (virtual or in-person)',
#        'Coding Bootcamp;Colleague',
#        'Books / Physical media;Friend or family member;Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);Colleague;Other (please specify):;Hackathons (virtual or in-person)',
#        'Books / Physical media;Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);Coding Bootcamp;Hackathons (virtual or in-person)',
#        'Friend or family member;School (i.e., University, College, etc);Online Courses or Certification;Colleague',
#        'Books / Physical media;Friend or family member;Other online resources (e.g., videos, blogs, forum);Coding Bootcamp',
#        'Books / Physical media;Other online resources (e.g., videos, blogs, forum);Online Courses or Certification;Coding Bootcamp;Hackathons (virtual or in-person)',
#        'Friend or family member;Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);On the job training;Other (please specify):',
#        'Books / Physical media;School (i.e., University, College, etc);On the job training;Online Courses or Certification;Coding Bootcamp;Colleague',
#        'Online Courses or Certification;Coding Bootcamp;Hackathons (virtual or in-person)',
#        'Friend or family member;On the job training;Online Courses or Certification;Colleague',
#        'Books / Physical media;Other online resources (e.g., videos, blogs, forum);On the job training;Online Courses or Certification;Colleague;Other (please specify):',
#        'Books / Physical media;Online Courses or Certification;Other (please specify):',
#        'Books / Physical media;Friend or family member;Other online resources (e.g., videos, blogs, forum);Online Courses or Certification;Colleague;Hackathons (virtual or in-person)',
#        'Friend or family member;Other online resources (e.g., videos, blogs, forum);On the job training;Online Courses or Certification;Colleague',
#        'Books / Physical media;Friend or family member;Coding Bootcamp',
#        'Books / Physical media;Coding Bootcamp;Hackathons (virtual or in-person)',
#        'Friend or family member;Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);Online Courses or Certification;Hackathons (virtual or in-person)',
#        'School (i.e., University, College, etc);Online Courses or Certification;Coding Bootcamp;Other (please specify):',
#        'Books / Physical media;Friend or family member;Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);Online Courses or Certification;Colleague;Other (please specify):',
#        'Books / Physical media;Friend or family member;On the job training;Online Courses or Certification;Colleague',
#        'Friend or family member;Colleague',
#        'Other online resources (e.g., videos, blogs, forum);Other (please specify):;Hackathons (virtual or in-person)',
# ...
#        'Friend or family member;Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);Coding Bootcamp;Colleague',
#        'Friend or family member;Online Courses or Certification;Coding Bootcamp;Colleague',
#        'Books / Physical media;Friend or family member;Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);Online Courses or Certification;Coding Bootcamp;Other (please specify):',
#        'Books / Physical media;Friend or family member;Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);On the job training;Coding Bootcamp;Hackathons (virtual or in-person)',
#        'Friend or family member;Online Courses or Certification;Coding Bootcamp;Colleague;Hackathons (virtual or in-person)',
#        'Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);On the job training;Online Courses or Certification;Coding Bootcamp;Other (please specify):;Hackathons (virtual or in-person)',
#        'Friend or family member;Colleague;Other (please specify):',
#        'Books / Physical media;Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);On the job training;Colleague;Other (please specify):;Hackathons (virtual or in-person)',
#        'Books / Physical media;Friend or family member;Online Courses or Certification;Colleague;Other (please specify):',
#        'Books / Physical media;Friend or family member;On the job training;Hackathons (virtual or in-person)',
#        'Books / Physical media;Other online resources (e.g., videos, blogs, forum);Coding Bootcamp;Colleague;Hackathons (virtual or in-person)',
#        'Books / Physical media;Friend or family member;School (i.e., University, College, etc);On the job training;Coding Bootcamp;Colleague',
#        'Friend or family member;School (i.e., University, College, etc);Online Courses or Certification;Coding Bootcamp;Hackathons (virtual or in-person)',
#        'Books / Physical media;On the job training;Online Courses or Certification;Coding Bootcamp;Colleague;Hackathons (virtual or in-person)',
#        'Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);Coding Bootcamp;Colleague',
#        'Friend or family member;Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);Coding Bootcamp;Hackathons (virtual or in-person)',
#        'Friend or family member;On the job training;Online Courses or Certification;Coding Bootcamp',
#        'Other online resources (e.g., videos, blogs, forum);On the job training;Coding Bootcamp;Colleague;Hackathons (virtual or in-person)',
#        'Books / Physical media;Friend or family member;On the job training;Coding Bootcamp',
#        'Coding Bootcamp;Colleague;Hackathons (virtual or in-person)',
#        'On the job training;Coding Bootcamp;Hackathons (virtual or in-person)',
#        'Books / Physical media;Friend or family member;On the job training;Coding Bootcamp;Colleague',
#        'Friend or family member;On the job training;Online Courses or Certification;Other (please specify):;Hackathons (virtual or in-person)',
#        'Friend or family member;Hackathons (virtual or in-person)',
#        'Friend or family member;Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);On the job training;Online Courses or Certification;Coding Bootcamp;Colleague;Other (please specify):;Hackathons (virtual or in-person)',
#        'Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);Online Courses or Certification;Colleague;Other (please specify):',
#        'Books / Physical media;Friend or family member;School (i.e., University, College, etc);Online Courses or Certification;Coding Bootcamp;Hackathons (virtual or in-person)',
#        'Books / Physical media;Other online resources (e.g., videos, blogs, forum);On the job training;Coding Bootcamp;Colleague;Other (please specify):',
#        'Books / Physical media;Friend or family member;Other online resources (e.g., videos, blogs, forum);Online Courses or Certification;Coding Bootcamp;Hackathons (virtual or in-person)',
#        'Books / Physical media;Friend or family member;Other online resources (e.g., videos, blogs, forum);Coding Bootcamp;Hackathons (virtual or in-person)',
#        'Books / Physical media;Friend or family member;On the job training;Online Courses or Certification;Coding Bootcamp;Colleague',
#        'Friend or family member;Online Courses or Certification;Colleague;Other (please specify):',
#        'Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);On the job training;Online Courses or Certification;Other (please specify):;Hackathons (virtual or in-person)',
#        'Books / Physical media;School (i.e., University, College, etc);Coding Bootcamp;Colleague;Hackathons (virtual or in-person)',
#        'Friend or family member;On the job training;Online Courses or Certification;Coding Bootcamp;Colleague;Hackathons (virtual or in-person)',
#        'Friend or family member;Online Courses or Certification;Other (please specify):;Hackathons (virtual or in-person)',
#        'Books / Physical media;Friend or family member;School (i.e., University, College, etc);Colleague;Other (please specify):;Hackathons (virtual or in-person)',
#        'Friend or family member;School (i.e., University, College, etc);Coding Bootcamp;Colleague',
#        'Books / Physical media;On the job training;Online Courses or Certification;Coding Bootcamp;Other (please specify):',
#        'Books / Physical media;Friend or family member;School (i.e., University, College, etc);On the job training;Coding Bootcamp',
#        'School (i.e., University, College, etc);On the job training;Coding Bootcamp;Colleague;Hackathons (virtual or in-person)',
#        'Books / Physical media;Friend or family member;Other online resources (e.g., videos, blogs, forum);Online Courses or Certification;Coding Bootcamp;Colleague;Hackathons (virtual or in-person)',
#        'Friend or family member;Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);Other (please specify):;Hackathons (virtual or in-person)',
#        'Books / Physical media;Friend or family member;On the job training;Online Courses or Certification;Hackathons (virtual or in-person)',
#        'Books / Physical media;Friend or family member;School (i.e., University, College, etc);Online Courses or Certification;Other (please specify):',
#        'Friend or family member;Other online resources (e.g., videos, blogs, forum);On the job training;Online Courses or Certification;Coding Bootcamp;Other (please specify):;Hackathons (virtual or in-person)',
#        'Books / Physical media;Friend or family member;Coding Bootcamp;Hackathons (virtual or in-person)',
#        'Friend or family member;Other online resources (e.g., videos, blogs, forum);Other (please specify):;Hackathons (virtual or in-person)',
#        'On the job training;Online Courses or Certification;Coding Bootcamp;Colleague;Other (please specify):',
#        'Books / Physical media;Friend or family member;Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);On the job training;Online Courses or Certification;Colleague;Other (please specify):;Hackathons (virtual or in-person)',
#        'Friend or family member;School (i.e., University, College, etc);On the job training;Hackathons (virtual or in-person)',
#        'Friend or family member;On the job training;Online Courses or Certification;Hackathons (virtual or in-person)',
#        'Books / Physical media;Friend or family member;School (i.e., University, College, etc);Coding Bootcamp;Colleague;Hackathons (virtual or in-person)',
#        'Friend or family member;On the job training;Other (please specify):',
#        'Books / Physical media;Friend or family member;Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);On the job training;Coding Bootcamp;Other (please specify):',
#        'Other online resources (e.g., videos, blogs, forum);On the job training;Online Courses or Certification;Colleague;Other (please specify):',
#        'Coding Bootcamp;Other (please specify):;Hackathons (virtual or in-person)',
#        'Books / Physical media;Friend or family member;School (i.e., University, College, etc);On the job training;Online Courses or Certification;Colleague;Other (please specify):',
#        'Books / Physical media;Coding Bootcamp;Other (please specify):',
#        'Books / Physical media;Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);Coding Bootcamp;Other (please specify):',
#        'Books / Physical media;School (i.e., University, College, etc);On the job training;Coding Bootcamp;Colleague;Hackathons (virtual or in-person)',
#        'Books / Physical media;Friend or family member;On the job training;Online Courses or Certification;Coding Bootcamp;Hackathons (virtual or in-person)',
#        'Books / Physical media;Friend or family member;Other (please specify):;Hackathons (virtual or in-person)',
#        'School (i.e., University, College, etc);Coding Bootcamp;Colleague;Other (please specify):',
#        'Friend or family member;Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);On the job training;Online Courses or Certification;Colleague;Other (please specify):;Hackathons (virtual or in-person)',
#        'Friend or family member;School (i.e., University, College, etc);On the job training;Online Courses or Certification;Other (please specify):',
#        'Books / Physical media;Friend or family member;Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);Other (please specify):;Hackathons (virtual or in-person)',
#        'Books / Physical media;Coding Bootcamp;Colleague;Hackathons (virtual or in-person)',
#        'Books / Physical media;Friend or family member;Other online resources (e.g., videos, blogs, forum);Online Courses or Certification;Coding Bootcamp;Other (please specify):',
#        'Friend or family member;Other online resources (e.g., videos, blogs, forum);On the job training;Online Courses or Certification;Colleague;Other (please specify):',
#        'Books / Physical media;Friend or family member;School (i.e., University, College, etc);Coding Bootcamp;Colleague',
#        'Books / Physical media;Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);Online Courses or Certification;Coding Bootcamp;Other (please specify):;Hackathons (virtual or in-person)',
#        'Books / Physical media;Friend or family member;Other online resources (e.g., videos, blogs, forum);Online Courses or Certification;Coding Bootcamp;Colleague;Other (please specify):;Hackathons (virtual or in-person)',
#        'Books / Physical media;Friend or family member;Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);Coding Bootcamp;Other (please specify):',
#        'Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);On the job training;Online Courses or Certification;Coding Bootcamp;Colleague;Other (please specify):;Hackathons (virtual or in-person)',
#        'Friend or family member;Other online resources (e.g., videos, blogs, forum);Online Courses or Certification;Other (please specify):;Hackathons (virtual or in-person)',
#        'Books / Physical media;Friend or family member;Other online resources (e.g., videos, blogs, forum);Colleague;Hackathons (virtual or in-person)',
#        'Books / Physical media;Friend or family member;School (i.e., University, College, etc);Coding Bootcamp;Hackathons (virtual or in-person)',
#        'Friend or family member;On the job training;Online Courses or Certification;Other (please specify):',
#        'Books / Physical media;Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);Online Courses or Certification;Coding Bootcamp;Colleague;Other (please specify):;Hackathons (virtual or in-person)',
#        'Books / Physical media;School (i.e., University, College, etc);Online Courses or Certification;Other (please specify):;Hackathons (virtual or in-person)',
#        'Books / Physical media;Friend or family member;On the job training;Coding Bootcamp;Colleague;Hackathons (virtual or in-person)',
#        'Books / Physical media;On the job training;Online Courses or Certification;Colleague;Other (please specify):',
#        'Books / Physical media;Friend or family member;School (i.e., University, College, etc);On the job training;Coding Bootcamp;Hackathons (virtual or in-person)',
#        'Friend or family member;School (i.e., University, College, etc);On the job training;Online Courses or Certification;Coding Bootcamp;Hackathons (virtual or in-person)',
#        'Friend or family member;School (i.e., University, College, etc);Coding Bootcamp;Hackathons (virtual or in-person)',
#        'Friend or family member;Other online resources (e.g., videos, blogs, forum);Online Courses or Certification;Coding Bootcamp;Other (please specify):',
#        'Friend or family member;Online Courses or Certification;Coding Bootcamp;Other (please specify):',
#        'Books / Physical media;Friend or family member;Online Courses or Certification;Other (please specify):',
#        'Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);On the job training;Online Courses or Certification;Coding Bootcamp;Other (please specify):',
#        'Books / Physical media;Other online resources (e.g., videos, blogs, forum);On the job training;Colleague;Other (please specify):;Hackathons (virtual or in-person)',
#        'Books / Physical media;Friend or family member;Coding Bootcamp;Other (please specify):',
#        'Books / Physical media;Friend or family member;Other online resources (e.g., videos, blogs, forum);On the job training;Coding Bootcamp;Colleague;Other (please specify):',
#        'Other online resources (e.g., videos, blogs, forum);On the job training;Online Courses or Certification;Coding Bootcamp;Colleague;Other (please specify):',
#        'On the job training;Other (please specify):;Hackathons (virtual or in-person)',
#        'Other online resources (e.g., videos, blogs, forum);Colleague;Other (please specify):;Hackathons (virtual or in-person)',
#        'Books / Physical media;On the job training;Coding Bootcamp;Colleague;Hackathons (virtual or in-person)',
#        'Books / Physical media;School (i.e., University, College, etc);On the job training;Coding Bootcamp;Other (please specify):',
#        'Books / Physical media;Friend or family member;Other online resources (e.g., videos, blogs, forum);On the job training;Coding Bootcamp;Colleague',
#        'Friend or family member;Other online resources (e.g., videos, blogs, forum);School (i.e., University, College, etc);Coding Bootcamp;Other (please specify):;Hackathons (virtual or in-person)',
#        'Books / Physical media;Friend or family member;On the job training;Coding Bootcamp;Hackathons (virtual or in-person)',
#        'Other online resources (e.g., videos, blogs, forum);Coding Bootcamp;Colleague;Hackathons (virtual or in-person)',
#        'Books / Physical media;Friend or family member;Other online resources (e.g., videos, blogs, forum);Online Courses or Certification;Coding Bootcamp;Other (please specify):;Hackathons (virtual or in-person)',
#        'Books / Physical media;Other online resources (e.g., videos, blogs, forum);Coding Bootcamp;Colleague;Other (please specify):',
#        'Friend or family member;School (i.e., University, College, etc);On the job training;Online Courses or Certification;Coding Bootcamp;Colleague;Hackathons (virtual or in-person)',
#        'Other online resources (e.g., videos, blogs, forum);On the job training;Coding Bootcamp;Other (please specify):'],
#       dtype=object)

# %%
df['LearnCode'] = df['LearnCode'].str.replace('Books / Physical media', 'books', regex=True)
df['LearnCode'] = df['LearnCode'].str.replace('Friend or family member', 'someone', regex=True)
df['LearnCode'] = df['LearnCode'].str.replace('Other online resources (e.g., videos, blogs, forum)', 'online', regex=True)
df['LearnCode'] = df['LearnCode'].str.replace('School (i.e., University, College, etc)', 'school', regex=True)
df['LearnCode'] = df['LearnCode'].str.replace('On the job training', 'job', regex=True)
df['LearnCode'] = df['LearnCode'].str.replace('Online Courses or Certification', 'online_course', regex=True)
df['LearnCode'] = df['LearnCode'].str.replace('Coding Bootcamp', 'bootcamp', regex=True)
df['LearnCode'] = df['LearnCode'].str.replace('Hackathons (virtual or in-person)', 'hackathon', regex=True)
df['LearnCode'] = df['LearnCode'].str.replace('Other (please specify):', 'other_', regex=True)
df['LearnCode'] = df['LearnCode'].str.lower().str.replace(', ', '_').str.replace('-', '_').str.replace(' ', '_')

# %%
df['LearnCodeOnline'].unique()
# Out:
# array([nan,
#        'Technical documentation;Blogs;Programming Games;Written Tutorials;Stack Overflow',
#        'Technical documentation;Blogs;Stack Overflow;Online books;Video-based Online Courses;Online challenges (e.g., daily or weekly coding challenges)',
#        ...,
#        'Written Tutorials;Online books;Video-based Online Courses;How-to videos;Written-based Online Courses;Coding sessions (live or recorded);Certification videos',
#        'Programming Games;Stack Overflow;Video-based Online Courses;Online challenges (e.g., daily or weekly coding challenges);How-to videos;Written-based Online Courses;Interactive tutorial;Coding sessions (live or recorded);Certification videos',
#        'Technical documentation;Programming Games;Stack Overflow;Online books;Video-based Online Courses;How-to videos;Written-based Online Courses;Coding sessions (live or recorded);Certification videos'],
#       dtype=object)

# %%
df['LearnCodeOnline'] = df['LearnCodeOnline'].str.lower().str.replace(', ', '_').str.replace('-', '_').str.replace(' ', '_')
# remove os parênteses e tudo que tem dentro
df['LearnCodeOnline'] = df['LearnCodeOnline'].str.replace(r"\(.*\)","")
# Out:
# C:\Users\nicbu\AppData\Local\Temp\ipykernel_18592\3851696651.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['LearnCodeOnline'] = df['LearnCodeOnline'].str.replace(r"\(.*\)","")

# %%
df['LearnCodeCoursesCert'].unique()
# Out:
# array([nan, 'Coursera;Udemy', 'Udemy;Codecademy', 'Coursera;Pluralsight',
#        'Coursera;Udemy;Codecademy;edX;Udacity',
#        'Coursera;Udemy;Pluralsight;edX', 'Udemy', 'Other',
#        'Coursera;Udemy;Udacity', 'Udemy;Pluralsight',
#        'Coursera;Udemy;Pluralsight', 'Codecademy', 'Coursera',
#        'Coursera;Udemy;edX', 'Udemy;Other', 'Pluralsight',
#        'Coursera;Udemy;Codecademy', 'Codecademy;Pluralsight',
#        'Coursera;edX', 'Udemy;Codecademy;Pluralsight',
#        'Pluralsight;Udacity', 'Coursera;Udemy;Other',
#        'Codecademy;Pluralsight;Other',
#        'Udemy;Codecademy;Pluralsight;Other', 'Udemy;Pluralsight;Udacity',
#        'Coursera;Udemy;Codecademy;Udacity', 'Udemy;edX',
#        'Coursera;Udemy;edX;Udacity',
#        'Coursera;Pluralsight;edX;Udacity;Other', 'edX',
#        'Coursera;Codecademy', 'Coursera;Other', 'Codecademy;Other',
#        'Udemy;Codecademy;Pluralsight;edX;Udacity', 'Coursera;Udacity',
#        'Udemy;Pluralsight;Other', 'Coursera;Codecademy;Pluralsight;edX',
#        'Coursera;Udemy;Other;Skillsoft', 'Udemy;Codecademy;Udacity;Other',
#        'Coursera;Codecademy;edX;Other', 'Codecademy;Skillsoft',
#        'Coursera;Udemy;edX;Udacity;Other',
#        'Coursera;Udemy;Codecademy;edX', 'Udemy;Codecademy;Other',
#        'Coursera;Pluralsight;edX',
#        'Coursera;Udemy;Codecademy;Pluralsight', 'Udemy;Skillsoft',
#        'Coursera;Udemy;Codecademy;Pluralsight;edX;Udacity',
#        'Pluralsight;Other', 'Udemy;Udacity', 'Coursera;Codecademy;Other',
#        'Coursera;Pluralsight;Udacity',
#        'Udemy;Codecademy;Pluralsight;Skillsoft',
#        'Udemy;Codecademy;Udacity', 'Pluralsight;edX',
#        'Coursera;Udemy;Pluralsight;edX;Udacity',
#        'Coursera;Udemy;Pluralsight;Other', 'Udemy;edX;Other',
#        'Udemy;Codecademy;Pluralsight;Udacity', 'Udacity',
#        'Coursera;Udemy;edX;Other', 'Coursera;Codecademy;edX',
#        'Coursera;Codecademy;Udacity', 'Codecademy;Pluralsight;Skillsoft',
#        'Coursera;Codecademy;Pluralsight;edX;Other', 'Coursera;edX;Other',
#        'Udemy;Codecademy;edX',
#        'Coursera;Udemy;Codecademy;edX;Udacity;Other', 'Codecademy;edX',
#        'Skillsoft', 'Udemy;Pluralsight;Skillsoft',
#        'Coursera;Codecademy;Pluralsight', 'Coursera;edX;Udacity',
#        'Coursera;edX;Udacity;Other', 'Coursera;Udemy;Pluralsight;Udacity',
#        'edX;Other', 'Udemy;Codecademy;edX;Udacity', 'Codecademy;Udacity',
#        'Coursera;Skillsoft', 'Udemy;Codecademy;Pluralsight;edX',
#        'Udemy;Codecademy;edX;Other', 'Codecademy;Udacity;Other',
#        'Coursera;Udemy;Codecademy;Skillsoft',
#        'Coursera;Codecademy;Udacity;Other',
#        'Coursera;Udemy;Pluralsight;edX;Other',
#        'Coursera;Codecademy;edX;Udacity', 'Codecademy;edX;Udacity',
#        'Codecademy;edX;Other', 'Pluralsight;Udacity;Other',
#        'Coursera;Pluralsight;Other',
#        'Coursera;Udemy;Codecademy;Pluralsight;edX',
#        'Coursera;Udemy;Codecademy;Pluralsight;Other',
#        'Coursera;Codecademy;Pluralsight;edX;Udacity;Other',
#        'Codecademy;Udacity;Skillsoft', 'Coursera;Pluralsight;Skillsoft',
#        'Udemy;Udacity;Other',
#        'Coursera;Udemy;Pluralsight;Other;Skillsoft',
#        'Coursera;Udemy;Codecademy;Pluralsight;Udacity',
#        'Coursera;Udemy;Pluralsight;Udacity;Other', 'Udacity;Other',
#        'Coursera;Udemy;Codecademy;Pluralsight;edX;Udacity;Skillsoft',
#        'Udemy;Codecademy;Pluralsight;Udacity;Other',
#        'Udemy;Pluralsight;edX', 'Coursera;Udemy;Udacity;Other',
#        'Udemy;Pluralsight;edX;Skillsoft', 'Coursera;Udacity;Other',
#        'Coursera;Udemy;Codecademy;Other', 'Coursera;Udemy;Skillsoft',
#        'Codecademy;Pluralsight;edX',
#        'Coursera;Udemy;Pluralsight;Skillsoft',
#        'Coursera;Pluralsight;edX;Other', 'Pluralsight;Skillsoft',
#        'Coursera;Pluralsight;edX;Udacity',
#        'Coursera;Udemy;Codecademy;Other;Skillsoft',
#        'Udemy;Codecademy;Pluralsight;edX;Other',
#        'Coursera;Udemy;Codecademy;Pluralsight;edX;Udacity;Other',
#        'Coursera;Udemy;Pluralsight;edX;Udacity;Skillsoft',
#        'Coursera;Udemy;Codecademy;Pluralsight;Skillsoft',
#        'Coursera;Udemy;Codecademy;Pluralsight;edX;Udacity;Other;Skillsoft',
#        'Coursera;Codecademy;Udacity;Skillsoft',
#        'Coursera;Udemy;Codecademy;Udacity;Other', 'Pluralsight;edX;Other',
#        'edX;Udacity', 'Coursera;Udemy;edX;Skillsoft',
#        'Coursera;Udemy;edX;Udacity;Skillsoft',
#        'Coursera;Codecademy;Skillsoft',
#        'Coursera;Udemy;Codecademy;Pluralsight;Udacity;Other',
#        'Coursera;Udemy;Codecademy;edX;Skillsoft',
#        'Udemy;Pluralsight;Udacity;Other',
#        'Udemy;Pluralsight;Other;Skillsoft', 'Udemy;edX;Udacity',
#        'Codecademy;Pluralsight;Udacity', 'Pluralsight;edX;Udacity',
#        'Codecademy;edX;Udacity;Other', 'Udemy;Pluralsight;edX;Udacity',
#        'Udemy;Codecademy;Skillsoft', 'Udemy;Codecademy;Other;Skillsoft',
#        'Coursera;Codecademy;Pluralsight;Other',
#        'Udemy;Pluralsight;edX;Udacity;Other',
#        'Coursera;Udemy;Codecademy;edX;Other',
#        'Codecademy;Pluralsight;Other;Skillsoft',
#        'Udemy;Codecademy;Pluralsight;Other;Skillsoft',
#        'Coursera;Codecademy;Pluralsight;Udacity', 'edX;Other;Skillsoft',
#        'Udemy;Pluralsight;edX;Other', 'Udemy;edX;Skillsoft',
#        'Codecademy;Pluralsight;Udacity;Other', 'Coursera;Other;Skillsoft',
#        'Coursera;Udemy;Pluralsight;edX;Udacity;Other', 'Other;Skillsoft',
#        'Coursera;Pluralsight;Udacity;Other',
#        'Codecademy;Pluralsight;edX;Other',
#        'Coursera;Udemy;Pluralsight;Udacity;Skillsoft',
#        'Udemy;Codecademy;edX;Skillsoft', 'edX;Skillsoft',
#        'Coursera;Udemy;Codecademy;Pluralsight;edX;Other',
#        'Udemy;edX;Udacity;Other',
#        'Coursera;Pluralsight;edX;Udacity;Skillsoft',
#        'Coursera;Udemy;Codecademy;Udacity;Skillsoft',
#        'Udemy;Codecademy;Pluralsight;Udacity;Other;Skillsoft',
#        'Coursera;Udemy;Udacity;Skillsoft',
#        'Coursera;Codecademy;Other;Skillsoft',
#        'Coursera;Udemy;Codecademy;Pluralsight;edX;Skillsoft',
#        'edX;Udacity;Other', 'Pluralsight;edX;Udacity;Other',
#        'Coursera;Udemy;Codecademy;Pluralsight;Udacity;Skillsoft',
#        'Coursera;Codecademy;edX;Udacity;Other',
#        'Udemy;Pluralsight;Udacity;Skillsoft', 'Udacity;Skillsoft',
#        'Udemy;Codecademy;edX;Udacity;Other',
#        'Coursera;Udemy;Codecademy;edX;Other;Skillsoft',
#        'Coursera;Codecademy;Pluralsight;Skillsoft',
#        'Coursera;Codecademy;Pluralsight;edX;Udacity',
#        'Udemy;Codecademy;Udacity;Skillsoft',
#        'Coursera;Codecademy;Pluralsight;edX;Skillsoft',
#        'Codecademy;edX;Udacity;Skillsoft', 'Udemy;Other;Skillsoft',
#        'Udemy;Codecademy;edX;Udacity;Skillsoft',
#        'Coursera;Udemy;Codecademy;edX;Udacity;Other;Skillsoft',
#        'Coursera;Udemy;Pluralsight;edX;Skillsoft',
#        'Coursera;Codecademy;edX;Skillsoft', 'Codecademy;edX;Skillsoft',
#        'Pluralsight;Other;Skillsoft',
#        'Coursera;Pluralsight;Udacity;Skillsoft',
#        'Coursera;Udemy;Codecademy;edX;Udacity;Skillsoft',
#        'Coursera;Pluralsight;edX;Skillsoft',
#        'Codecademy;Pluralsight;edX;Udacity;Other',
#        'Coursera;Pluralsight;edX;Other;Skillsoft',
#        'Pluralsight;edX;Other;Skillsoft',
#        'Udemy;Codecademy;Pluralsight;edX;Other;Skillsoft',
#        'Pluralsight;edX;Skillsoft',
#        'Udemy;Pluralsight;edX;Udacity;Other;Skillsoft',
#        'Coursera;Udemy;Codecademy;Pluralsight;Other;Skillsoft',
#        'Codecademy;Pluralsight;edX;Udacity', 'Udemy;Udacity;Skillsoft',
#        'Coursera;Codecademy;Pluralsight;edX;Udacity;Skillsoft',
#        'Coursera;Udemy;Pluralsight;edX;Other;Skillsoft',
#        'Coursera;edX;Skillsoft', 'Codecademy;Other;Skillsoft',
#        'Udemy;Codecademy;Pluralsight;Udacity;Skillsoft',
#        'Coursera;Codecademy;Pluralsight;Udacity;Other;Skillsoft',
#        'Udacity;Other;Skillsoft',
#        'Coursera;Codecademy;Pluralsight;Udacity;Other',
#        'Coursera;Codecademy;edX;Udacity;Skillsoft',
#        'Udemy;Codecademy;Pluralsight;edX;Udacity;Skillsoft',
#        'Udemy;Udacity;Other;Skillsoft',
#        'Coursera;Pluralsight;Other;Skillsoft'], dtype=object)

# %%
df['LearnCodeCoursesCert'] = df['LearnCodeCoursesCert'].str.lower().str.replace(', ', '_').str.replace('-', '_').str.replace(' ', '_')

# %%
df['YearsCode'].unique()
# Out:
# array([nan, '14', '20', '8', '15', '3', '1', '6', '37', '5', '12', '22',
#        '11', '4', '7', '13', '36', '2', '25', '10', '40', '16', '27',
#        '24', '19', '9', '17', '18', '26', 'More than 50 years', '29',
#        '30', '32', 'Less than 1 year', '48', '45', '38', '39', '28', '23',
#        '43', '21', '41', '35', '50', '33', '31', '34', '46', '44', '42',
#        '47', '49'], dtype=object)

# %%
df['YearsCodeNumber'] = pd.to_numeric(df['YearsCode'], errors = 'coerce').replace(np.nan, 0)
df['YearsCodeNumber'].unique()
# Out:
# array([ 0., 14., 20.,  8., 15.,  3.,  1.,  6., 37.,  5., 12., 22., 11.,
#         4.,  7., 13., 36.,  2., 25., 10., 40., 16., 27., 24., 19.,  9.,
#        17., 18., 26., 29., 30., 32., 48., 45., 38., 39., 28., 23., 43.,
#        21., 41., 35., 50., 33., 31., 34., 46., 44., 42., 47., 49.])

# %%
df['YearsCodePro'].unique()
# Out:
# array([nan, '5', '17', '3', '6', '30', '2', '10', '15', '4', '22', '20',
#        '40', '9', '14', '21', '7', '18', '25', '8', '12', '45', '1', '19',
#        '28', '24', '11', '23', 'Less than 1 year', '32', '27', '16', '44',
#        '26', '37', '46', '13', '31', '39', '34', '38', '35', '29', '42',
#        '36', '33', '43', '41', '48', '50', 'More than 50 years', '47',
#        '49'], dtype=object)

# %%
df['YearsCodeProNumber'] = pd.to_numeric(df['YearsCodePro'], errors = 'coerce').replace(np.nan, 0)
df['YearsCodeProNumber'].unique()
# Out:
# array([ 0.,  5., 17.,  3.,  6., 30.,  2., 10., 15.,  4., 22., 20., 40.,
#         9., 14., 21.,  7., 18., 25.,  8., 12., 45.,  1., 19., 28., 24.,
#        11., 23., 32., 27., 16., 44., 26., 37., 46., 13., 31., 39., 34.,
#        38., 35., 29., 42., 36., 33., 43., 41., 48., 50., 47., 49.])

# %%
df['DevType'].unique()
# Out:
# array([nan,
#        'Data scientist or machine learning specialist;Developer, front-end;Engineer, data;Engineer, site reliability',
#        'Developer, full-stack', ...,
#        'Data scientist or machine learning specialist;Developer, front-end;Developer, full-stack;Developer, back-end;Developer, QA or test;Developer, mobile;Database administrator;Cloud infrastructure engineer;Data or business analyst;Designer;Blockchain',
#        'Developer, front-end;Developer, full-stack;Developer, back-end;Developer, desktop or enterprise applications;Developer, mobile;Educator;Developer, embedded applications or devices',
#        'Developer, front-end;Engineer, data;Engineer, site reliability;Developer, full-stack;Developer, back-end;Developer, desktop or enterprise applications;Developer, QA or test;Student;Developer, mobile;Academic researcher;DevOps specialist;Developer, embedded applications or devices;Developer, game or graphics;Cloud infrastructure engineer;Data or business analyst;Designer;Scientist;Product manager;System administrator'],
#       dtype=object)

# %%
df['DevType'] = df['DevType'].str.lower().str.replace(', ', '_').str.replace('-', '_').str.replace(' ', '_')

# %%
df['OrgSize'].unique()
# Out:
# array([nan, '20 to 99 employees', '100 to 499 employees', 'I don’t know',
#        'Just me - I am a freelancer, sole proprietor, etc.',
#        '2 to 9 employees', '5,000 to 9,999 employees',
#        '1,000 to 4,999 employees', '10,000 or more employees',
#        '500 to 999 employees', '10 to 19 employees'], dtype=object)

# %% [markdown]
# Possível análise a se fazer:
# Cruzar tamanho de empresa com salário

# %%
df['OrgSize'].unique()
# Out:
# array([nan, '20 to 99 employees', '100 to 499 employees', 'I don’t know',
#        'Just me - I am a freelancer, sole proprietor, etc.',
#        '2 to 9 employees', '5,000 to 9,999 employees',
#        '1,000 to 4,999 employees', '10,000 or more employees',
#        '500 to 999 employees', '10 to 19 employees'], dtype=object)

# %%
df['PurchaseInfluence'].unique()
# Out:
# array([nan, 'I have some influence', 'I have little or no influence',
#        'I have a great deal of influence'], dtype=object)

# %%
df.drop('PurchaseInfluence', axis=1, inplace=True)

# %%
df['BuyNewTool'].unique()
# Out:
# array([nan, 'Other (please specify):',
#        'Start a free trial;Visit developer communities like Stack Overflow',
#        'Start a free trial',
#        'Start a free trial;Ask developers I know/work with;Research companies that have advertised on sites I visit',
#        'Start a free trial;Visit developer communities like Stack Overflow;Ask developers I know/work with',
#        'Start a free trial;Ask developers I know/work with',
#        'Visit developer communities like Stack Overflow',
#        'Start a free trial;Research companies that have advertised on sites I visit',
#        'Visit developer communities like Stack Overflow;Ask developers I know/work with',
#        'Other (please specify):;Start a free trial;Research companies that have advertised on sites I visit',
#        'Ask developers I know/work with',
#        'Start a free trial;Visit developer communities like Stack Overflow;Read ratings or reviews on third party sites like G2Crowd',
#        'Other (please specify):;Ask developers I know/work with',
#        'Start a free trial;Visit developer communities like Stack Overflow;Ask developers I know/work with;Read ratings or reviews on third party sites like G2Crowd',
#        'Visit developer communities like Stack Overflow;Read ratings or reviews on third party sites like G2Crowd',
#        'Start a free trial;Ask developers I know/work with;Read ratings or reviews on third party sites like G2Crowd',
#        'Start a free trial;Visit developer communities like Stack Overflow;Ask developers I know/work with;Research companies that have advertised on sites I visit;Read ratings or reviews on third party sites like G2Crowd',
#        'Visit developer communities like Stack Overflow;Ask developers I know/work with;Read ratings or reviews on third party sites like G2Crowd',
#        'Other (please specify):;Visit developer communities like Stack Overflow',
#        'Start a free trial;Visit developer communities like Stack Overflow;Research companies that have emailed me',
#        'Other (please specify):;Visit developer communities like Stack Overflow;Ask developers I know/work with;Research companies that have advertised on sites I visit',
#        'Visit developer communities like Stack Overflow;Research companies that have advertised on sites I visit;Read ratings or reviews on third party sites like G2Crowd',
#        'Start a free trial;Read ratings or reviews on third party sites like G2Crowd',
#        'Start a free trial;Visit developer communities like Stack Overflow;Research companies that have advertised on sites I visit',
#        'Other (please specify):;Start a free trial;Ask developers I know/work with',
#        'Start a free trial;Visit developer communities like Stack Overflow;Ask developers I know/work with;Research companies that have advertised on sites I visit;Read ratings or reviews on third party sites like G2Crowd;Research companies that have emailed me',
#        'Other (please specify):;Visit developer communities like Stack Overflow;Ask developers I know/work with',
#        'Ask developers I know/work with;Research companies that have advertised on sites I visit',
#        'Other (please specify):;Start a free trial;Visit developer communities like Stack Overflow;Read ratings or reviews on third party sites like G2Crowd',
#        'Other (please specify):;Start a free trial;Visit developer communities like Stack Overflow',
#        'Visit developer communities like Stack Overflow;Ask developers I know/work with;Research companies that have advertised on sites I visit;Read ratings or reviews on third party sites like G2Crowd',
#        'Other (please specify):;Start a free trial;Visit developer communities like Stack Overflow;Research companies that have advertised on sites I visit;Read ratings or reviews on third party sites like G2Crowd',
#        'Start a free trial;Visit developer communities like Stack Overflow;Research companies that have advertised on sites I visit;Read ratings or reviews on third party sites like G2Crowd',
#        'Other (please specify):;Start a free trial;Ask developers I know/work with;Read ratings or reviews on third party sites like G2Crowd',
#        'Other (please specify):;Start a free trial;Visit developer communities like Stack Overflow;Ask developers I know/work with',
#        'Start a free trial;Research companies that have advertised on sites I visit;Read ratings or reviews on third party sites like G2Crowd',
#        'Other (please specify):;Start a free trial',
#        'Start a free trial;Ask developers I know/work with;Research companies that have advertised on sites I visit;Research companies that have emailed me',
#        'Other (please specify):;Start a free trial;Visit developer communities like Stack Overflow;Ask developers I know/work with;Research companies that have advertised on sites I visit',
#        'Ask developers I know/work with;Research companies that have advertised on sites I visit;Read ratings or reviews on third party sites like G2Crowd',
#        'Start a free trial;Visit developer communities like Stack Overflow;Ask developers I know/work with;Research companies that have advertised on sites I visit;Research companies that have emailed me',
#        'Read ratings or reviews on third party sites like G2Crowd',
#        'Ask developers I know/work with;Read ratings or reviews on third party sites like G2Crowd',
#        'Start a free trial;Visit developer communities like Stack Overflow;Ask developers I know/work with;Research companies that have advertised on sites I visit',
#        'Research companies that have advertised on sites I visit',
#        'Other (please specify):;Ask developers I know/work with;Research companies that have advertised on sites I visit;Read ratings or reviews on third party sites like G2Crowd;Research companies that have emailed me',
#        'Visit developer communities like Stack Overflow;Research companies that have advertised on sites I visit',
#        'Start a free trial;Visit developer communities like Stack Overflow;Research companies that have advertised on sites I visit;Research companies that have emailed me',
#        'Visit developer communities like Stack Overflow;Ask developers I know/work with;Research companies that have advertised on sites I visit',
#        'Start a free trial;Visit developer communities like Stack Overflow;Research companies that have advertised on sites I visit;Read ratings or reviews on third party sites like G2Crowd;Research companies that have emailed me',
#        'Start a free trial;Ask developers I know/work with;Research companies that have advertised on sites I visit;Read ratings or reviews on third party sites like G2Crowd',
#        'Other (please specify):;Start a free trial;Visit developer communities like Stack Overflow;Ask developers I know/work with;Read ratings or reviews on third party sites like G2Crowd',
#        'Other (please specify):;Visit developer communities like Stack Overflow;Ask developers I know/work with;Read ratings or reviews on third party sites like G2Crowd',
#        'Other (please specify):;Start a free trial;Visit developer communities like Stack Overflow;Ask developers I know/work with;Read ratings or reviews on third party sites like G2Crowd;Research companies that have emailed me',
#        'Start a free trial;Research companies that have emailed me',
#        'Ask developers I know/work with;Research companies that have emailed me',
#        'Visit developer communities like Stack Overflow;Ask developers I know/work with;Read ratings or reviews on third party sites like G2Crowd;Research companies that have emailed me',
#        'Visit developer communities like Stack Overflow;Ask developers I know/work with;Research companies that have advertised on sites I visit;Research companies that have emailed me',
#        'Other (please specify):;Visit developer communities like Stack Overflow;Research companies that have emailed me',
#        'Start a free trial;Ask developers I know/work with;Research companies that have emailed me',
#        'Other (please specify):;Visit developer communities like Stack Overflow;Read ratings or reviews on third party sites like G2Crowd',
#        'Other (please specify):;Start a free trial;Research companies that have emailed me',
#        'Visit developer communities like Stack Overflow;Ask developers I know/work with;Research companies that have advertised on sites I visit;Read ratings or reviews on third party sites like G2Crowd;Research companies that have emailed me',
#        'Other (please specify):;Start a free trial;Ask developers I know/work with;Research companies that have advertised on sites I visit',
#        'Start a free trial;Visit developer communities like Stack Overflow;Ask developers I know/work with;Research companies that have emailed me',
#        'Other (please specify):;Start a free trial;Visit developer communities like Stack Overflow;Ask developers I know/work with;Research companies that have advertised on sites I visit;Read ratings or reviews on third party sites like G2Crowd',
#        'Visit developer communities like Stack Overflow;Ask developers I know/work with;Research companies that have emailed me',
#        'Start a free trial;Visit developer communities like Stack Overflow;Read ratings or reviews on third party sites like G2Crowd;Research companies that have emailed me',
#        'Start a free trial;Ask developers I know/work with;Read ratings or reviews on third party sites like G2Crowd;Research companies that have emailed me',
#        'Research companies that have emailed me',
#        'Other (please specify):;Ask developers I know/work with;Read ratings or reviews on third party sites like G2Crowd',
#        'Start a free trial;Visit developer communities like Stack Overflow;Ask developers I know/work with;Read ratings or reviews on third party sites like G2Crowd;Research companies that have emailed me',
#        'Research companies that have advertised on sites I visit;Read ratings or reviews on third party sites like G2Crowd',
#        'Ask developers I know/work with;Read ratings or reviews on third party sites like G2Crowd;Research companies that have emailed me',
#        'Visit developer communities like Stack Overflow;Research companies that have advertised on sites I visit;Research companies that have emailed me',
#        'Ask developers I know/work with;Research companies that have advertised on sites I visit;Research companies that have emailed me',
#        'Research companies that have advertised on sites I visit;Research companies that have emailed me',
#        'Other (please specify):;Start a free trial;Ask developers I know/work with;Research companies that have emailed me',
#        'Start a free trial;Research companies that have advertised on sites I visit;Research companies that have emailed me',
#        'Other (please specify):;Visit developer communities like Stack Overflow;Research companies that have advertised on sites I visit;Read ratings or reviews on third party sites like G2Crowd',
#        'Other (please specify):;Visit developer communities like Stack Overflow;Ask developers I know/work with;Research companies that have advertised on sites I visit;Read ratings or reviews on third party sites like G2Crowd',
#        'Visit developer communities like Stack Overflow;Research companies that have advertised on sites I visit;Read ratings or reviews on third party sites like G2Crowd;Research companies that have emailed me',
#        'Other (please specify):;Ask developers I know/work with;Research companies that have advertised on sites I visit',
#        'Other (please specify):;Start a free trial;Read ratings or reviews on third party sites like G2Crowd',
#        'Other (please specify):;Start a free trial;Ask developers I know/work with;Research companies that have advertised on sites I visit;Research companies that have emailed me',
#        'Visit developer communities like Stack Overflow;Research companies that have emailed me',
#        'Other (please specify):;Start a free trial;Visit developer communities like Stack Overflow;Research companies that have advertised on sites I visit',
#        'Start a free trial;Ask developers I know/work with;Research companies that have advertised on sites I visit;Read ratings or reviews on third party sites like G2Crowd;Research companies that have emailed me',
#        'Start a free trial;Read ratings or reviews on third party sites like G2Crowd;Research companies that have emailed me',
#        'Other (please specify):;Start a free trial;Visit developer communities like Stack Overflow;Ask developers I know/work with;Research companies that have advertised on sites I visit;Read ratings or reviews on third party sites like G2Crowd;Research companies that have emailed me',
#        'Start a free trial;Research companies that have advertised on sites I visit;Read ratings or reviews on third party sites like G2Crowd;Research companies that have emailed me',
#        'Other (please specify):;Start a free trial;Visit developer communities like Stack Overflow;Research companies that have advertised on sites I visit;Research companies that have emailed me',
#        'Other (please specify):;Visit developer communities like Stack Overflow;Research companies that have advertised on sites I visit',
#        'Other (please specify):;Start a free trial;Research companies that have advertised on sites I visit;Read ratings or reviews on third party sites like G2Crowd',
#        'Other (please specify):;Ask developers I know/work with;Research companies that have emailed me',
#        'Other (please specify):;Start a free trial;Visit developer communities like Stack Overflow;Ask developers I know/work with;Research companies that have advertised on sites I visit;Research companies that have emailed me',
#        'Other (please specify):;Read ratings or reviews on third party sites like G2Crowd',
#        'Visit developer communities like Stack Overflow;Read ratings or reviews on third party sites like G2Crowd;Research companies that have emailed me',
#        'Other (please specify):;Visit developer communities like Stack Overflow;Research companies that have advertised on sites I visit;Research companies that have emailed me',
#        'Other (please specify):;Start a free trial;Visit developer communities like Stack Overflow;Read ratings or reviews on third party sites like G2Crowd;Research companies that have emailed me',
#        'Other (please specify):;Start a free trial;Ask developers I know/work with;Research companies that have advertised on sites I visit;Read ratings or reviews on third party sites like G2Crowd',
#        'Ask developers I know/work with;Research companies that have advertised on sites I visit;Read ratings or reviews on third party sites like G2Crowd;Research companies that have emailed me',
#        'Other (please specify):;Research companies that have advertised on sites I visit;Read ratings or reviews on third party sites like G2Crowd;Research companies that have emailed me',
#        'Other (please specify):;Start a free trial;Visit developer communities like Stack Overflow;Ask developers I know/work with;Research companies that have emailed me',
#        'Read ratings or reviews on third party sites like G2Crowd;Research companies that have emailed me',
#        'Other (please specify):;Visit developer communities like Stack Overflow;Read ratings or reviews on third party sites like G2Crowd;Research companies that have emailed me',
#        'Other (please specify):;Research companies that have advertised on sites I visit;Read ratings or reviews on third party sites like G2Crowd',
#        'Other (please specify):;Research companies that have advertised on sites I visit',
#        'Other (please specify):;Visit developer communities like Stack Overflow;Ask developers I know/work with;Research companies that have advertised on sites I visit;Read ratings or reviews on third party sites like G2Crowd;Research companies that have emailed me',
#        'Other (please specify):;Research companies that have advertised on sites I visit;Research companies that have emailed me',
#        'Other (please specify):;Visit developer communities like Stack Overflow;Research companies that have advertised on sites I visit;Read ratings or reviews on third party sites like G2Crowd;Research companies that have emailed me',
#        'Other (please specify):;Start a free trial;Visit developer communities like Stack Overflow;Research companies that have emailed me',
#        'Research companies that have advertised on sites I visit;Read ratings or reviews on third party sites like G2Crowd;Research companies that have emailed me',
#        'Other (please specify):;Start a free trial;Read ratings or reviews on third party sites like G2Crowd;Research companies that have emailed me',
#        'Other (please specify):;Visit developer communities like Stack Overflow;Ask developers I know/work with;Read ratings or reviews on third party sites like G2Crowd;Research companies that have emailed me',
#        'Other (please specify):;Research companies that have emailed me',
#        'Other (please specify):;Start a free trial;Visit developer communities like Stack Overflow;Research companies that have advertised on sites I visit;Read ratings or reviews on third party sites like G2Crowd;Research companies that have emailed me',
#        'Other (please specify):;Start a free trial;Ask developers I know/work with;Research companies that have advertised on sites I visit;Read ratings or reviews on third party sites like G2Crowd;Research companies that have emailed me',
#        'Other (please specify):;Ask developers I know/work with;Read ratings or reviews on third party sites like G2Crowd;Research companies that have emailed me',
#        'Other (please specify):;Visit developer communities like Stack Overflow;Ask developers I know/work with;Research companies that have emailed me',
#        'Other (please specify):;Visit developer communities like Stack Overflow;Ask developers I know/work with;Research companies that have advertised on sites I visit;Research companies that have emailed me',
#        'Other (please specify):;Start a free trial;Research companies that have advertised on sites I visit;Research companies that have emailed me',
#        'Other (please specify):;Ask developers I know/work with;Research companies that have advertised on sites I visit;Research companies that have emailed me',
#        'Other (please specify):;Start a free trial;Ask developers I know/work with;Read ratings or reviews on third party sites like G2Crowd;Research companies that have emailed me',
#        'Other (please specify):;Ask developers I know/work with;Research companies that have advertised on sites I visit;Read ratings or reviews on third party sites like G2Crowd'],
#       dtype=object)

# %%
df.drop('BuyNewTool', axis=1, inplace=True)

# %%
df['Country'].unique()
# Out:
# array([nan, 'Canada',
#        'United Kingdom of Great Britain and Northern Ireland', 'Israel',
#        'United States of America', 'Germany', 'India', 'Netherlands',
#        'Croatia', 'Australia', 'Russian Federation', 'Czech Republic',
#        'Austria', 'Serbia', 'Italy', 'Ireland', 'Poland', 'Slovenia',
#        'Iraq', 'Sweden', 'Madagascar', 'Norway', 'Taiwan',
#        'Hong Kong (S.A.R.)', 'Mexico', 'France', 'Brazil', 'Lithuania',
#        'Uruguay', 'Denmark', 'Spain', 'Egypt', 'Turkey', 'South Africa',
#        'Ukraine', 'Finland', 'Romania', 'Portugal', 'Singapore', 'Oman',
#        'Belgium', 'Chile', 'Bulgaria', 'Latvia', 'Philippines', 'Greece',
#        'Belarus', 'Saudi Arabia', 'Kenya', 'Switzerland', 'Iceland',
#        'Viet Nam', 'Thailand', 'China', 'Montenegro', 'Slovakia', 'Japan',
#        'Luxembourg', 'Turkmenistan', 'Argentina', 'Hungary', 'Tunisia',
#        'Bangladesh', 'Maldives', 'Dominican Republic', 'Jordan',
#        'Pakistan', 'Nepal', 'Iran, Islamic Republic of...', 'Indonesia',
#        'Ecuador', 'Bosnia and Herzegovina', 'Armenia', 'Colombia',
#        'Kazakhstan', 'South Korea', 'Costa Rica', 'Honduras', 'Mauritius',
#        'Estonia', 'Algeria', 'Trinidad and Tobago', 'Mali', 'Morocco',
#        'Swaziland', 'New Zealand',
#        'The former Yugoslav Republic of Macedonia', 'Afghanistan',
#        'Cyprus', 'United Arab Emirates', 'Peru', 'Uzbekistan', 'Ethiopia',
#        'Bahrain', 'Malta', 'Nicaragua', 'Andorra', 'Republic of Korea',
#        'Lebanon', 'Belize', 'Zambia', 'Bolivia', 'Malaysia', 'Sri Lanka',
#        "Lao People's Democratic Republic", 'Guatemala', 'Azerbaijan',
#        'Suriname', 'El Salvador', 'Syrian Arab Republic', 'Qatar',
#        'Nigeria', 'Kyrgyzstan', 'Zimbabwe', 'Rwanda', 'Georgia',
#        'Cambodia', 'Malawi', 'Yemen', 'Fiji', 'Nomadic', 'Uganda',
#        'Albania', 'Timor-Leste', 'Mongolia', 'Republic of Moldova',
#        'Tajikistan', 'Ghana', 'United Republic of Tanzania', 'Myanmar',
#        'Kuwait', 'Cameroon', 'Kosovo', 'Jamaica', 'Benin', 'Botswana',
#        'Niger', 'Palestine', 'Cape Verde', 'Libyan Arab Jamahiriya',
#        'Venezuela, Bolivarian Republic of...', 'Senegal', 'Cuba', 'Togo',
#        'Angola', 'Isle of Man', 'Panama', 'Bahamas', 'Paraguay', 'Sudan',
#        'Liberia', 'Bhutan', 'Democratic Republic of the Congo',
#        "Côte d'Ivoire", 'Barbados', 'Congo, Republic of the...',
#        'Namibia', 'Somalia', 'Sierra Leone', 'Mozambique', 'Lesotho',
#        'Chad', 'North Korea', 'Antigua and Barbuda', 'Papua New Guinea',
#        'Palau', 'Guinea', 'Haiti', 'Gabon', 'Mauritania', 'San Marino',
#        'Guyana', 'Saint Lucia', 'Burkina Faso', 'Brunei Darussalam',
#        'Gambia', 'Monaco', 'Djibouti', 'Seychelles', 'Solomon Islands',
#        'Saint Kitts and Nevis'], dtype=object)

# %%
df['Country'] = df['Country'].str.lower().str.replace(', ', '_').str.replace('-', '_').str.replace(' ', '_')
# remove os parênteses e tudo que tem dentro
df['Country'] = df['Country'].str.replace(r"\(.*\)","")
# Out:
# C:\Users\nicbu\AppData\Local\Temp\ipykernel_18592\139146218.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Country'] = df['Country'].str.replace(r"\(.*\)","")

# %%
df['Currency'].unique()
# Out:
# array([nan, 'CAD\tCanadian dollar', 'GBP\tPound sterling',
#        'ILS\tIsraeli new shekel', 'USD\tUnited States dollar',
#        'EUR European Euro', 'HRK\tCroatian kuna',
#        'AUD\tAustralian dollar', 'RUB\tRussian ruble',
#        'CZK\tCzech koruna', 'PLN\tPolish zloty', 'NOK\tNorwegian krone',
#        'TWD\tNew Taiwan dollar', 'HKD\tHong Kong dollar',
#        'INR\tIndian rupee', 'BRL\tBrazilian real', 'UYU\tUruguayan peso',
#        'RSD\tSerbian dinar', 'SEK\tSwedish krona', 'DKK\tDanish krone',
#        'EGP\tEgyptian pound', 'TRY\tTurkish lira', 'RON\tRomanian leu',
#        'SGD\tSingapore dollar', 'SAR\tSaudi Arabian riyal',
#        'BGN\tBulgarian lev', 'BYN\tBelarusian ruble',
#        'KES\tKenyan shilling', 'CHF\tSwiss franc',
#        'ZAR\tSouth African rand', 'ISK\tIcelandic krona',
#        'THB\tThai baht', 'CNY\tChinese Yuan Renminbi',
#        'VND\tVietnamese dong', 'ARS\tArgentine peso',
#        'HUF\tHungarian forint', 'TND\tTunisian dinar',
#        'BDT\tBangladeshi taka', 'MVR\tMaldivian rufiyaa',
#        'CLP\tChilean peso', 'MXN\tMexican peso', 'PKR\tPakistani rupee',
#        'NPR\tNepalese rupee', 'IDR\tIndonesian rupiah',
#        'UAH\tUkrainian hryvnia',
#        'BAM\tBosnia and Herzegovina convertible mark', 'IMP\tManx pound',
#        'IRR\tIranian rial', 'CRC\tCosta Rican colon',
#        'MUR\tMauritian rupee', 'KZT\tKazakhstani tenge',
#        'XOF\tWest African CFA franc', 'MAD\tMoroccan dirham',
#        'PHP\tPhilippine peso', 'AMD\tArmenian dram',
#        'NZD\tNew Zealand dollar', 'AED United Arab Emirates dirham',
#        'JPY\tJapanese yen', 'PEN\tPeruvian sol', 'COP\tColombian peso',
#        'GIP\tGibraltar pound', 'DOP\tDominican peso',
#        'AFN\tAfghan afghani', 'KRW\tSouth Korean won',
#        'LBP\tLebanese pound', 'MYR\tMalaysian ringgit',
#        'GTQ\tGuatemalan quetzal', 'AZN\tAzerbaijan manat',
#        'LKR\tSri Lankan rupee', 'UZS\tUzbekistani som',
#        'QAR\tQatari riyal', 'NGN\tNigerian naira', 'MGA\tMalagasy ariary',
#        'ETB\tEthiopian birr', 'MKD\tMacedonian denar',
#        'KHR\tCambodian riel', 'JOD\tJordanian dinar', 'YER\tYemeni rial',
#        'ANG Netherlands Antillean guilder', 'FJD\tFijian dollar',
#        'PGK\tPapua New Guinean kina', 'UGX\tUgandan shilling',
#        'MNT\tMongolian tugrik', 'DZD\tAlgerian dinar',
#        'TJS\tTajikistani somoni', 'GHS\tGhanaian cedi',
#        'TZS\tTanzanian shilling', 'MDL\tMoldovan leu',
#        'XAF\tCentral African CFA franc', 'TMT\tTurkmen manat',
#        'BWP\tBotswana pula', 'ALL\tAlbanian lek', 'MMK\tMyanmar kyat',
#        'GEL\tGeorgian lari', 'BHD\tBahraini dinar', 'KWD\tKuwaiti dinar',
#        'CVE\tCape Verdean escudo', 'LYD\tLibyan dinar',
#        'RWF\tRwandan franc', 'BMD\tBermudian dollar',
#        'BOB\tBolivian boliviano', 'KYD\tCayman Islands dollar',
#        'VES\tVenezuelan bolivar', 'HNL\tHonduran lempira',
#        'PYG\tParaguayan guarani', 'SYP\tSyrian pound', 'CUP\tCuban peso',
#        'BTN\tBhutanese ngultrum', 'BZD\tBelize dollar',
#        'JMD\tJamaican dollar', 'BBD\tBarbadian dollar',
#        'NIO\tNicaraguan cordoba', 'ZMW Zambian kwacha',
#        'KGS\tKyrgyzstani som', 'IQD\tIraqi dinar', 'BIF\tBurundi franc',
#        'LAK\tLao kip', 'MZN\tMozambican metical', 'AOA\tAngolan kwanza',
#        'AWG\tAruban florin', 'OMR\tOmani rial', 'SDG\tSudanese pound',
#        'SHP\tSaint Helena pound', 'DJF\tDjiboutian franc',
#        'SCR\tSeychellois rupee', 'SZL\tSwazi lilangeni',
#        'GNF\tGuinean franc', 'TTD\tTrinidad and Tobago dollar',
#        'BND\tBrunei dollar', 'SLL\tSierra Leonean leone',
#        'NAD\tNamibian dollar', 'HTG\tHaitian gourde',
#        'MWK\tMalawian kwacha', 'GYD\tGuyanese dollar',
#        'none\tCook Islands dollar', 'XPF\tCFP franc',
#        'CDF\tCongolese franc', 'SOS\tSomali shilling',
#        'XDR\tSDR (Special Drawing Right)', 'XCD\tEast Caribbean dollar',
#        'SBD\tSolomon Islands dollar', 'JEP\tJersey pound',
#        'TOP\tTongan pa’anga'], dtype=object)

# %%
# limpa a moeda para ficar apenas o código de 3 letras dela
df['Currency'] = df['Currency'].str.replace(r"[(\t)\s].*","")
# Out:
# C:\Users\nicbu\AppData\Local\Temp\ipykernel_18592\3244471054.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Currency'] = df['Currency'].str.replace(r"[(\t)\s].*","")

# %%
df['CompTotal'].unique()
# Out:
# array([     nan,   32000.,   60000., ..., 1038000.,   64200.,  439000.])

# %%
df.rename(columns={'CompTotal': 'GrossWage', 'CompFreq': 'WageFreq'}, inplace=True)

# %%
df['WageFreq'].unique()
# Out:
# array([nan, 'Yearly', 'Monthly', 'Weekly'], dtype=object)

# %% [markdown]
# **Prestar atenção no campo a seguir (renomeado para YearlyWageInDollar)**. Ele já traz os valores de salário convertidos na mesma moeda e mesma frequência. Talvez seja interessante tirar dados sobre os salários em diferentes frequências se tem alguma correlação.

# %%
df.rename(columns={'ConvertedCompYearly': 'YearlyWageInDollar'}, inplace=True)

# %% [markdown]
# Aqui termina a limpeza da primeira seção do formulário
#
# -----

# %% [markdown]
# ## Segunda seção
#
# Questões 19 a 32

# %%
df['LanguageHaveWorkedWith'].unique()
# Out:
# array([nan, 'JavaScript;TypeScript', 'C#;C++;HTML/CSS;JavaScript;Python',
#        ..., 'Assembly;C;C++;Java;TypeScript',
#        'Bash/Shell;Dart;JavaScript;PHP;Python;SQL;TypeScript',
#        'C#;JavaScript;Lua;PowerShell;SQL;TypeScript'], dtype=object)

# %%
df['DatabaseHaveWorkedWith'].unique()
# Out:
# array([nan, 'Microsoft SQL Server',
#        'Cloud Firestore;Elasticsearch;Microsoft SQL Server;Firebase Realtime Database',
#        ...,
#        'Cassandra;Cloud Firestore;Elasticsearch;MongoDB;PostgreSQL;SQLite',
#        'Elasticsearch;MongoDB;Oracle;SQLite',
#        'Microsoft SQL Server;Neo4j;Redis'], dtype=object)

# %%
df['PlatformHaveWorkedWith'].unique()
# Out:
# array([nan, 'Firebase;Microsoft Azure', 'AWS;Google Cloud;Heroku', ...,
#        'AWS;DigitalOcean;Google Cloud;Heroku;OpenStack',
#        'IBM Cloud or Watson;Linode;VMware',
#        'Colocation;DigitalOcean;Heroku;Linode;Oracle Cloud Infrastructure;OVH'],
#       dtype=object)

# %%
df['WebframeHaveWorkedWith'].unique()
# Out:
# array([nan, 'Angular.js', 'ASP.NET;ASP.NET Core ', ...,
#        'Angular;ASP.NET;ASP.NET Core ;Blazor;Django;Drupal;Express;Flask;jQuery;Laravel',
#        'Express;FastAPI;Flask;Laravel;Next.js;Node.js;React.js;Symfony;Vue.js',
#        'Angular.js;Express;jQuery;Next.js;Node.js;Play Framework;React.js'],
#       dtype=object)

# %%
df['MiscTechHaveWorkedWith'].unique()
# Out:
# array([nan, 'Pandas', '.NET', ...,
#        'Apache Spark;Hadoop;Keras;NumPy;Pandas',
#        '.NET;Apache Kafka;NumPy;Spring',
#        'Apache Kafka;Flutter;Hadoop;Keras;NumPy;Pandas;Scikit-learn;TensorFlow;Torch/PyTorch'],
#       dtype=object)

# %%
df['ToolsTechHaveWorkedWith'].unique()
# Out:
# array([nan, 'npm', 'Homebrew', 'Homebrew;npm', 'Docker;npm;Terraform',
#        'Docker;Homebrew;Kubernetes', 'Docker', 'Docker;Homebrew;npm;Yarn',
#        'Docker;npm;Yarn', 'Docker;npm', 'Docker;Kubernetes',
#        'Docker;Kubernetes;npm;Terraform;Yarn', 'Kubernetes;npm;Terraform',
#        'Docker;Kubernetes;npm', 'Ansible;Docker;npm;Terraform',
#        'Ansible;Docker;Terraform', 'npm;Yarn',
#        'Docker;Homebrew;Kubernetes;npm;Yarn', 'Ansible;Docker;npm',
#        'Docker;Homebrew;Unity 3D',
#        'Ansible;Docker;Homebrew;Kubernetes;npm;Puppet;Terraform',
#        'Ansible;Docker;Homebrew;Kubernetes;Terraform',
#        'Docker;Flow;Kubernetes;npm;Unity 3D', 'Docker;Homebrew',
#        'Ansible;Docker;Kubernetes;npm;Terraform;Unity 3D;Unreal Engine;Yarn',
#        'Docker;Puppet', 'Docker;Homebrew;npm', 'Unity 3D',
#        'Docker;Kubernetes;Puppet', 'Docker;Kubernetes;npm;Yarn',
#        'Docker;npm;Terraform;Yarn', 'Docker;Yarn',
#        'Ansible;Docker;Kubernetes', 'Docker;Terraform',
#        'Ansible;Docker;Kubernetes;npm;Terraform;Yarn', 'Kubernetes;npm',
#        'Docker;Homebrew;Yarn', 'Ansible;Chef;Docker;Terraform',
#        'Ansible;Docker;Kubernetes;npm', 'Docker;Homebrew;Terraform',
#        'Docker;Kubernetes;Yarn', 'Kubernetes;Terraform',
#        'Chef;Docker;npm', 'Yarn', 'Chef;Homebrew;Kubernetes',
#        'npm;Terraform', 'Docker;Homebrew;Kubernetes;npm;Puppet',
#        'Docker;Unreal Engine', 'Ansible;Kubernetes', 'Ansible;Docker',
#        'Docker;Homebrew;Kubernetes;npm;Terraform', 'Docker;Unity 3D',
#        'Docker;Kubernetes;Terraform', 'Docker;Homebrew;Kubernetes;npm',
#        'Docker;Homebrew;npm;Unity 3D',
#        'Docker;Homebrew;npm;Pulumi;Terraform;Unreal Engine',
#        'Homebrew;npm;Yarn', 'Docker;Pulumi', 'Ansible;Unity 3D',
#        'Ansible;Docker;Kubernetes;Terraform', 'Kubernetes',
#        'Kubernetes;Yarn', 'Terraform',
#        'Docker;Kubernetes;npm;Terraform;Unity 3D',
#        'Ansible;Docker;Kubernetes;Terraform;Yarn',
#        'Docker;Homebrew;Kubernetes;npm;Terraform;Yarn',
#        'Docker;Homebrew;Kubernetes;Terraform',
#        'Docker;Kubernetes;Terraform;Unity 3D', 'Docker;npm;Unity 3D',
#        'Docker;Kubernetes;npm;Unity 3D', 'Docker;Terraform;Unity 3D',
#        'Ansible;Docker;Homebrew', 'Homebrew;Terraform',
#        'Docker;Kubernetes;Unity 3D', 'Chef;Docker;Kubernetes;Terraform',
#        'Docker;Homebrew;Kubernetes;npm;Unreal Engine',
#        'Docker;Kubernetes;npm;Puppet;Terraform', 'Ansible;Docker;Puppet',
#        'npm;Terraform;Yarn', 'Ansible;Docker;Homebrew;npm;Terraform',
#        'Docker;Kubernetes;npm;Terraform', 'Ansible;npm',
#        'Docker;Homebrew;npm;Terraform;Yarn',
#        'Docker;Homebrew;Kubernetes;Yarn', 'npm;Puppet',
#        'Docker;Kubernetes;npm;Terraform;Unity 3D;Unreal Engine',
#        'Ansible', 'Ansible;Docker;Kubernetes;npm;Yarn',
#        'Docker;Kubernetes;npm;Unreal Engine',
#        'npm;Unity 3D;Unreal Engine',
#        'Docker;npm;Unity 3D;Unreal Engine;Yarn',
#        'Ansible;Docker;Kubernetes;npm;Unity 3D',
#        'Docker;npm;Unity 3D;Unreal Engine', 'Puppet',
#        'Ansible;Docker;Homebrew;npm', 'Ansible;Docker;npm;Terraform;Yarn',
#        'Docker;npm;Unreal Engine',
#        'Ansible;Docker;Homebrew;Kubernetes;npm',
#        'Docker;Homebrew;npm;Unity 3D;Yarn', 'Chef;Docker;Homebrew;npm',
#        'npm;Unity 3D', 'Homebrew;Yarn', 'Ansible;Docker;Homebrew;Yarn',
#        'Ansible;Chef;Docker;Kubernetes;npm;Terraform',
#        'Docker;npm;Unity 3D;Yarn', 'Docker;Kubernetes;npm;Pulumi;Yarn',
#        'Homebrew;Kubernetes', 'npm;Unity 3D;Yarn',
#        'Docker;npm;Puppet;Unity 3D;Unreal Engine;Yarn', 'Unreal Engine',
#        'Docker;Homebrew;npm;Terraform', 'Ansible;Homebrew;npm;Terraform',
#        'Ansible;Docker;npm;Yarn', 'Ansible;Docker;Kubernetes;Puppet',
#        'Docker;Homebrew;Kubernetes;Pulumi;Terraform',
#        'Ansible;Docker;Homebrew;Terraform;Yarn',
#        'Ansible;Docker;Homebrew;npm;Yarn',
#        'Docker;npm;Puppet;Terraform;Yarn',
#        'Ansible;Chef;Docker;Homebrew;Kubernetes;npm',
#        'Docker;Kubernetes;npm;Puppet',
#        'Ansible;Chef;Docker;Kubernetes;Terraform',
#        'Ansible;Chef;Docker;Homebrew;npm',
#        'Docker;Unity 3D;Unreal Engine',
#        'Ansible;Docker;Kubernetes;npm;Puppet',
#        'Ansible;Docker;Homebrew;Kubernetes;npm;Puppet;Terraform;Yarn',
#        'Docker;Flow;Homebrew;Kubernetes;npm;Yarn',
#        'Ansible;Chef;Docker;Homebrew;Kubernetes;npm;Terraform;Yarn',
#        'Docker;Homebrew;Kubernetes;npm;Pulumi;Terraform',
#        'Docker;Kubernetes;Unreal Engine', 'Homebrew;npm;Unity 3D;Yarn',
#        'Ansible;Docker;Kubernetes;npm;Terraform',
#        'Ansible;Docker;Kubernetes;npm;Puppet;Yarn',
#        'Ansible;Docker;Kubernetes;Pulumi;Terraform',
#        'Kubernetes;npm;Yarn', 'Unity 3D;Unreal Engine',
#        'Ansible;Kubernetes;Terraform', 'Docker;npm;Pulumi',
#        'Ansible;Docker;Homebrew;Kubernetes;npm;Pulumi;Terraform;Yarn',
#        'Docker;Unity 3D;Unreal Engine;Yarn',
#        'Kubernetes;Pulumi;Unity 3D;Yarn',
#        'Docker;Homebrew;npm;Unreal Engine',
#        'npm;Unity 3D;Unreal Engine;Yarn',
#        'Ansible;Docker;Homebrew;Kubernetes;npm;Terraform',
#        'Ansible;Docker;Kubernetes;npm;Pulumi;Terraform;Yarn',
#        'Ansible;Docker;Homebrew;Kubernetes', 'Docker;Homebrew;npm;Puppet',
#        'Ansible;npm;Yarn', 'Docker;npm;Terraform;Unity 3D',
#        'Chef;Docker;Kubernetes', 'Ansible;Homebrew;npm',
#        'Ansible;Docker;Homebrew;Kubernetes;npm;Puppet',
#        'Docker;Homebrew;Kubernetes;Unity 3D;Unreal Engine',
#        'Ansible;Docker;Unity 3D', 'Chef;npm',
#        'Docker;Homebrew;Kubernetes;Terraform;Yarn',
#        'Ansible;Docker;Homebrew;npm;Terraform;Yarn',
#        'Docker;Homebrew;npm;Pulumi', 'Homebrew;Unreal Engine',
#        'Ansible;Docker;Terraform;Unity 3D;Yarn',
#        'Chef;Docker;Homebrew;Kubernetes;npm;Terraform;Yarn',
#        'Ansible;Docker;npm;Unity 3D', 'Kubernetes;npm;Pulumi;Terraform',
#        'Docker;npm;Terraform;Unity 3D;Unreal Engine',
#        'npm;Terraform;Unity 3D;Unreal Engine',
#        'Ansible;Docker;Homebrew;Terraform',
#        'Ansible;Docker;Homebrew;Kubernetes;Yarn',
#        'Docker;Homebrew;npm;Puppet;Terraform;Unity 3D',
#        'Homebrew;npm;Terraform', 'Homebrew;Kubernetes;Terraform',
#        'Flow;npm;Yarn', 'Ansible;Docker;Homebrew;Kubernetes;npm;Yarn',
#        'Docker;Homebrew;npm;Unity 3D;Unreal Engine',
#        'Docker;Homebrew;Kubernetes;npm;Unity 3D',
#        'Ansible;Docker;Homebrew;Kubernetes;npm;Terraform;Yarn',
#        'Homebrew;Unity 3D', 'Chef;Homebrew',
#        'Ansible;Chef;Docker;Homebrew;Terraform;Yarn',
#        'Docker;npm;Puppet;Unreal Engine;Yarn',
#        'Ansible;Docker;npm;Terraform;Unity 3D;Yarn', 'npm;Unreal Engine',
#        'npm;Puppet;Yarn', 'Docker;Homebrew;Kubernetes;npm;Pulumi;Yarn',
#        'Ansible;Chef;Docker;Terraform;Unity 3D',
#        'Terraform;Unity 3D;Unreal Engine',
#        'Ansible;Chef;Docker;Homebrew;Kubernetes;npm;Puppet;Terraform;Unity 3D;Yarn',
#        'Docker;Unity 3D;Yarn', 'Docker;Kubernetes;Puppet;Terraform',
#        'Homebrew;npm;Terraform;Yarn', 'Homebrew;Kubernetes;npm;Terraform',
#        'Homebrew;npm;Unity 3D;Unreal Engine;Yarn',
#        'Docker;npm;Unreal Engine;Yarn',
#        'Kubernetes;Terraform;Unity 3D;Unreal Engine',
#        'Chef;Docker;Homebrew;npm;Puppet;Unity 3D;Unreal Engine;Yarn',
#        'Ansible;Chef;Docker;npm;Pulumi',
#        'Docker;Kubernetes;Pulumi;Terraform',
#        'Docker;Kubernetes;npm;Unity 3D;Unreal Engine;Yarn',
#        'Homebrew;Kubernetes;npm', 'Chef;Docker;Kubernetes;Yarn',
#        'Docker;Homebrew;Terraform;Unity 3D;Unreal Engine', 'Chef',
#        'Docker;Flow;npm', 'Docker;Pulumi;Terraform', 'Docker;Flow;Yarn',
#        'Ansible;Docker;Homebrew;Kubernetes;Pulumi;Yarn',
#        'Chef;Docker;Homebrew;npm;Terraform;Yarn',
#        'Docker;Homebrew;Kubernetes;Unity 3D',
#        'Docker;Homebrew;Kubernetes;npm;Unity 3D;Unreal Engine;Yarn',
#        'Docker;Homebrew;Unity 3D;Unreal Engine',
#        'Docker;Kubernetes;Terraform;Yarn', 'Kubernetes;Unreal Engine',
#        'Ansible;Docker;Kubernetes;Yarn',
#        'Docker;Homebrew;Kubernetes;Pulumi', 'Ansible;Homebrew;Yarn',
#        'Docker;Flow;Kubernetes;npm;Terraform',
#        'Ansible;Docker;Homebrew;Kubernetes;Puppet',
#        'Ansible;Homebrew;Kubernetes;Terraform',
#        'Flow;Homebrew;Kubernetes;npm', 'Docker;npm;Pulumi;Yarn',
#        'Docker;Homebrew;Kubernetes;npm;Pulumi;Terraform;Unreal Engine',
#        'Docker;npm;Puppet;Yarn',
#        'Docker;Homebrew;Kubernetes;npm;Puppet;Terraform',
#        'Docker;Kubernetes;npm;Terraform;Unity 3D;Yarn',
#        'Docker;npm;Terraform;Unreal Engine;Yarn',
#        'Docker;Homebrew;Kubernetes;Puppet;Yarn',
#        'Flow;Homebrew;Kubernetes;npm;Unity 3D', 'Kubernetes;Puppet',
#        'Docker;Homebrew;npm;Pulumi;Terraform;Yarn',
#        'Ansible;Docker;Puppet;Unity 3D;Unreal Engine',
#        'Chef;Docker;Kubernetes;npm;Puppet', 'Homebrew;npm;Unity 3D',
#        'Chef;Docker;Kubernetes;npm;Terraform',
#        'Chef;Docker;Homebrew;npm;Terraform',
#        'Ansible;Kubernetes;npm;Puppet;Yarn',
#        'Ansible;Chef;Docker;Flow;Homebrew;Kubernetes;npm;Pulumi;Terraform',
#        'Ansible;Homebrew;Kubernetes;Terraform;Yarn',
#        'Docker;Kubernetes;npm;Unity 3D;Yarn',
#        'Docker;Homebrew;npm;Unity 3D;Unreal Engine;Yarn',
#        'Ansible;Homebrew',
#        'Ansible;Docker;Homebrew;npm;Pulumi;Terraform;Unreal Engine;Yarn',
#        'Ansible;Terraform', 'Chef;Docker;Homebrew;npm;Unity 3D;Yarn',
#        'Docker;Homebrew;Unreal Engine', 'Chef;Docker;Kubernetes;Puppet',
#        'Flow', 'Docker;Homebrew;Terraform;Yarn',
#        'Docker;Flow;Homebrew;npm;Yarn',
#        'Docker;Homebrew;Kubernetes;npm;Unity 3D;Yarn',
#        'Chef;Docker;Puppet', 'Pulumi', 'Flow;Kubernetes',
#        'Flow;Homebrew;npm', 'Ansible;Homebrew;Kubernetes;npm',
#        'Ansible;Chef;Docker;Homebrew;Kubernetes;Puppet',
#        'Docker;Homebrew;npm;Puppet;Yarn',
#        'Docker;Homebrew;Kubernetes;npm;Pulumi;Unity 3D;Unreal Engine;Yarn',
#        'Ansible;Yarn',
#        'Ansible;Chef;Docker;Homebrew;Kubernetes;npm;Pulumi;Puppet;Terraform',
#        'Docker;Terraform;Yarn',
#        'Ansible;Homebrew;Kubernetes;npm;Terraform',
#        'Homebrew;Kubernetes;Terraform;Yarn', 'Ansible;Docker;Yarn',
#        'Chef;Docker;Homebrew;Kubernetes;Terraform',
#        'Docker;Homebrew;Kubernetes;Puppet;Terraform',
#        'Chef;Docker;Kubernetes;npm',
#        'Docker;Homebrew;Kubernetes;npm;Terraform;Unity 3D;Unreal Engine;Yarn',
#        'Chef;Docker;Flow;Kubernetes;npm;Puppet;Unity 3D;Unreal Engine;Yarn',
#        'Homebrew;Kubernetes;npm;Unity 3D', 'Docker;npm;Puppet',
#        'Ansible;Docker;Homebrew;Kubernetes;Pulumi;Terraform',
#        'Ansible;Chef;Docker;Homebrew;Kubernetes;npm;Pulumi;Terraform;Yarn',
#        'Flow;Homebrew;npm;Yarn',
#        'Ansible;Chef;Docker;Homebrew;Kubernetes;Terraform;Yarn',
#        'Docker;Homebrew;npm;Unreal Engine;Yarn',
#        'Ansible;Homebrew;Unreal Engine',
#        'Chef;Docker;Homebrew;Kubernetes;npm;Yarn', 'Terraform;Unity 3D',
#        'Ansible;Docker;Homebrew;npm;Unity 3D;Yarn',
#        'Docker;Kubernetes;Unity 3D;Unreal Engine',
#        'Chef;Kubernetes;npm;Yarn',
#        'Docker;Kubernetes;npm;Pulumi;Terraform;Yarn', 'Homebrew;Puppet',
#        'Ansible;Docker;Homebrew;Puppet', 'Ansible;Docker;Unreal Engine',
#        'npm;Unreal Engine;Yarn',
#        'Ansible;Chef;Flow;Homebrew;Pulumi;Unity 3D;Unreal Engine;Yarn',
#        'npm;Terraform;Unity 3D',
#        'Docker;Homebrew;Kubernetes;npm;Unity 3D;Unreal Engine',
#        'Ansible;Docker;Kubernetes;Unity 3D', 'Ansible;Chef',
#        'Ansible;Docker;Puppet;Terraform',
#        'Docker;Kubernetes;npm;Puppet;Unity 3D;Yarn', 'Chef;Homebrew;npm',
#        'Chef;Docker;Homebrew',
#        'Docker;Flow;Homebrew;Kubernetes;npm;Unity 3D;Yarn',
#        'Kubernetes;Unity 3D;Unreal Engine',
#        'Homebrew;Kubernetes;npm;Yarn', 'npm;Pulumi',
#        'Ansible;Docker;npm;Pulumi;Terraform;Unity 3D;Yarn',
#        'Ansible;Docker;Homebrew;Kubernetes;npm;Terraform;Unity 3D;Yarn',
#        'Docker;Flow;Homebrew;npm;Puppet;Yarn', 'Homebrew;npm;Puppet',
#        'Ansible;Docker;Flow',
#        'Ansible;Chef;Docker;Kubernetes;Puppet;Terraform', 'Pulumi;Yarn',
#        'Homebrew;npm;Unreal Engine;Yarn', 'Unity 3D;Yarn', 'Chef;Yarn',
#        'Docker;Flow;Kubernetes;npm',
#        'Ansible;Docker;Homebrew;Kubernetes;npm;Unity 3D;Unreal Engine;Yarn',
#        'Ansible;Kubernetes;npm',
#        'Ansible;Chef;Docker;Homebrew;npm;Terraform;Yarn',
#        'Chef;Docker;Homebrew;npm;Yarn', 'Docker;npm;Pulumi;Terraform',
#        'Ansible;Chef;Docker;Homebrew;Kubernetes;Terraform',
#        'Docker;Flow;npm;Yarn', 'Chef;Terraform',
#        'Docker;Homebrew;npm;Puppet;Terraform;Yarn',
#        'Docker;Homebrew;npm;Terraform;Unity 3D', 'Ansible;npm;Terraform',
#        'Homebrew;Kubernetes;Unity 3D', 'Flow;Yarn', 'Chef;Docker',
#        'Chef;Docker;Terraform;Unreal Engine',
#        'Ansible;Chef;Docker;Homebrew;npm;Yarn',
#        'Ansible;Chef;Docker;Kubernetes;Puppet',
#        'Docker;Homebrew;Kubernetes;npm;Pulumi;Terraform;Unity 3D;Unreal Engine',
#        'Docker;Homebrew;Kubernetes;Pulumi;Terraform;Yarn',
#        'Ansible;Docker;Kubernetes;Puppet;Terraform;Yarn',
#        'Docker;Kubernetes;npm;Puppet;Yarn',
#        'Homebrew;npm;Unity 3D;Unreal Engine',
#        'Kubernetes;npm;Unity 3D;Unreal Engine;Yarn',
#        'Homebrew;Pulumi;Yarn',
#        'Docker;Kubernetes;npm;Puppet;Terraform;Yarn',
#        'Docker;Homebrew;Kubernetes;npm;Puppet;Yarn',
#        'Chef;Pulumi;Unreal Engine', 'Docker;npm;Puppet;Terraform',
#        'Ansible;Chef;Docker;npm;Yarn',
#        'Docker;Kubernetes;npm;Unity 3D;Unreal Engine',
#        'Ansible;Unreal Engine', 'Chef;Docker;Homebrew;Kubernetes',
#        'Ansible;Chef;Docker;Kubernetes;npm;Pulumi;Puppet;Terraform',
#        'Ansible;Docker;Kubernetes;npm;Pulumi',
#        'Docker;Homebrew;Unreal Engine;Yarn',
#        'Ansible;Docker;Kubernetes;npm;Puppet;Terraform;Yarn',
#        'Homebrew;npm;Unreal Engine',
#        'Ansible;Chef;Docker;Homebrew;Kubernetes;npm;Puppet;Terraform;Yarn',
#        'Ansible;Chef;Docker', 'Ansible;Chef;Docker;Kubernetes;npm;Yarn',
#        'Docker;Flow;Homebrew;npm;Unity 3D;Unreal Engine',
#        'Ansible;Chef;Terraform', 'Chef;npm;Puppet',
#        'Kubernetes;Terraform;Yarn', 'Docker;npm;Terraform;Unity 3D;Yarn',
#        'Docker;Homebrew;npm;Pulumi;Yarn',
#        'Ansible;Docker;Homebrew;Kubernetes;npm;Puppet;Yarn',
#        'Ansible;Docker;Homebrew;Unity 3D;Unreal Engine',
#        'Docker;Puppet;Terraform', 'Docker;Puppet;Yarn',
#        'Ansible;Chef;Docker;Homebrew;Kubernetes',
#        'Ansible;Docker;Kubernetes;Puppet;Terraform', 'Flow;npm',
#        'Ansible;Docker;Homebrew;npm;Unity 3D',
#        'Docker;Kubernetes;npm;Pulumi;Unity 3D',
#        'Docker;Kubernetes;Terraform;Unreal Engine;Yarn',
#        'Docker;Homebrew;Kubernetes;npm;Puppet;Unity 3D;Unreal Engine',
#        'Chef;Unity 3D;Unreal Engine', 'Docker;Flow;npm;Unity 3D;Yarn',
#        'Kubernetes;npm;Unity 3D',
#        'Docker;Homebrew;Kubernetes;Unity 3D;Yarn',
#        'Docker;Homebrew;Kubernetes;Unreal Engine;Yarn',
#        'Docker;Homebrew;Kubernetes;npm;Puppet;Terraform;Yarn',
#        'Docker;Flow;npm;Unreal Engine;Yarn',
#        'Ansible;Docker;Homebrew;Kubernetes;Terraform;Yarn',
#        'Ansible;Docker;Homebrew;Kubernetes;npm;Unity 3D;Unreal Engine',
#        'Ansible;Chef;Docker;Homebrew;Kubernetes;npm;Terraform;Unreal Engine;Yarn',
#        'Docker;Flow;Kubernetes;npm;Yarn', 'Ansible;npm;Terraform;Yarn',
#        'Flow;Homebrew;Yarn', 'Chef;npm;Puppet;Terraform',
#        'Docker;Homebrew;npm;Terraform;Unity 3D;Yarn', 'Terraform;Yarn',
#        'Docker;Flow;Homebrew;Kubernetes;npm;Terraform;Yarn',
#        'Ansible;Docker;Homebrew;Kubernetes;Terraform;Unity 3D',
#        'Docker;Kubernetes;npm;Terraform;Unity 3D;Unreal Engine;Yarn',
#        'Docker;npm;Pulumi;Terraform;Yarn',
#        'Chef;Homebrew;Kubernetes;npm;Terraform;Yarn',
#        'Homebrew;Unreal Engine;Yarn',
#        'Ansible;Docker;Homebrew;Kubernetes;Puppet;Terraform',
#        'Pulumi;Terraform', 'Ansible;Chef;Docker;Kubernetes;npm',
#        'Ansible;Chef;Docker;Homebrew;Kubernetes;Puppet;Terraform',
#        'Ansible;Kubernetes;npm;Terraform',
#        'Ansible;Docker;Terraform;Yarn',
#        'Ansible;Docker;Kubernetes;npm;Puppet;Terraform',
#        'Ansible;Docker;Flow;Homebrew;Kubernetes;npm;Unity 3D;Yarn',
#        'Chef;Homebrew;npm;Terraform',
#        'Ansible;Docker;Homebrew;Unreal Engine;Yarn',
#        'Homebrew;Kubernetes;npm;Terraform;Yarn',
#        'Ansible;Docker;npm;Unity 3D;Yarn',
#        'Chef;Docker;Homebrew;Kubernetes;npm;Terraform;Unreal Engine;Yarn',
#        'Ansible;Chef;Docker;Flow;Homebrew;Terraform;Unity 3D;Unreal Engine',
#        'npm;Puppet;Unreal Engine',
#        'Chef;Docker;Homebrew;Kubernetes;npm;Puppet;Terraform;Yarn',
#        'Docker;Homebrew;Puppet',
#        'Docker;Kubernetes;npm;Unreal Engine;Yarn',
#        'Ansible;Docker;Kubernetes;npm;Pulumi;Terraform',
#        'Flow;npm;Terraform', 'Ansible;Chef;Docker;npm;Terraform;Yarn',
#        'npm;Terraform;Unity 3D;Unreal Engine;Yarn',
#        'Ansible;Kubernetes;Terraform;Yarn',
#        'Ansible;Docker;Homebrew;npm;Puppet;Yarn',
#        'Ansible;Docker;Kubernetes;npm;Unity 3D;Unreal Engine;Yarn',
#        'Flow;npm;Unity 3D', 'Flow;Homebrew;Kubernetes;npm;Yarn',
#        'Docker;Homebrew;Kubernetes;Terraform;Unreal Engine',
#        'Docker;Homebrew;npm;Pulumi;Unity 3D;Unreal Engine;Yarn',
#        'Homebrew;Unity 3D;Yarn', 'Homebrew;Unity 3D;Unreal Engine',
#        'Chef;Flow;Homebrew;npm;Yarn', 'Ansible;Chef;Kubernetes;Unity 3D',
#        'Ansible;Docker;npm;Unity 3D;Unreal Engine;Yarn',
#        'Docker;npm;Puppet;Unity 3D;Unreal Engine',
#        'Docker;npm;Puppet;Unity 3D;Yarn',
#        'Docker;Kubernetes;npm;Pulumi;Terraform',
#        'Ansible;Chef;Docker;Homebrew;Unity 3D',
#        'Ansible;Chef;Homebrew;npm', 'Ansible;Homebrew;Kubernetes',
#        'Ansible;Homebrew;Terraform',
#        'Ansible;Docker;npm;Puppet;Terraform;Yarn',
#        'Ansible;Docker;Homebrew;Kubernetes;npm;Puppet;Terraform;Unity 3D;Yarn',
#        'Docker;Homebrew;Kubernetes;npm;Pulumi',
#        'Ansible;Docker;Unity 3D;Unreal Engine',
#        'Ansible;Kubernetes;Puppet;Terraform', 'Docker;Kubernetes;Pulumi',
#        'Ansible;Docker;Kubernetes;Pulumi',
#        'Kubernetes;npm;Unity 3D;Unreal Engine',
#        'Ansible;Chef;Docker;npm;Puppet',
#        'Docker;Homebrew;Kubernetes;npm;Unreal Engine;Yarn',
#        'Ansible;Chef;Docker;Homebrew;Kubernetes;npm;Terraform',
#        'Docker;Flow;Homebrew;npm', 'Ansible;Puppet',
#        'Chef;Docker;Homebrew;Yarn',
#        'Ansible;Docker;Kubernetes;npm;Puppet;Terraform;Unity 3D;Unreal Engine;Yarn',
#        'Docker;Homebrew;npm;Terraform;Unity 3D;Unreal Engine;Yarn',
#        'Chef;npm;Terraform;Yarn', 'Homebrew;Puppet;Terraform',
#        'Chef;Docker;Homebrew;Kubernetes;npm',
#        'Docker;Homebrew;Pulumi;Terraform', 'Chef;Homebrew;npm;Yarn',
#        'Docker;Homebrew;npm;Puppet;Unity 3D;Yarn',
#        'Ansible;Docker;Flow;Kubernetes;npm;Yarn',
#        'Docker;Flow;Kubernetes;npm;Pulumi',
#        'Chef;Docker;Homebrew;Kubernetes;npm;Unity 3D',
#        'Ansible;Chef;Docker;npm;Terraform',
#        'Ansible;Docker;Homebrew;Kubernetes;npm;Terraform;Unity 3D',
#        'Chef;Docker;npm;Yarn', 'Chef;npm;Terraform;Unity 3D',
#        'Ansible;Chef;Docker;npm',
#        'Ansible;Docker;Homebrew;npm;Terraform;Unity 3D',
#        'Chef;Docker;Flow;npm;Yarn',
#        'Chef;Docker;Homebrew;Kubernetes;npm;Terraform',
#        'Chef;Kubernetes;Terraform', 'Ansible;Docker;Flow;npm;Yarn',
#        'Ansible;Homebrew;npm;Yarn',
#        'Chef;Docker;Homebrew;Kubernetes;Pulumi;Terraform;Unity 3D;Unreal Engine;Yarn',
#        'Chef;npm;Terraform', 'Docker;Homebrew;Pulumi;Yarn',
#        'Ansible;Chef;Docker;Homebrew',
#        'Chef;Docker;Kubernetes;npm;Puppet;Terraform;Yarn',
#        'Ansible;Chef;Docker;npm;Terraform;Unreal Engine',
#        'Ansible;Pulumi',
#        'Ansible;Docker;Homebrew;Kubernetes;npm;Terraform;Unreal Engine;Yarn',
#        'Docker;Kubernetes;Unity 3D;Yarn',
#        'Ansible;Chef;Homebrew;Puppet;Terraform;Yarn',
#        'Ansible;Docker;Homebrew;npm;Puppet;Terraform;Yarn',
#        'Ansible;Docker;npm;Unreal Engine',
#        'Docker;npm;Terraform;Unity 3D;Unreal Engine;Yarn',
#        'npm;Puppet;Unity 3D', 'Docker;Flow',
#        'Kubernetes;npm;Pulumi;Terraform;Unity 3D',
#        'Ansible;Chef;Docker;Flow;Homebrew;Kubernetes;npm;Pulumi;Puppet;Terraform;Unity 3D;Unreal Engine;Yarn',
#        'Docker;Homebrew;npm;Terraform;Unreal Engine',
#        'Ansible;Chef;Docker;Kubernetes;npm;Terraform;Yarn',
#        'Docker;Homebrew;npm;Pulumi;Puppet;Yarn',
#        'Homebrew;npm;Puppet;Yarn',
#        'Chef;Docker;Kubernetes;npm;Pulumi;Terraform', 'Ansible;Flow;npm',
#        'Docker;Homebrew;Kubernetes;npm;Pulumi;Unity 3D;Yarn',
#        'Docker;Kubernetes;Pulumi;Puppet;Terraform',
#        'Ansible;Homebrew;Kubernetes;npm;Yarn', 'Ansible;npm;Puppet;Yarn',
#        'Ansible;Chef;Flow;npm;Terraform;Yarn',
#        'Docker;Homebrew;Kubernetes;Puppet;Unity 3D',
#        'Chef;Docker;Kubernetes;npm;Puppet;Terraform',
#        'Docker;Homebrew;Kubernetes;npm;Puppet;Terraform;Unity 3D;Yarn',
#        'Ansible;Homebrew;Terraform;Yarn',
#        'Docker;Homebrew;Kubernetes;npm;Terraform;Unity 3D;Yarn',
#        'Ansible;Chef;Docker;Homebrew;npm;Puppet;Yarn',
#        'Ansible;Docker;Kubernetes;npm;Unity 3D;Yarn',
#        'Ansible;Chef;Docker;Kubernetes;npm;Puppet;Terraform;Unity 3D',
#        'Ansible;Chef;Docker;Homebrew;npm;Terraform',
#        'Ansible;Docker;Homebrew;Kubernetes;npm;Pulumi;Puppet;Terraform',
#        'Docker;Homebrew;Unity 3D;Yarn', 'Chef;Docker;npm;Unity 3D;Yarn',
#        'Chef;Docker;Homebrew;Terraform', 'Ansible;Docker;Flow;npm',
#        'Ansible;Docker;npm;Puppet', 'Ansible;Kubernetes;Yarn',
#        'Ansible;Docker;Flow;Puppet;Terraform',
#        'Chef;Docker;Homebrew;Kubernetes;Pulumi;Terraform',
#        'Ansible;npm;Unity 3D', 'Chef;Homebrew;Kubernetes;npm;Terraform',
#        'Docker;Homebrew;Kubernetes;Unreal Engine',
#        'Ansible;Docker;Flow;Kubernetes;npm;Puppet;Yarn',
#        'Docker;Flow;Homebrew;npm;Terraform;Yarn',
#        'Ansible;Chef;Docker;npm;Puppet;Terraform',
#        'Ansible;Flow;npm;Yarn',
#        'Ansible;Docker;Kubernetes;npm;Puppet;Unity 3D;Yarn',
#        'Ansible;Docker;Flow;Homebrew;Kubernetes;npm;Puppet;Terraform;Unity 3D;Unreal Engine',
#        'Ansible;Chef;Homebrew;Kubernetes;Terraform',
#        'Kubernetes;Puppet;Terraform',
#        'Ansible;Docker;Homebrew;npm;Pulumi;Terraform',
#        'Chef;Docker;Kubernetes;Terraform;Yarn',
#        'Ansible;Docker;Homebrew;Kubernetes;npm;Unity 3D;Yarn',
#        'Ansible;Chef;Docker;Kubernetes;npm;Puppet;Terraform;Yarn',
#        'Docker;Homebrew;Kubernetes;Unity 3D;Unreal Engine;Yarn',
#        'Ansible;Docker;Flow;Terraform', 'Docker;Kubernetes;npm;Pulumi',
#        'Ansible;Homebrew;npm;Terraform;Yarn',
#        'Ansible;Docker;Kubernetes;npm;Unity 3D;Unreal Engine',
#        'Unreal Engine;Yarn', 'Docker;npm;Pulumi;Unity 3D',
#        'Flow;npm;Unity 3D;Unreal Engine;Yarn',
#        'Ansible;Chef;Docker;Kubernetes;npm;Puppet;Terraform',
#        'Unity 3D;Unreal Engine;Yarn',
#        'Ansible;Chef;Homebrew;npm;Unity 3D;Yarn',
#        'Docker;Kubernetes;Pulumi;Yarn', 'Ansible;Chef;Yarn',
#        'Ansible;Homebrew;npm;Unity 3D;Yarn',
#        'Chef;Docker;Homebrew;Kubernetes;npm;Unity 3D;Unreal Engine;Yarn',
#        'Chef;Docker;npm;Unity 3D;Unreal Engine;Yarn',
#        'Ansible;Chef;Docker;Puppet;Terraform',
#        'Ansible;Chef;Docker;Kubernetes',
#        'Ansible;Docker;Homebrew;npm;Unity 3D;Unreal Engine;Yarn',
#        'Docker;Homebrew;Kubernetes;npm;Pulumi;Terraform;Yarn',
#        'Homebrew;Kubernetes;npm;Terraform;Unity 3D;Unreal Engine;Yarn',
#        'Ansible;Docker;Homebrew;Kubernetes;npm;Unreal Engine;Yarn',
#        'Docker;Flow;Homebrew;Kubernetes;npm;Unity 3D;Unreal Engine;Yarn',
#        'Ansible;Homebrew;Kubernetes;npm;Terraform;Yarn',
#        'Ansible;Flow;Kubernetes;npm;Terraform;Yarn',
#        'Docker;Kubernetes;npm;Pulumi;Terraform;Unity 3D;Unreal Engine;Yarn',
#        'Homebrew;Pulumi', 'Kubernetes;Pulumi;Terraform',
#        'Ansible;Docker;Homebrew;Kubernetes;npm;Terraform;Unity 3D;Unreal Engine;Yarn',
#        'Ansible;Docker;Flow;Kubernetes;Terraform;Unreal Engine',
#        'Docker;Flow;npm;Unity 3D;Unreal Engine',
#        'Ansible;Chef;Terraform;Unity 3D',
#        'Ansible;Docker;Kubernetes;Unreal Engine',
#        'Chef;Docker;Flow;npm;Terraform;Unreal Engine',
#        'Ansible;Docker;Kubernetes;Pulumi;Terraform;Unity 3D',
#        'Docker;Homebrew;npm;Pulumi;Unreal Engine;Yarn',
#        'Ansible;Docker;Flow;Homebrew;Kubernetes;npm;Puppet;Yarn',
#        'Kubernetes;Unity 3D', 'Chef;Pulumi;Terraform', 'Ansible;Flow',
#        'Ansible;Chef;Docker;Kubernetes;npm;Puppet;Yarn',
#        'Ansible;Homebrew;npm;Puppet;Yarn',
#        'Ansible;Docker;npm;Terraform;Unreal Engine',
#        'Chef;Docker;Homebrew;Kubernetes;Puppet;Terraform',
#        'Ansible;Docker;Homebrew;Kubernetes;npm;Pulumi;Terraform',
#        'Chef;Kubernetes', 'Ansible;Chef;Docker;Homebrew;Yarn',
#        'Docker;Homebrew;Kubernetes;npm;Terraform;Unreal Engine;Yarn',
#        'Ansible;Docker;Homebrew;npm;Puppet;Terraform',
#        'Ansible;Chef;Docker;Homebrew;npm;Puppet;Terraform;Yarn',
#        'Docker;Pulumi;Yarn',
#        'Ansible;Chef;Docker;Flow;Homebrew;Kubernetes;npm;Pulumi;Puppet;Terraform',
#        'Docker;Homebrew;npm;Pulumi;Terraform',
#        'Ansible;Docker;Homebrew;Kubernetes;npm;Pulumi;Yarn',
#        'Docker;Flow;Unity 3D',
#        'Docker;Homebrew;Kubernetes;Pulumi;Unity 3D;Unreal Engine',
#        'Ansible;Docker;npm;Terraform;Unreal Engine;Yarn',
#        'Docker;Kubernetes;npm;Terraform;Unreal Engine;Yarn',
#        'Ansible;Docker;Kubernetes;npm;Terraform;Unreal Engine',
#        'npm;Puppet;Unity 3D;Unreal Engine',
#        'Ansible;Chef;Docker;Homebrew;npm;Unreal Engine',
#        'Ansible;Chef;Docker;Homebrew;Kubernetes;npm;Yarn',
#        'Chef;Docker;npm;Terraform', 'Ansible;Docker;npm;Pulumi',
#        'Flow;Unity 3D', 'Docker;Flow;Homebrew;Kubernetes;npm',
#        'Ansible;Chef;Docker;Homebrew;Kubernetes;npm;Puppet;Yarn',
#        'Chef;Docker;Homebrew;Kubernetes;npm;Unity 3D;Yarn',
#        'Ansible;Chef;Docker;Flow;npm',
#        'Docker;Homebrew;Unity 3D;Unreal Engine;Yarn',
#        'Flow;Homebrew;npm;Unity 3D;Yarn', 'Chef;Docker;npm;Puppet',
#        'Ansible;Homebrew;Puppet;Terraform',
#        'Chef;Docker;npm;Terraform;Yarn',
#        'Ansible;Chef;Docker;Homebrew;Terraform',
#        'Ansible;Chef;Docker;Homebrew;Kubernetes;npm;Puppet',
#        'Chef;Docker;Kubernetes;Puppet;Terraform', 'npm;Pulumi;Terraform',
#        'Ansible;Docker;Homebrew;Unity 3D',
#        'Ansible;Docker;Homebrew;Unreal Engine',
#        'Chef;Docker;npm;Unity 3D',
#        'Ansible;Docker;Homebrew;npm;Unreal Engine;Yarn',
#        'Homebrew;Terraform;Yarn', 'Ansible;Docker;Unity 3D;Yarn',
#        'Chef;Docker;Homebrew;npm;Puppet;Yarn',
#        'Ansible;Docker;Homebrew;Kubernetes;npm;Unity 3D',
#        'Ansible;Chef;Docker;Homebrew;Kubernetes;Puppet;Terraform;Unity 3D;Unreal Engine;Yarn',
#        'Homebrew;npm;Pulumi;Yarn',
#        'Ansible;Docker;Kubernetes;npm;Pulumi;Yarn',
#        'Chef;npm;Unity 3D;Yarn',
#        'Docker;Homebrew;Kubernetes;npm;Puppet;Unity 3D',
#        'Chef;Docker;Homebrew;Puppet;Unreal Engine',
#        'Ansible;Docker;Flow;Homebrew;Kubernetes;npm;Yarn',
#        'Ansible;Docker;npm;Pulumi;Terraform;Yarn',
#        'Docker;Homebrew;Kubernetes;npm;Pulumi;Unreal Engine',
#        'Flow;Terraform',
#        'Ansible;Docker;Flow;Kubernetes;Pulumi;Puppet;Terraform;Unity 3D;Unreal Engine;Yarn',
#        'Docker;Flow;Homebrew;npm;Unity 3D;Yarn',
#        'Chef;Docker;npm;Unity 3D;Unreal Engine',
#        'Ansible;Chef;Kubernetes',
#        'Ansible;Chef;Homebrew;Puppet;Unity 3D;Yarn',
#        'Ansible;Kubernetes;npm;Yarn', 'Docker;npm;Puppet;Unity 3D',
#        'Ansible;Docker;Kubernetes;npm;Puppet;Unity 3D;Unreal Engine;Yarn',
#        'Ansible;Docker;npm;Puppet;Terraform;Unity 3D;Unreal Engine',
#        'Ansible;Docker;Homebrew;Terraform;Unity 3D',
#        'Docker;Flow;Homebrew;Kubernetes;Terraform;Yarn',
#        'Chef;Docker;Kubernetes;npm;Terraform;Yarn',
#        'Docker;Kubernetes;npm;Puppet;Unity 3D;Unreal Engine',
#        'Chef;Docker;Homebrew;Terraform;Yarn',
#        'Flow;Kubernetes;npm;Unity 3D;Unreal Engine', 'Chef;npm;Yarn',
#        'Homebrew;Kubernetes;npm;Puppet',
#        'Homebrew;Kubernetes;npm;Unity 3D;Yarn',
#        'Docker;Puppet;Terraform;Yarn',
#        'Ansible;Chef;Docker;Homebrew;Kubernetes;Puppet;Terraform;Unreal Engine',
#        'Docker;Homebrew;Kubernetes;Puppet',
#        'Ansible;Chef;Docker;Flow;Kubernetes',
#        'Docker;Flow;Kubernetes;npm;Terraform;Yarn',
#        'Ansible;Chef;Docker;Homebrew;Kubernetes;npm;Puppet;Unity 3D;Yarn',
#        'Ansible;Docker;Homebrew;Puppet;Yarn',
#        'Kubernetes;Pulumi;Terraform;Yarn',
#        'Docker;Homebrew;Puppet;Unity 3D;Yarn',
#        'Ansible;Docker;npm;Terraform;Unity 3D',
#        'Ansible;Chef;Docker;Flow;Homebrew;Kubernetes;npm;Pulumi;Puppet;Terraform;Unity 3D;Unreal Engine',
#        'Docker;Homebrew;Kubernetes;Puppet;Terraform;Unity 3D',
#        'Ansible;Chef;Docker;Kubernetes;npm;Terraform;Unreal Engine;Yarn',
#        'Docker;Kubernetes;npm;Terraform;Unreal Engine',
#        'Ansible;Docker;Kubernetes;Unity 3D;Unreal Engine',
#        'Ansible;Docker;Flow;Homebrew;npm;Puppet;Terraform;Unity 3D',
#        'Ansible;Chef;Docker;npm;Puppet;Yarn',
#        'Ansible;Chef;Docker;Homebrew;Kubernetes;npm;Puppet;Terraform',
#        'Docker;Terraform;Unity 3D;Yarn', 'Kubernetes;Pulumi',
#        'Ansible;Docker;Homebrew;Kubernetes;npm;Pulumi',
#        'Kubernetes;npm;Terraform;Yarn',
#        'Ansible;Chef;Docker;Flow;Homebrew;Kubernetes;Terraform;Yarn',
#        'Puppet;Terraform', 'Docker;Flow;Homebrew;Kubernetes;Puppet',
#        'Ansible;Docker;Homebrew;npm;Unity 3D;Unreal Engine',
#        'Ansible;Chef;Puppet;Terraform',
#        'Ansible;Kubernetes;npm;Puppet;Terraform',
#        'Docker;Terraform;Unreal Engine',
#        'Docker;Flow;Kubernetes;Puppet;Terraform;Unreal Engine;Yarn',
#        'Docker;Homebrew;npm;Puppet;Terraform',
#        'Ansible;Docker;Kubernetes;Terraform;Unreal Engine',
#        'Docker;Homebrew;Pulumi', 'Ansible;Docker;Terraform;Unreal Engine',
#        'Ansible;Docker;Puppet;Yarn', 'Ansible;Terraform;Yarn',
#        'Ansible;Docker;Homebrew;npm;Pulumi',
#        'Ansible;Docker;Homebrew;Kubernetes;Pulumi;Puppet',
#        'Docker;Unreal Engine;Yarn',
#        'Docker;Homebrew;Kubernetes;npm;Pulumi;Terraform;Unity 3D',
#        'Ansible;Docker;Kubernetes;Terraform;Unity 3D',
#        'Ansible;Chef;Docker;Flow;Kubernetes;Puppet',
#        'Chef;Homebrew;Kubernetes;npm;Yarn',
#        'Docker;Kubernetes;Puppet;Terraform;Yarn',
#        'Flow;Kubernetes;Unity 3D',
#        'Ansible;Flow;Pulumi;Terraform;Unity 3D',
#        'Ansible;Docker;npm;Puppet;Yarn', 'Puppet;Terraform;Unity 3D',
#        'Pulumi;Unity 3D', 'Ansible;Chef;Docker;Puppet;Unity 3D',
#        'Homebrew;Kubernetes;Unity 3D;Yarn',
#        'Ansible;Docker;npm;Unity 3D;Unreal Engine',
#        'Flow;Homebrew;Unity 3D',
#        'Docker;Flow;Homebrew;Kubernetes;npm;Terraform;Unity 3D;Unreal Engine;Yarn',
#        'Kubernetes;npm;Unity 3D;Yarn', 'Flow;Unity 3D;Unreal Engine',
#        'Ansible;Docker;Puppet;Unity 3D;Yarn',
#        'Docker;Homebrew;Kubernetes;npm;Puppet;Unity 3D;Yarn',
#        'Ansible;Chef;Flow;Terraform', 'Ansible;Chef;Docker;Puppet',
#        'Ansible;Docker;Terraform;Unity 3D',
#        'Docker;Kubernetes;Puppet;Yarn', 'Chef;Docker;Yarn',
#        'Chef;Kubernetes;Unity 3D',
#        'Chef;Docker;Homebrew;Kubernetes;npm;Puppet;Yarn',
#        'Chef;Docker;Terraform', 'Ansible;npm;Pulumi',
#        'Docker;Flow;Homebrew;Kubernetes;Terraform',
#        'Docker;Homebrew;Kubernetes;npm;Terraform;Unreal Engine',
#        'Chef;Docker;Unity 3D',
#        'Ansible;Docker;Homebrew;Kubernetes;Terraform;Unity 3D;Unreal Engine',
#        'Chef;Flow',
#        'Chef;Docker;Flow;Homebrew;Kubernetes;npm;Puppet;Terraform',
#        'Ansible;Chef;Docker;Kubernetes;Unity 3D',
#        'Ansible;Terraform;Unity 3D',
#        'Homebrew;Kubernetes;npm;Unreal Engine',
#        'Flow;Homebrew;npm;Unity 3D;Unreal Engine;Yarn',
#        'npm;Puppet;Unity 3D;Yarn',
#        'Ansible;Chef;Docker;Homebrew;npm;Puppet;Unity 3D',
#        'Chef;Docker;Kubernetes;npm;Yarn', 'npm;Pulumi;Yarn',
#        'Docker;Kubernetes;npm;Pulumi;Terraform;Unity 3D;Yarn',
#        'Ansible;Chef;Docker;Homebrew;Kubernetes;Puppet;Terraform;Yarn',
#        'Flow;Unity 3D;Unreal Engine;Yarn',
#        'Docker;Homebrew;npm;Puppet;Unity 3D',
#        'Kubernetes;npm;Puppet;Terraform',
#        'Ansible;Docker;Homebrew;Kubernetes;Pulumi;Terraform;Yarn',
#        'Ansible;Chef;Docker;Homebrew;Kubernetes;npm;Puppet;Unity 3D;Unreal Engine;Yarn',
#        'Ansible;Docker;Homebrew;Kubernetes;Terraform;Unreal Engine;Yarn',
#        'Docker;Homebrew;Kubernetes;npm;Puppet;Terraform;Unity 3D;Unreal Engine;Yarn',
#        'Chef;Docker;Homebrew;npm;Unity 3D;Unreal Engine;Yarn',
#        'Ansible;Docker;Kubernetes;npm;Terraform;Unity 3D',
#        'Puppet;Unity 3D', 'Ansible;Docker;Homebrew;Kubernetes;Unity 3D',
#        'Ansible;Docker;Homebrew;npm;Unreal Engine',
#        'Ansible;Docker;Flow;Homebrew;Kubernetes;npm;Terraform',
#        'Docker;Flow;Homebrew;Kubernetes;npm;Pulumi;Puppet;Terraform;Unity 3D;Unreal Engine',
#        'Docker;Homebrew;Kubernetes;npm;Pulumi;Puppet;Yarn',
#        'Kubernetes;Puppet;Terraform;Yarn',
#        'Docker;Homebrew;Kubernetes;npm;Terraform;Unity 3D;Unreal Engine',
#        'Homebrew;Terraform;Unity 3D', 'Ansible;Chef;Docker;Yarn',
#        'Chef;Flow;Kubernetes;Pulumi;Terraform;Unreal Engine',
#        'Docker;Flow;Kubernetes',
#        'Ansible;Docker;Homebrew;Kubernetes;npm;Terraform;Unity 3D;Unreal Engine',
#        'Ansible;Docker;Pulumi',
#        'Docker;Homebrew;Kubernetes;npm;Terraform;Unity 3D',
#        'Ansible;Docker;Homebrew;Pulumi;Terraform',
#        'Docker;Kubernetes;Terraform;Unreal Engine',
#        'Ansible;Docker;Kubernetes;Pulumi;Terraform;Yarn',
#        'Ansible;Docker;Homebrew;Unity 3D;Unreal Engine;Yarn',
#        'Docker;Homebrew;npm;Puppet;Terraform;Unity 3D;Unreal Engine;Yarn',
#        'Chef;Docker;Homebrew;Kubernetes;npm;Pulumi;Terraform;Yarn',
#        'Kubernetes;npm;Terraform;Unity 3D;Yarn',
#        'Docker;Homebrew;npm;Puppet;Unity 3D;Unreal Engine',
#        'Ansible;Chef;Docker;Flow;Kubernetes;npm;Puppet;Terraform',
#        'Docker;Terraform;Unity 3D;Unreal Engine',
#        'Homebrew;Kubernetes;Yarn',
#        'Ansible;Chef;Docker;Flow;Homebrew;Kubernetes;npm;Pulumi;Puppet;Terraform;Unity 3D;Yarn',
#        'Ansible;Docker;npm;Pulumi;Puppet;Terraform',
#        'Ansible;Chef;Docker;Homebrew;Puppet;Terraform',
#        'Ansible;Docker;npm;Puppet;Terraform', 'Chef;Unity 3D',
#        'Chef;Docker;Homebrew;Kubernetes;npm;Puppet;Terraform',
#        'Chef;npm;Unity 3D;Unreal Engine',
#        'Chef;Docker;Homebrew;Kubernetes;Yarn',
#        'Docker;Flow;Homebrew;Kubernetes;npm;Puppet;Unreal Engine;Yarn',
#        'Docker;Kubernetes;Unity 3D;Unreal Engine;Yarn',
#        'Docker;Homebrew;Terraform;Unity 3D',
#        'Docker;Homebrew;npm;Terraform;Unreal Engine;Yarn',
#        'Docker;Homebrew;npm;Pulumi;Unity 3D',
#        'Ansible;Chef;Docker;Kubernetes;npm;Puppet',
#        'Chef;Docker;Flow;Unity 3D;Unreal Engine', 'Ansible;Chef;Homebrew',
#        'Docker;Flow;Kubernetes;Unity 3D',
#        'Docker;Kubernetes;npm;Puppet;Unity 3D;Unreal Engine;Yarn',
#        'Docker;Flow;Kubernetes;npm;Unity 3D;Yarn',
#        'Docker;Homebrew;Kubernetes;Terraform;Unity 3D',
#        'Ansible;Docker;Kubernetes;Puppet;Yarn',
#        'Docker;Flow;Homebrew;Kubernetes;Yarn',
#        'Ansible;Chef;Kubernetes;Terraform',
#        'Ansible;Docker;Flow;Kubernetes;npm;Puppet;Unity 3D;Unreal Engine;Yarn',
#        'Chef;Docker;Homebrew;Kubernetes;Puppet;Terraform;Unity 3D;Unreal Engine',
#        'Homebrew;npm;Terraform;Unity 3D',
#        'Ansible;Docker;Unity 3D;Unreal Engine;Yarn',
#        'Ansible;Docker;Flow;Homebrew;Kubernetes;npm;Unreal Engine;Yarn',
#        'Ansible;Chef;Docker;npm;Puppet;Terraform;Yarn',
#        'Ansible;Homebrew;Kubernetes;Puppet', 'Chef;Kubernetes;npm',
#        'Ansible;Docker;Homebrew;npm;Pulumi;Terraform;Yarn',
#        'Ansible;Docker;Homebrew;npm;Terraform;Unity 3D;Yarn',
#        'Ansible;Docker;Flow;Homebrew;Yarn', 'Chef;Flow;Homebrew;Yarn',
#        'Ansible;Chef;Docker;Homebrew;Kubernetes;npm;Terraform;Unreal Engine',
#        'Docker;Homebrew;Kubernetes;Terraform;Unity 3D;Yarn',
#        'Chef;Docker;npm;Puppet;Yarn',
#        'Ansible;Docker;Flow;Homebrew;Kubernetes;npm;Puppet;Terraform;Unity 3D;Unreal Engine;Yarn',
#        'Flow;Unreal Engine', 'Ansible;Homebrew;npm;Puppet',
#        'Ansible;Docker;Flow;Homebrew;npm;Terraform;Yarn',
#        'Docker;Kubernetes;Pulumi;Unreal Engine;Yarn',
#        'Docker;Homebrew;Pulumi;Unity 3D',
#        'Ansible;Chef;Docker;Homebrew;Kubernetes;npm;Pulumi;Puppet;Terraform;Unity 3D;Unreal Engine;Yarn',
#        'Docker;Flow;Terraform', 'Docker;Homebrew;Puppet;Yarn',
#        'Docker;Kubernetes;Terraform;Unity 3D;Unreal Engine',
#        'Flow;Homebrew;Unreal Engine',
#        'Homebrew;Kubernetes;npm;Terraform;Unity 3D;Unreal Engine',
#        'Kubernetes;npm;Puppet', 'Chef;Docker;Homebrew;Puppet',
#        'Ansible;Chef;Docker;Unity 3D;Unreal Engine',
#        'Chef;Docker;Kubernetes;npm;Terraform;Unity 3D;Unreal Engine;Yarn',
#        'Ansible;Kubernetes;Unity 3D', 'Chef;Unity 3D;Unreal Engine;Yarn',
#        'Docker;Flow;Homebrew;Kubernetes;npm;Pulumi;Yarn',
#        'Flow;Kubernetes;npm',
#        'Ansible;Chef;Flow;Homebrew;Puppet;Terraform;Yarn',
#        'Flow;Kubernetes;npm;Unity 3D',
#        'Ansible;Docker;Kubernetes;npm;Terraform;Unity 3D;Yarn',
#        'Ansible;Docker;npm;Terraform;Unity 3D;Unreal Engine',
#        'Chef;Homebrew;Kubernetes;Pulumi;Unity 3D;Yarn',
#        'Docker;Homebrew;Kubernetes;npm;Pulumi;Puppet;Terraform',
#        'Ansible;Docker;Flow;Homebrew;npm;Unity 3D',
#        'Homebrew;npm;Puppet;Terraform',
#        'Ansible;Chef;Docker;Flow;Kubernetes;npm;Yarn',
#        'Docker;Flow;Homebrew;npm;Unreal Engine;Yarn',
#        'Docker;Flow;Homebrew;Terraform;Yarn',
#        'Ansible;Unreal Engine;Yarn', 'Flow;Homebrew',
#        'Ansible;Chef;Docker;Homebrew;Kubernetes;npm;Puppet;Terraform;Unity 3D;Unreal Engine;Yarn',
#        'Ansible;Docker;Homebrew;npm;Puppet', 'Chef;Docker;Flow',
#        'Docker;Homebrew;Terraform;Unreal Engine',
#        'Ansible;Flow;Terraform;Unity 3D;Unreal Engine',
#        'Chef;Docker;Unity 3D;Yarn',
#        'Ansible;Chef;Docker;Flow;Homebrew;Kubernetes;npm;Puppet;Terraform;Unity 3D;Unreal Engine;Yarn',
#        'Ansible;Docker;Homebrew;Kubernetes;Terraform;Unreal Engine',
#        'Ansible;Homebrew;npm;Unity 3D', 'npm;Pulumi;Unity 3D;Yarn',
#        'Pulumi;Unity 3D;Unreal Engine',
#        'Ansible;Homebrew;Kubernetes;Yarn',
#        'Ansible;Docker;npm;Puppet;Unity 3D;Unreal Engine',
#        'Ansible;Chef;Docker;Flow;Kubernetes;npm;Puppet;Terraform;Unreal Engine;Yarn',
#        'Docker;Flow;Kubernetes;Terraform;Unity 3D;Yarn',
#        'Flow;npm;Unreal Engine;Yarn',
#        'Ansible;Chef;Docker;Flow;Homebrew;Kubernetes;Yarn',
#        'Ansible;Docker;Kubernetes;npm;Unreal Engine',
#        'Chef;Docker;Homebrew;Kubernetes;npm;Pulumi;Terraform',
#        'Flow;Kubernetes;npm;Unity 3D;Unreal Engine;Yarn',
#        'Homebrew;Kubernetes;npm;Terraform;Unity 3D', 'Flow;Puppet',
#        'Ansible;Docker;Kubernetes;Terraform;Unity 3D;Unreal Engine;Yarn',
#        'Docker;Flow;Homebrew;Kubernetes;npm;Terraform;Unity 3D;Yarn',
#        'Docker;Flow;npm;Unreal Engine',
#        'Ansible;Chef;Docker;Kubernetes;npm;Puppet;Terraform;Unity 3D;Unreal Engine',
#        'Ansible;Chef;Docker;Homebrew;Kubernetes;npm;Terraform;Unity 3D;Unreal Engine',
#        'Docker;Homebrew;Kubernetes;Terraform;Unity 3D;Unreal Engine',
#        'Flow;npm;Unreal Engine', 'Kubernetes;npm;Unreal Engine',
#        'Ansible;Chef;Docker;Kubernetes;npm;Pulumi;Terraform',
#        'Ansible;Chef;Puppet',
#        'Docker;Kubernetes;npm;Puppet;Terraform;Unity 3D;Yarn',
#        'Docker;Kubernetes;npm;Pulumi;Unreal Engine;Yarn',
#        'Ansible;Chef;Docker;Homebrew;Puppet',
#        'Chef;Homebrew;npm;Unity 3D;Yarn', 'Flow;Puppet;Unity 3D',
#        'Chef;Puppet', 'Docker;Kubernetes;Pulumi;Terraform;Yarn',
#        'Docker;Flow;Homebrew;Kubernetes',
#        'Docker;Flow;Homebrew;Unity 3D;Yarn',
#        'Ansible;Docker;npm;Pulumi;Yarn',
#        'Docker;Pulumi;Unity 3D;Unreal Engine',
#        'Ansible;Chef;Docker;Flow;Homebrew;Kubernetes;npm;Pulumi;Puppet;Unity 3D;Unreal Engine;Yarn',
#        'Docker;Terraform;Unity 3D;Unreal Engine;Yarn',
#        'Homebrew;npm;Puppet;Terraform;Yarn',
#        'Ansible;Docker;Kubernetes;Pulumi;Yarn',
#        'Ansible;Kubernetes;npm;Terraform;Yarn',
#        'Ansible;Docker;Kubernetes;npm;Unreal Engine;Yarn',
#        'Kubernetes;npm;Unreal Engine;Yarn', 'Docker;Flow;Homebrew',
#        'Ansible;Chef;Docker;Homebrew;Kubernetes;npm;Terraform;Unity 3D;Unreal Engine;Yarn',
#        'Terraform;Unreal Engine',
#        'Docker;Kubernetes;npm;Pulumi;Puppet;Yarn',
#        'Chef;Kubernetes;npm;Unity 3D;Unreal Engine',
#        'npm;Puppet;Unity 3D;Unreal Engine;Yarn',
#        'Ansible;Chef;Docker;Homebrew;npm;Puppet;Terraform',
#        'Docker;Homebrew;Puppet;Terraform;Yarn',
#        'Docker;npm;Puppet;Terraform;Unity 3D;Unreal Engine;Yarn',
#        'Chef;Docker;Kubernetes;npm;Unity 3D;Yarn',
#        'Ansible;Docker;Kubernetes;npm;Puppet;Unity 3D',
#        'Ansible;Chef;npm',
#        'Chef;Docker;Homebrew;Kubernetes;npm;Terraform;Unity 3D;Yarn',
#        'Ansible;Docker;Kubernetes;npm;Terraform;Unity 3D;Unreal Engine',
#        'Chef;Flow;Homebrew;Kubernetes',
#        'Docker;Terraform;Unreal Engine;Yarn',
#        'Ansible;Docker;Homebrew;npm;Pulumi;Unity 3D;Yarn',
#        'Ansible;Puppet;Terraform',
#        'Ansible;Docker;Homebrew;Kubernetes;npm;Terraform;Unreal Engine',
#        'Flow;Homebrew;Kubernetes;npm;Terraform;Unity 3D',
#        'Ansible;Chef;Flow;Kubernetes;npm;Pulumi;Puppet;Terraform;Unity 3D;Unreal Engine;Yarn',
#        'Ansible;Docker;Pulumi;Terraform',
#        'Ansible;Chef;Docker;Kubernetes;Puppet;Terraform;Yarn',
#        'Flow;Puppet;Unity 3D;Unreal Engine',
#        'Ansible;Docker;Flow;Homebrew;Kubernetes;npm;Puppet;Terraform;Unity 3D;Yarn',
#        'Ansible;npm;Unity 3D;Unreal Engine',
#        'Chef;Docker;Homebrew;npm;Terraform;Unity 3D;Yarn',
#        'Ansible;Docker;Homebrew;Kubernetes;npm;Pulumi;Terraform;Unity 3D;Unreal Engine;Yarn',
#        'Ansible;Docker;Homebrew;Kubernetes;Terraform;Unity 3D;Yarn',
#        'Ansible;Docker;Homebrew;Pulumi;Terraform;Yarn',
#        'Ansible;Docker;Flow;Homebrew;npm;Yarn',
#        'Chef;Docker;Flow;Homebrew;Kubernetes;Pulumi;Puppet;Terraform;Unity 3D;Unreal Engine;Yarn',
#        'Chef;Homebrew;Unity 3D', 'Kubernetes;Puppet;Unity 3D',
#        'Docker;Homebrew;Puppet;Terraform',
#        'Docker;Kubernetes;npm;Puppet;Unity 3D',
#        'Ansible;Docker;Flow;Homebrew',
#        'Chef;Homebrew;npm;Terraform;Unity 3D;Yarn',
#        'Docker;npm;Pulumi;Terraform;Unity 3D;Yarn',
#        'Ansible;Chef;Flow;Terraform;Unity 3D',
#        'Chef;Docker;Flow;Homebrew;Kubernetes;npm;Pulumi;Puppet;Terraform;Unity 3D;Unreal Engine;Yarn',
#        'Ansible;Docker;Homebrew;Kubernetes;npm;Puppet;Unity 3D',
#        'Ansible;Docker;Homebrew;Kubernetes;Unity 3D;Yarn',
#        'Ansible;Chef;Kubernetes;npm;Puppet',
#        'Docker;Flow;npm;Puppet;Yarn', 'Flow;Pulumi',
#        'Chef;Homebrew;Unity 3D;Yarn', 'Chef;Flow;Terraform;Unity 3D;Yarn',
#        'Flow;Kubernetes;Unreal Engine',
#        'Ansible;Docker;Homebrew;Kubernetes;npm;Puppet;Unity 3D;Unreal Engine;Yarn',
#        'Docker;Flow;Unreal Engine',
#        'Chef;Docker;Kubernetes;Pulumi;Puppet;Terraform;Unity 3D;Unreal Engine;Yarn',
#        'Ansible;Chef;Flow;Yarn', 'Ansible;Homebrew;Unity 3D',
#        'Ansible;Chef;Docker;Homebrew;Pulumi;Terraform;Yarn',
#        'Docker;Flow;Kubernetes;npm;Terraform;Unity 3D;Unreal Engine',
#        'Docker;Homebrew;Kubernetes;npm;Puppet;Unity 3D;Unreal Engine;Yarn',
#        'Docker;npm;Pulumi;Puppet;Terraform;Unity 3D;Unreal Engine',
#        'Ansible;Flow;Kubernetes;npm',
#        'Ansible;Chef;Docker;Flow;Homebrew;npm;Pulumi;Terraform;Unity 3D;Unreal Engine;Yarn',
#        'Ansible;Chef;Docker;Kubernetes;Yarn',
#        'Docker;Flow;Kubernetes;npm;Unity 3D;Unreal Engine;Yarn',
#        'Homebrew;Kubernetes;Puppet;Terraform;Unity 3D;Unreal Engine;Yarn',
#        'Pulumi;Puppet', 'Chef;Docker;Unity 3D;Unreal Engine',
#        'Ansible;Docker;Kubernetes;Terraform;Unity 3D;Unreal Engine',
#        'Docker;Kubernetes;npm;Pulumi;Terraform;Unity 3D',
#        'npm;Terraform;Unreal Engine',
#        'Ansible;Docker;Homebrew;npm;Pulumi;Yarn',
#        'Kubernetes;npm;Puppet;Terraform;Yarn',
#        'Ansible;Chef;Docker;Homebrew;Kubernetes;npm;Unity 3D;Yarn',
#        'Homebrew;Kubernetes;Puppet', 'Docker;Flow;npm;Terraform;Yarn',
#        'Ansible;Unity 3D;Unreal Engine'], dtype=object)

# %%
df['NEWCollabToolsHaveWorkedWith'].unique()
# Out:
# array([nan, 'Notepad++;Visual Studio',
#        'Notepad++;Visual Studio;Visual Studio Code', ...,
#        'Android Studio;Atom;Eclipse;GoLand;IntelliJ;Nano;Notepad++;PyCharm;Sublime Text;Visual Studio Code;Webstorm',
#        'CLion;IntelliJ;Notepad++;Rider;Vim;Visual Studio;Visual Studio Code',
#        'Eclipse;GoLand;Vim;Visual Studio Code'], dtype=object)

# %%
df.rename(columns={'OpSysProfessional use': 'OpSysProfessionalUse', 'OpSysPersonal use': 'OpSysPersonalUse'}, inplace=True)
df['OpSysProfessionalUse'].unique()
# Out:
# array([nan, 'macOS', 'Windows', 'Linux-based;macOS',
#        'Windows;Windows Subsystem for Linux (WSL)',
#        'Linux-based;macOS;Windows', 'Linux-based;Windows',
#        'Windows Subsystem for Linux (WSL)', 'macOS;Windows',
#        'Linux-based', 'Linux-based;Windows Subsystem for Linux (WSL)',
#        'Linux-based;Windows;Windows Subsystem for Linux (WSL)',
#        'Linux-based;macOS;Windows;Windows Subsystem for Linux (WSL)',
#        'Other (please specify):',
#        'BSD;Linux-based;Windows;Windows Subsystem for Linux (WSL)',
#        'macOS;Other (please specify):',
#        'macOS;Windows;Windows Subsystem for Linux (WSL)',
#        'macOS;Windows Subsystem for Linux (WSL)',
#        'Windows;Other (please specify):', 'BSD;Linux-based;macOS;Windows',
#        'BSD;Linux-based',
#        'BSD;Linux-based;Windows;Other (please specify):',
#        'Linux-based;macOS;Windows Subsystem for Linux (WSL)',
#        'BSD;Linux-based;Windows Subsystem for Linux (WSL)',
#        'BSD;Linux-based;macOS',
#        'Linux-based;Windows;Windows Subsystem for Linux (WSL);Other (please specify):',
#        'BSD', 'Linux-based;Other (please specify):', 'BSD;macOS',
#        'BSD;Windows',
#        'BSD;Linux-based;macOS;Windows;Windows Subsystem for Linux (WSL)',
#        'BSD;macOS;Windows;Windows Subsystem for Linux (WSL)',
#        'BSD;Linux-based;macOS;Windows Subsystem for Linux (WSL)',
#        'BSD;Linux-based;Windows',
#        'Linux-based;Windows;Other (please specify):',
#        'BSD;Windows Subsystem for Linux (WSL)', 'BSD;macOS;Windows',
#        'Linux-based;macOS;Windows;Other (please specify):',
#        'BSD;Linux-based;Other (please specify):',
#        'Linux-based;macOS;Windows;Windows Subsystem for Linux (WSL);Other (please specify):',
#        'Linux-based;macOS;Other (please specify):',
#        'Linux-based;Windows Subsystem for Linux (WSL);Other (please specify):',
#        'Windows Subsystem for Linux (WSL);Other (please specify):',
#        'BSD;Linux-based;macOS;Windows;Windows Subsystem for Linux (WSL);Other (please specify):',
#        'Windows;Windows Subsystem for Linux (WSL);Other (please specify):',
#        'BSD;Windows;Windows Subsystem for Linux (WSL)',
#        'BSD;Linux-based;Windows;Windows Subsystem for Linux (WSL);Other (please specify):',
#        'Linux-based;macOS;Windows Subsystem for Linux (WSL);Other (please specify):',
#        'macOS;Windows;Other (please specify):',
#        'BSD;Other (please specify):',
#        'BSD;macOS;Windows Subsystem for Linux (WSL)',
#        'BSD;Linux-based;macOS;Windows;Other (please specify):',
#        'macOS;Windows;Windows Subsystem for Linux (WSL);Other (please specify):',
#        'BSD;Linux-based;macOS;Other (please specify):',
#        'BSD;Windows;Other (please specify):',
#        'BSD;Linux-based;macOS;Windows Subsystem for Linux (WSL);Other (please specify):'],
#       dtype=object)

# %%
df['VersionControlSystem'].unique()
# Out:
# array([nan, 'Git', 'Git;Other (please specify):', 'Mercurial;SVN',
#        "I don't use one", 'Git;SVN', 'SVN', 'Other (please specify):',
#        'Git;Mercurial', 'Git;Other (please specify):;SVN', 'Mercurial',
#        'Git;Other (please specify):;Mercurial', 'Git;Mercurial;SVN',
#        'Other (please specify):;SVN',
#        'Git;Other (please specify):;Mercurial;SVN',
#        'Other (please specify):;Mercurial',
#        'Other (please specify):;Mercurial;SVN'], dtype=object)

# %%
df['VCInteraction'].unique()
# Out:
# array([nan, 'Code editor',
#        'Code editor;Command-line;Version control hosting service web GUI;Dedicated version control GUI application',
#        'Command-line;Version control hosting service web GUI;Dedicated version control GUI application',
#        'Code editor;Command-line', 'Command-line',
#        'Command-line;Dedicated version control GUI application',
#        'Version control hosting service web GUI;Dedicated version control GUI application',
#        'Code editor;Dedicated version control GUI application',
#        'Code editor;Command-line;Dedicated version control GUI application',
#        'Command-line;Version control hosting service web GUI',
#        'Code editor;Command-line;Version control hosting service web GUI',
#        'Code editor;Version control hosting service web GUI',
#        'Version control hosting service web GUI',
#        'Dedicated version control GUI application',
#        'Code editor;Version control hosting service web GUI;Dedicated version control GUI application'],
#       dtype=object)

# %%
df.rename(columns={'VCHostingPersonal use': 'VCHostingPersonalUse', 'VCHostingProfessional use': 'VCHostingProfessionalUse'}, inplace=True)
df['VCHostingProfessionalUse'].unique()
# Out:
# array([nan])

# %%
df['VCHostingPersonalUse'].unique()
# Out:
# array([nan])

# %%
df.drop('VCHostingPersonalUse', axis=1, inplace=True)
df.drop('VCHostingProfessionalUse', axis=1, inplace=True)

# %%
df['OfficeStackAsyncHaveWorkedWith'].unique()
# Out:
# array([nan, 'Jira Work Management;Trello', 'Confluence', ...,
#        'ClickUp;Confluence;Jira Work Management;Microsoft Planner;Microsoft Lists;monday.com',
#        'Confluence;Jira Work Management;Microsoft Planner;Microsoft Lists;Wrike',
#        'Airtable;Microsoft Planner;Microsoft Lists;Trello'], dtype=object)

# %%
df['OfficeStackSyncHaveWorkedWith'].unique()
# Out:
# array([nan, 'Microsoft Teams', 'Slack;Zoom', 'Microsoft Teams;Zoom',
#        'Rocketchat;Slack;Zoom', 'Google Chat;Microsoft Teams;Slack;Zoom',
#        'Google Chat;Microsoft Teams;Zoom', 'Google Chat;Slack',
#        'Cisco Webex Teams;Google Chat;Microsoft Teams;RingCentral;Slack;Zoom',
#        'Microsoft Teams;Slack;Zoom', 'Microsoft Teams;Slack',
#        'Google Chat;Microsoft Teams;Slack', 'Zoom',
#        'Google Chat;Slack;Zoom', 'Slack', 'Cisco Webex Teams;Zoom',
#        'Cisco Webex Teams;Microsoft Teams;Zoom',
#        'Cisco Webex Teams;Microsoft Teams;Slack;Zoom',
#        'Microsoft Teams;Rocketchat;Slack;Wire;Zoom',
#        'Cisco Webex Teams;Microsoft Teams;Slack', 'Google Chat',
#        'Cisco Webex Teams;Google Chat;Microsoft Teams;Slack;Zoom',
#        'Cisco Webex Teams', 'Google Chat;Microsoft Teams', 'Mattermost',
#        'Mattermost;Slack', 'Cisco Webex Teams;Microsoft Teams',
#        'Microsoft Teams;Symphony', 'Mattermost;Microsoft Teams;Zoom',
#        'Cisco Webex Teams;Slack;Zoom',
#        'Microsoft Teams;RingCentral;Slack',
#        'Cisco Webex Teams;Microsoft Teams;RingCentral;Slack;Zoom',
#        'Google Chat;Microsoft Teams;Slack;Symphony;Zoom',
#        'Google Chat;Zoom', 'Mattermost;Microsoft Teams',
#        'Cisco Webex Teams;Google Chat;Slack;Zoom',
#        'Cisco Webex Teams;Mattermost;Zoom',
#        'Cisco Webex Teams;Google Chat;Slack', 'Cisco Webex Teams;Slack',
#        'Mattermost;Zoom', 'Rocketchat', 'Microsoft Teams;Rocketchat;Zoom',
#        'Mattermost;Microsoft Teams;Rocketchat;Slack;Zoom',
#        'Microsoft Teams;RingCentral;Slack;Zoom',
#        'Microsoft Teams;Rocketchat',
#        'Cisco Webex Teams;Mattermost;RingCentral;Zoom',
#        'Microsoft Teams;RingCentral;Zoom',
#        'Cisco Webex Teams;Google Chat;Microsoft Teams;Slack',
#        'Mattermost;Microsoft Teams;Slack;Zoom', 'Mattermost;Slack;Zoom',
#        'Cisco Webex Teams;Google Chat;Mattermost;Microsoft Teams;Rocketchat;Slack;Zoom',
#        'Google Chat;Mattermost',
#        'Mattermost;Microsoft Teams;Rocketchat;Zoom',
#        'Cisco Webex Teams;Mattermost;Microsoft Teams',
#        'Microsoft Teams;Rocketchat;Slack;Zoom',
#        'Microsoft Teams;Rocketchat;Slack', 'Mattermost;Rocketchat;Zoom',
#        'Cisco Webex Teams;Mattermost;Microsoft Teams;Slack;Zoom',
#        'Mattermost;Rocketchat',
#        'Cisco Webex Teams;Google Chat;Mattermost;Microsoft Teams;Slack;Zoom',
#        'Slack;Wickr;Zoom',
#        'Cisco Webex Teams;Google Chat;Microsoft Teams;Zoom',
#        'Google Chat;Mattermost;Slack;Wire;Zoom',
#        'Google Chat;Microsoft Teams;Slack;Wire;Zoom',
#        'Google Chat;Mattermost;Microsoft Teams;Slack;Zoom',
#        'Mattermost;Microsoft Teams;Slack',
#        'Cisco Webex Teams;Microsoft Teams;Rocketchat;Slack;Zoom',
#        'Rocketchat;Zoom', 'Slack;Wire;Zoom',
#        'Mattermost;Rocketchat;Slack', 'Microsoft Teams;Wickr',
#        'Google Chat;Mattermost;Microsoft Teams;Rocketchat;Slack;Zoom',
#        'Cisco Webex Teams;Microsoft Teams;Slack;Wire;Zoom',
#        'Cisco Webex Teams;Mattermost;Microsoft Teams;Zoom',
#        'Cisco Webex Teams;Microsoft Teams;RingCentral;Slack',
#        'RingCentral;Zoom', 'Cisco Webex Teams;Mattermost;Rocketchat;Zoom',
#        'Google Chat;Mattermost;Slack;Zoom', 'RingCentral;Slack;Zoom',
#        'Cisco Webex Teams;Google Chat;Mattermost;Microsoft Teams;Rocketchat;Slack;Wire;Zoom',
#        'Symphony;Zoom', 'Cisco Webex Teams;Slack;Symphony;Zoom',
#        'Symphony',
#        'Cisco Webex Teams;Mattermost;Microsoft Teams;Rocketchat;Slack;Zoom',
#        'Cisco Webex Teams;Google Chat;Rocketchat;Slack',
#        'Cisco Webex Teams;Google Chat;Zoom', 'Google Chat;Wire',
#        'Google Chat;Slack;Wire;Zoom', 'RingCentral;Slack',
#        'Cisco Webex Teams;Mattermost;Microsoft Teams;Slack',
#        'Google Chat;Slack;Wickr;Zoom',
#        'Google Chat;Microsoft Teams;Wire;Zoom',
#        'Microsoft Teams;Slack;Symphony;Zoom',
#        'Cisco Webex Teams;Mattermost;Slack;Zoom',
#        'Mattermost;Microsoft Teams;Wire',
#        'Mattermost;Microsoft Teams;Symphony',
#        'Cisco Webex Teams;Google Chat;Mattermost;Microsoft Teams;Zoom',
#        'Microsoft Teams;Wire;Zoom', 'Google Chat;RingCentral',
#        'Cisco Webex Teams;Microsoft Teams;Slack;Symphony;Zoom',
#        'Cisco Webex Teams;Rocketchat;Slack;Zoom',
#        'Microsoft Teams;Slack;Wire;Zoom', 'Google Chat;Mattermost;Zoom',
#        'Google Chat;Mattermost;Microsoft Teams;Zoom',
#        'Mattermost;Rocketchat;Slack;Zoom',
#        'Cisco Webex Teams;Mattermost;Slack',
#        'Cisco Webex Teams;Google Chat;Microsoft Teams',
#        'Google Chat;Mattermost;Microsoft Teams;Slack',
#        'Google Chat;Slack;Wire', 'Cisco Webex Teams;Symphony;Zoom',
#        'Cisco Webex Teams;Mattermost;Rocketchat;Slack;Zoom',
#        'Cisco Webex Teams;Rocketchat',
#        'Mattermost;Microsoft Teams;Rocketchat;Slack',
#        'Google Chat;Slack;Symphony;Zoom',
#        'Google Chat;Microsoft Teams;Rocketchat', 'Google Chat;Wire;Zoom',
#        'Google Chat;Microsoft Teams;RingCentral;Zoom',
#        'Microsoft Teams;Symphony;Zoom',
#        'Cisco Webex Teams;Google Chat;Microsoft Teams;Rocketchat;Zoom',
#        'Cisco Webex Teams;Microsoft Teams;Slack;Wickr;Zoom', 'Slack;Wire',
#        'Google Chat;RingCentral;Slack;Zoom',
#        'Cisco Webex Teams;Mattermost', 'Google Chat;RingCentral;Slack',
#        'Mattermost;Rocketchat;Wickr;Zoom', 'Rocketchat;Slack',
#        'Mattermost;Microsoft Teams;Rocketchat',
#        'Google Chat;Microsoft Teams;RingCentral;Slack;Zoom',
#        'Cisco Webex Teams;Google Chat;Microsoft Teams;Rocketchat;Symphony;Zoom',
#        'Coolfire Core;Google Chat;Mattermost;Microsoft Teams;Slack;Symphony;Zoom',
#        'Cisco Webex Teams;Microsoft Teams;Rocketchat;Zoom',
#        'Google Chat;Microsoft Teams;Rocketchat;Zoom',
#        'Microsoft Teams;RingCentral;Symphony;Zoom',
#        'Google Chat;Microsoft Teams;Rocketchat;Slack;Zoom',
#        'Google Chat;Rocketchat',
#        'Cisco Webex Teams;Google Chat;Microsoft Teams;Symphony;Unify Circuit;Wire;Zoom',
#        'Cisco Webex Teams;Google Chat;Rocketchat',
#        'Cisco Webex Teams;Google Chat;Microsoft Teams;Wickr;Zoom',
#        'Google Chat;Rocketchat;Zoom', 'Google Chat;Mattermost;Slack',
#        'Cisco Webex Teams;Google Chat;Mattermost;Microsoft Teams;Rocketchat;Slack;Wickr;Wire;Zoom',
#        'Coolfire Core;Mattermost;Microsoft Teams;Slack;Zoom',
#        'Cisco Webex Teams;Microsoft Teams;Rocketchat',
#        'Microsoft Teams;Unify Circuit', 'Rocketchat;Slack;Symphony;Zoom',
#        'Cisco Webex Teams;Coolfire Core;Google Chat;Mattermost;Microsoft Teams;Unify Circuit',
#        'Google Chat;Rocketchat;Slack;Zoom',
#        'Cisco Webex Teams;Google Chat;Microsoft Teams;Rocketchat;Slack;Zoom',
#        'Google Chat;Microsoft Teams;Slack;Wickr',
#        'Cisco Webex Teams;Google Chat;Mattermost;Microsoft Teams;RingCentral;Rocketchat;Slack;Zoom',
#        'Microsoft Teams;Slack;Wickr;Zoom',
#        'Cisco Webex Teams;Google Chat;Rocketchat;Slack;Zoom',
#        'RingCentral',
#        'Cisco Webex Teams;Google Chat;Microsoft Teams;Slack;Wire;Zoom',
#        'Microsoft Teams;Rocketchat;Wire',
#        'Google Chat;Microsoft Teams;Symphony;Zoom', 'Wire',
#        'Cisco Webex Teams;Google Chat',
#        'Google Chat;Microsoft Teams;Rocketchat;Slack',
#        'Microsoft Teams;RingCentral', 'Google Chat;RingCentral;Zoom',
#        'Cisco Webex Teams;Google Chat;Mattermost;Zoom',
#        'Google Chat;Microsoft Teams;RingCentral',
#        'Google Chat;Rocketchat;Slack',
#        'Cisco Webex Teams;Rocketchat;Zoom',
#        'Microsoft Teams;Rocketchat;Slack;Symphony',
#        'Microsoft Teams;RingCentral;Rocketchat;Slack;Zoom', 'Slack;Wickr',
#        'Cisco Webex Teams;Google Chat;Microsoft Teams;Slack;Unify Circuit;Zoom',
#        'Rocketchat;Wickr',
#        'Cisco Webex Teams;Coolfire Core;Mattermost;RingCentral;Rocketchat;Slack;Symphony;Unify Circuit;Wickr;Wire;Zoom',
#        'Cisco Webex Teams;Google Chat;Microsoft Teams;Slack;Symphony;Zoom',
#        'Google Chat;Microsoft Teams;Unify Circuit;Zoom',
#        'Cisco Webex Teams;Microsoft Teams;RingCentral',
#        'Cisco Webex Teams;Symphony', 'Wickr',
#        'Google Chat;Mattermost;Symphony',
#        'Google Chat;Microsoft Teams;Slack;Wickr;Zoom',
#        'Google Chat;Microsoft Teams;Unify Circuit',
#        'Microsoft Teams;RingCentral;Slack;Symphony;Zoom',
#        'Slack;Symphony', 'Google Chat;Mattermost;Rocketchat;Slack;Zoom',
#        'Google Chat;Mattermost;Microsoft Teams',
#        'Cisco Webex Teams;Microsoft Teams;Symphony',
#        'Cisco Webex Teams;Microsoft Teams;Slack;Wire',
#        'Rocketchat;Slack;Wire;Zoom', 'Mattermost;Wire;Zoom',
#        'Cisco Webex Teams;Microsoft Teams;RingCentral;Symphony;Zoom',
#        'Microsoft Teams;Rocketchat;Unify Circuit;Wickr', 'Wickr;Zoom',
#        'Cisco Webex Teams;Google Chat;Microsoft Teams;Slack;Wickr;Zoom',
#        'Cisco Webex Teams;Google Chat;Mattermost;RingCentral;Slack;Wickr;Zoom',
#        'Microsoft Teams;Slack;Wickr',
#        'Cisco Webex Teams;Mattermost;Microsoft Teams;Rocketchat;Slack;Wire;Zoom',
#        'Mattermost;Microsoft Teams;Wickr;Zoom', 'Unify Circuit',
#        'Cisco Webex Teams;Google Chat;Microsoft Teams;RingCentral;Zoom',
#        'Cisco Webex Teams;Google Chat;Microsoft Teams;Rocketchat;Slack;Wire;Zoom',
#        'Slack;Symphony;Zoom',
#        'Cisco Webex Teams;Coolfire Core;Google Chat;Mattermost;Microsoft Teams;RingCentral;Rocketchat;Slack;Symphony;Unify Circuit;Wickr;Wire;Zoom',
#        'Wire;Zoom', 'Cisco Webex Teams;Google Chat;Mattermost;Slack;Zoom',
#        'Cisco Webex Teams;Google Chat;Microsoft Teams;Rocketchat;Slack;Symphony;Zoom',
#        'Coolfire Core;Google Chat;Mattermost;Microsoft Teams;Rocketchat;Wire',
#        'Cisco Webex Teams;Microsoft Teams;RingCentral;Zoom',
#        'Cisco Webex Teams;Slack;Wire;Zoom', 'Microsoft Teams;Slack;Wire',
#        'Microsoft Teams;Symphony;Wire',
#        'Mattermost;Microsoft Teams;Rocketchat;Slack;Wire;Zoom',
#        'Microsoft Teams;Rocketchat;Slack;Symphony;Zoom',
#        'Cisco Webex Teams;Microsoft Teams;Symphony;Zoom',
#        'Microsoft Teams;Slack;Unify Circuit',
#        'Cisco Webex Teams;Google Chat;Slack;Symphony;Zoom',
#        'Cisco Webex Teams;Rocketchat;Slack',
#        'Google Chat;Mattermost;Microsoft Teams;Rocketchat;Slack',
#        'Cisco Webex Teams;Google Chat;Mattermost',
#        'Cisco Webex Teams;Google Chat;Mattermost;Microsoft Teams;Rocketchat;Zoom',
#        'Cisco Webex Teams;Microsoft Teams;Slack;Unify Circuit',
#        'Google Chat;Microsoft Teams;Slack;Unify Circuit;Zoom',
#        'Google Chat;Rocketchat;Slack;Symphony;Zoom',
#        'Cisco Webex Teams;RingCentral;Slack;Zoom',
#        'Cisco Webex Teams;Coolfire Core;Mattermost;Microsoft Teams;RingCentral;Slack;Symphony;Unify Circuit;Zoom',
#        'Google Chat;Microsoft Teams;Slack;Symphony;Wire;Zoom',
#        'Cisco Webex Teams;Microsoft Teams;Slack;Unify Circuit;Zoom',
#        'Microsoft Teams;Wire', 'Microsoft Teams;Rocketchat;Slack;Wickr',
#        'Google Chat;Mattermost;Microsoft Teams;RingCentral;Slack;Zoom',
#        'Cisco Webex Teams;Google Chat;Mattermost;Microsoft Teams;Slack;Wire;Zoom',
#        'Coolfire Core;Google Chat;Zoom',
#        'Microsoft Teams;Rocketchat;Slack;Wire',
#        'Cisco Webex Teams;Google Chat;Rocketchat;Zoom',
#        'Cisco Webex Teams;Mattermost;Unify Circuit',
#        'Google Chat;Microsoft Teams;Wickr;Zoom',
#        'Cisco Webex Teams;Coolfire Core;Google Chat;Mattermost;Microsoft Teams;RingCentral;Rocketchat;Slack;Unify Circuit;Wickr;Wire;Zoom',
#        'Cisco Webex Teams;Microsoft Teams;Wickr;Zoom',
#        'Cisco Webex Teams;Microsoft Teams;Wire',
#        'Coolfire Core;Google Chat',
#        'Cisco Webex Teams;Mattermost;Microsoft Teams;Rocketchat;Zoom',
#        'Cisco Webex Teams;Coolfire Core;RingCentral;Slack;Zoom',
#        'Cisco Webex Teams;Google Chat;Wire',
#        'Mattermost;RingCentral;Rocketchat;Symphony;Wickr;Wire',
#        'Rocketchat;Symphony',
#        'Microsoft Teams;Rocketchat;Slack;Wickr;Zoom',
#        'Coolfire Core;Google Chat;Microsoft Teams;Wire;Zoom',
#        'Google Chat;Unify Circuit',
#        'Microsoft Teams;Rocketchat;Symphony;Zoom',
#        'Google Chat;Mattermost;Microsoft Teams;Rocketchat;Zoom',
#        'Mattermost;Slack;Wickr;Zoom',
#        'Google Chat;Microsoft Teams;Slack;Wire',
#        'Cisco Webex Teams;Google Chat;Microsoft Teams;Slack;Symphony',
#        'Google Chat;Microsoft Teams;Symphony', 'Coolfire Core;Slack;Zoom',
#        'Cisco Webex Teams;Google Chat;Mattermost;Microsoft Teams;Rocketchat;Unify Circuit;Wickr;Wire;Zoom',
#        'Unify Circuit;Zoom',
#        'Cisco Webex Teams;Google Chat;Microsoft Teams;Unify Circuit;Zoom',
#        'Cisco Webex Teams;Google Chat;Microsoft Teams;Wire;Zoom',
#        'Cisco Webex Teams;Mattermost;Rocketchat;Wickr',
#        'Cisco Webex Teams;Coolfire Core;Mattermost;Microsoft Teams;Rocketchat;Wire;Zoom',
#        'Cisco Webex Teams;Google Chat;Microsoft Teams;RingCentral;Slack;Wickr;Zoom',
#        'Cisco Webex Teams;Google Chat;Mattermost;Microsoft Teams',
#        'Google Chat;Mattermost;Slack;Wickr;Zoom',
#        'Microsoft Teams;Unify Circuit;Wire;Zoom',
#        'Cisco Webex Teams;Google Chat;Mattermost;Microsoft Teams;RingCentral;Rocketchat;Slack;Symphony;Unify Circuit;Wickr;Wire;Zoom',
#        'Google Chat;Microsoft Teams;Rocketchat;Wire;Zoom',
#        'Cisco Webex Teams;Coolfire Core;Google Chat;RingCentral;Rocketchat;Slack;Symphony;Wickr;Zoom',
#        'Coolfire Core;Microsoft Teams;Slack;Zoom',
#        'Google Chat;Symphony;Zoom',
#        'Coolfire Core;Google Chat;Microsoft Teams;Slack;Zoom',
#        'Google Chat;Microsoft Teams;RingCentral;Rocketchat;Slack;Zoom',
#        'Cisco Webex Teams;Google Chat;Mattermost;Rocketchat;Slack;Zoom',
#        'Cisco Webex Teams;Coolfire Core',
#        'Coolfire Core;Google Chat;Mattermost;Microsoft Teams',
#        'Cisco Webex Teams;Coolfire Core;Google Chat;Mattermost;Microsoft Teams;RingCentral',
#        'Microsoft Teams;Wickr;Wire;Zoom', 'Microsoft Teams;Wickr;Zoom',
#        'Cisco Webex Teams;Google Chat;Mattermost;Rocketchat;Zoom',
#        'Coolfire Core;Microsoft Teams;Slack',
#        'Google Chat;Microsoft Teams;RingCentral;Slack;Wire;Zoom',
#        'Microsoft Teams;Rocketchat;Wickr;Zoom',
#        'Google Chat;Mattermost;Microsoft Teams;Slack;Wire',
#        'Cisco Webex Teams;Mattermost;Rocketchat;Slack;Wire;Zoom',
#        'Google Chat;Microsoft Teams;Wickr',
#        'Google Chat;Microsoft Teams;Wire',
#        'Mattermost;Microsoft Teams;Symphony;Zoom',
#        'Google Chat;Slack;Unify Circuit;Zoom',
#        'Cisco Webex Teams;Google Chat;Mattermost;Microsoft Teams;Slack',
#        'Cisco Webex Teams;Google Chat;Slack;Unify Circuit;Zoom',
#        'Cisco Webex Teams;Coolfire Core;Google Chat;Mattermost',
#        'Cisco Webex Teams;Microsoft Teams;Wire;Zoom',
#        'Google Chat;RingCentral;Slack;Symphony;Zoom',
#        'Coolfire Core;Mattermost;RingCentral;Slack;Wickr;Wire',
#        'Cisco Webex Teams;Wickr',
#        'Microsoft Teams;RingCentral;Rocketchat;Slack',
#        'Cisco Webex Teams;Google Chat;RingCentral;Slack;Zoom',
#        'Coolfire Core;Google Chat;Mattermost;Microsoft Teams;RingCentral;Rocketchat;Slack;Symphony;Unify Circuit;Wickr;Wire;Zoom',
#        'Mattermost;Microsoft Teams;RingCentral;Slack;Zoom',
#        'Microsoft Teams;Unify Circuit;Zoom',
#        'RingCentral;Rocketchat;Slack;Zoom',
#        'Cisco Webex Teams;Mattermost;Rocketchat;Slack',
#        'Cisco Webex Teams;RingCentral;Slack',
#        'Cisco Webex Teams;Google Chat;Microsoft Teams;Slack;Wickr',
#        'Google Chat;Mattermost;Rocketchat;Slack',
#        'Cisco Webex Teams;Google Chat;Rocketchat;Slack;Symphony;Wickr;Zoom',
#        'Cisco Webex Teams;Google Chat;Microsoft Teams;RingCentral;Symphony;Wire;Zoom',
#        'Google Chat;Mattermost;Rocketchat', 'Slack;Wickr;Wire;Zoom',
#        'Google Chat;Microsoft Teams;Slack;Symphony', 'Wickr;Wire;Zoom',
#        'Google Chat;Slack;Wickr',
#        'Google Chat;Mattermost;Microsoft Teams;Rocketchat',
#        'Cisco Webex Teams;Microsoft Teams;Slack;Symphony;Unify Circuit',
#        'Coolfire Core;Mattermost;RingCentral;Symphony;Wickr;Wire',
#        'Cisco Webex Teams;Coolfire Core;Google Chat;Microsoft Teams;Zoom',
#        'Cisco Webex Teams;Microsoft Teams;RingCentral;Wickr;Zoom',
#        'Google Chat;Mattermost;Microsoft Teams;Slack;Wickr;Zoom',
#        'Coolfire Core;Google Chat;Microsoft Teams;Zoom',
#        'RingCentral;Rocketchat;Slack;Symphony;Unify Circuit;Wickr;Wire;Zoom',
#        'Cisco Webex Teams;Microsoft Teams;Rocketchat;Wire;Zoom',
#        'Cisco Webex Teams;Microsoft Teams;Rocketchat;Slack;Wire',
#        'Microsoft Teams;Slack;Symphony', 'Coolfire Core',
#        'Cisco Webex Teams;Coolfire Core;Mattermost;Microsoft Teams;RingCentral;Unify Circuit;Wickr;Wire;Zoom',
#        'Google Chat;Mattermost;Wire;Zoom',
#        'Google Chat;Mattermost;Slack;Symphony;Unify Circuit;Wickr;Wire;Zoom',
#        'Cisco Webex Teams;Google Chat;RingCentral;Slack;Unify Circuit',
#        'Google Chat;Microsoft Teams;RingCentral;Slack',
#        'Google Chat;Microsoft Teams;Slack;Unify Circuit',
#        'Google Chat;Mattermost;RingCentral;Slack;Wire;Zoom',
#        'Google Chat;Mattermost;Microsoft Teams;Symphony;Zoom',
#        'Cisco Webex Teams;Microsoft Teams;Rocketchat;Slack',
#        'Cisco Webex Teams;Google Chat;RingCentral',
#        'RingCentral;Rocketchat;Slack;Symphony;Wire;Zoom',
#        'Cisco Webex Teams;Microsoft Teams;Unify Circuit',
#        'Google Chat;Microsoft Teams;RingCentral;Symphony;Zoom',
#        'Rocketchat;Unify Circuit;Wickr',
#        'Cisco Webex Teams;Coolfire Core;Google Chat;Microsoft Teams;RingCentral;Slack;Unify Circuit;Wickr;Wire;Zoom',
#        'Microsoft Teams;Slack;Unify Circuit;Zoom',
#        'Cisco Webex Teams;Coolfire Core;Google Chat',
#        'Cisco Webex Teams;Unify Circuit',
#        'Coolfire Core;Google Chat;Unify Circuit;Wickr;Wire;Zoom',
#        'Cisco Webex Teams;Symphony;Unify Circuit;Wire', 'Mattermost;Wire',
#        'Cisco Webex Teams;Coolfire Core;Google Chat;Microsoft Teams;Slack;Zoom',
#        'Google Chat;Mattermost;Rocketchat;Slack;Symphony;Unify Circuit;Wickr;Zoom',
#        'Cisco Webex Teams;Microsoft Teams;RingCentral;Slack;Symphony;Zoom',
#        'Cisco Webex Teams;Google Chat;Mattermost;Microsoft Teams;Rocketchat;Slack',
#        'Cisco Webex Teams;Coolfire Core;Google Chat;Microsoft Teams;Rocketchat;Slack;Unify Circuit;Zoom',
#        'Cisco Webex Teams;Coolfire Core;Google Chat;Microsoft Teams;RingCentral;Rocketchat;Slack;Symphony;Unify Circuit;Wire;Zoom',
#        'Cisco Webex Teams;Coolfire Core;Microsoft Teams;Slack;Wire;Zoom',
#        'Coolfire Core;Microsoft Teams;Symphony',
#        'Microsoft Teams;Rocketchat;Wire;Zoom',
#        'Google Chat;Microsoft Teams;Rocketchat;Wickr',
#        'Cisco Webex Teams;Google Chat;Microsoft Teams;Slack;Wire',
#        'Rocketchat;Wire', 'Coolfire Core;Microsoft Teams;Zoom',
#        'Mattermost;Slack;Wire', 'Rocketchat;Unify Circuit;Zoom',
#        'Cisco Webex Teams;Mattermost;Microsoft Teams;Slack;Symphony;Zoom',
#        'Cisco Webex Teams;Google Chat;Microsoft Teams;Symphony;Zoom',
#        'Cisco Webex Teams;Google Chat;Microsoft Teams;Rocketchat;Slack;Symphony;Unify Circuit;Wickr;Wire;Zoom',
#        'Cisco Webex Teams;Google Chat;Microsoft Teams;Slack;Unify Circuit',
#        'Slack;Unify Circuit;Zoom',
#        'Cisco Webex Teams;Mattermost;Symphony',
#        'Cisco Webex Teams;Coolfire Core;Google Chat;Mattermost;Microsoft Teams;RingCentral;Slack;Symphony;Unify Circuit;Wickr;Wire;Zoom',
#        'Cisco Webex Teams;Rocketchat;Slack;Unify Circuit;Wickr;Wire;Zoom',
#        'Coolfire Core;Wire',
#        'Google Chat;Microsoft Teams;RingCentral;Rocketchat;Unify Circuit',
#        'Google Chat;Wickr;Zoom', 'Mattermost;Symphony',
#        'Cisco Webex Teams;Google Chat;Microsoft Teams;RingCentral;Wire;Zoom',
#        'Cisco Webex Teams;Google Chat;Microsoft Teams;Rocketchat;Slack',
#        'Google Chat;Microsoft Teams;RingCentral;Rocketchat;Slack;Symphony;Unify Circuit;Wickr;Wire;Zoom',
#        'Cisco Webex Teams;Mattermost;Rocketchat', 'Symphony;Wire;Zoom',
#        'Cisco Webex Teams;Google Chat;Microsoft Teams;RingCentral;Rocketchat;Slack;Zoom',
#        'Google Chat;Microsoft Teams;Wickr;Wire',
#        'Google Chat;Slack;Wickr;Wire;Zoom',
#        'Coolfire Core;Google Chat;RingCentral;Wickr',
#        'Cisco Webex Teams;Google Chat;Mattermost;Microsoft Teams;Rocketchat;Slack;Symphony;Wire;Zoom',
#        'Google Chat;Unify Circuit;Wire;Zoom',
#        'Mattermost;RingCentral;Zoom',
#        'Cisco Webex Teams;Microsoft Teams;Rocketchat;Slack;Wire;Zoom',
#        'Google Chat;Slack;Symphony;Wire;Zoom',
#        'Cisco Webex Teams;Microsoft Teams;Rocketchat;Symphony;Zoom',
#        'Cisco Webex Teams;Google Chat;Mattermost;Microsoft Teams;Slack;Unify Circuit;Zoom',
#        'Google Chat;Mattermost;Microsoft Teams;Slack;Wickr;Wire;Zoom',
#        'Cisco Webex Teams;Google Chat;Mattermost;Rocketchat',
#        'Cisco Webex Teams;Coolfire Core;Google Chat;Mattermost;Microsoft Teams;RingCentral;Rocketchat;Slack;Symphony;Unify Circuit;Wickr;Wire',
#        'Cisco Webex Teams;Google Chat;Mattermost;Microsoft Teams;Symphony;Zoom',
#        'Cisco Webex Teams;Coolfire Core;Google Chat;Microsoft Teams;RingCentral;Rocketchat;Zoom',
#        'Cisco Webex Teams;Mattermost;Microsoft Teams;Symphony;Wire;Zoom',
#        'Google Chat;RingCentral;Rocketchat;Slack;Zoom',
#        'Cisco Webex Teams;Coolfire Core;Google Chat;Mattermost;Microsoft Teams;Rocketchat;Slack;Symphony;Unify Circuit;Wire;Zoom',
#        'Google Chat;Mattermost;Microsoft Teams;RingCentral;Rocketchat;Slack;Symphony;Unify Circuit;Wickr;Wire;Zoom',
#        'Symphony;Unify Circuit', 'Cisco Webex Teams;RingCentral;Zoom',
#        'Cisco Webex Teams;Mattermost;Microsoft Teams;RingCentral;Slack;Zoom',
#        'Cisco Webex Teams;Google Chat;Microsoft Teams;Slack;Unify Circuit;Wire;Zoom'],
#       dtype=object)

# %%
df['Blockchain'].unique()
# Out:
# array([nan, 'Very unfavorable', 'Unfavorable', 'Favorable',
#        'Very favorable', 'Indifferent', 'Unsure'], dtype=object)

# %% [markdown]
# Aqui termina a limpeza da segunda seção do formulário
#
# -----

# %% [markdown]
# ## Terceira seção
#
# Questões 33 a 37

# %%
df.drop('NEWSOSites', axis=1, inplace=True)

# %%
df['SOVisitFreq'].unique()
# Out:
# array([nan, 'Daily or almost daily', 'Multiple times per day',
#        'A few times per week', 'A few times per month or weekly',
#        'Less than once per month or monthly'], dtype=object)

# %%
df['SOVisitFreq'] = df['SOVisitFreq'].replace({
  "Daily or almost daily": 'daily',
  "Multiple times per day": 'multiple_day',
  "A few times per week": 'multiple_week',
  "A few times per month or weekly": 'weekly',
  "Less than once per month or monthly": 'monthly'
})

# %%
df.drop('SOAccount', axis=1, inplace=True)
df.drop('SOPartFreq', axis=1, inplace=True)
df.drop('SOComm', axis=1, inplace=True)

# %% [markdown]
# Aqui termina a limpeza da terceira seção do formulário
#
# -----

# %% [markdown]
# ## Quarta seção
#
# Questões 38 a 44

# %%
df['Age'].unique()
# Out:
# array([nan, '25-34 years old', '35-44 years old', 'Under 18 years old',
#        '18-24 years old', '45-54 years old', '55-64 years old',
#        '65 years or older', 'Prefer not to say'], dtype=object)

# %%
df['Age'] = df['Age'].replace({
  'Prefer not to say': 'opt_out'
})

# %%
df['Gender'].unique()
# Out:
# array([nan, 'Man', 'Or, in your own words:', 'Woman',
#        'Non-binary, genderqueer, or gender non-conforming',
#        'Prefer not to say',
#        'Man;Non-binary, genderqueer, or gender non-conforming',
#        'Or, in your own words:;Non-binary, genderqueer, or gender non-conforming',
#        'Woman;Non-binary, genderqueer, or gender non-conforming',
#        'Man;Woman', 'Man;Or, in your own words:',
#        'Or, in your own words:;Woman;Non-binary, genderqueer, or gender non-conforming',
#        'Man;Woman;Non-binary, genderqueer, or gender non-conforming',
#        'Or, in your own words:;Woman',
#        'Man;Or, in your own words:;Woman;Non-binary, genderqueer, or gender non-conforming',
#        'Man;Or, in your own words:;Non-binary, genderqueer, or gender non-conforming',
#        'Man;Or, in your own words:;Woman'], dtype=object)

# %%
df['Gender'] = df['Gender'].str.replace('Or, in your own words:', 'other', regex=True)
df['Gender'] = df['Gender'].str.replace('Prefer not to say', 'opt_out', regex=True)
df['Gender'] = df['Gender'].str.replace('Non-binary, genderqueer, or gender non-conforming', 'non_binary', regex=True)

df['Gender'] = df['Gender'].str.lower().str.replace(', ', '_').str.replace('-', '_').str.replace(' ', '_')

df['Gender'].unique()
# Out:
# array([nan, 'man', 'other', 'woman', 'non_binary', 'opt_out',
#        'man;non_binary', 'other;non_binary', 'woman;non_binary',
#        'man;woman', 'man;other', 'other;woman;non_binary',
#        'man;woman;non_binary', 'other;woman',
#        'man;other;woman;non_binary', 'man;other;non_binary',
#        'man;other;woman'], dtype=object)

# %%
df['Trans'].unique()
# Out:
# array([nan, 'No', 'Or, in your own words:', 'Yes', 'Prefer not to say'],
#       dtype=object)

# %%
df['Trans'] = df['Trans'].replace({
  'Or, in your own words:', 'other',
  'Prefer not to say', 'opt_out'
})


df['Trans'] = df['Trans'].str.lower().str.replace(', ', '_').str.replace('-', '_').str.replace(' ', '_')

# %%
df['Sexuality'].unique()
# Out:
# array([nan, 'Bisexual', 'Straight / Heterosexual',
#        'Prefer to self-describe:', 'Bisexual;Straight / Heterosexual',
#        'Gay or Lesbian', 'Prefer to self-describe:;Queer',
#        'Prefer not to say', 'Queer', 'Straight / Heterosexual;Queer',
#        'Straight / Heterosexual;Prefer to self-describe:',
#        'Bisexual;Queer', 'Bisexual;Gay or Lesbian',
#        'Gay or Lesbian;Queer',
#        'Bisexual;Straight / Heterosexual;Prefer to self-describe:;Queer',
#        'Bisexual;Prefer to self-describe:',
#        'Prefer to self-describe:;Gay or Lesbian;Queer',
#        'Straight / Heterosexual;Prefer to self-describe:;Queer',
#        'Bisexual;Straight / Heterosexual;Gay or Lesbian',
#        'Bisexual;Straight / Heterosexual;Prefer to self-describe:;Gay or Lesbian;Queer',
#        'Bisexual;Straight / Heterosexual;Queer',
#        'Bisexual;Gay or Lesbian;Queer',
#        'Bisexual;Prefer to self-describe:;Queer',
#        'Bisexual;Prefer to self-describe:;Gay or Lesbian',
#        'Straight / Heterosexual;Gay or Lesbian',
#        'Prefer to self-describe:;Gay or Lesbian',
#        'Bisexual;Straight / Heterosexual;Prefer to self-describe:',
#        'Bisexual;Straight / Heterosexual;Gay or Lesbian;Queer',
#        'Straight / Heterosexual;Gay or Lesbian;Queer',
#        'Straight / Heterosexual;Prefer to self-describe:;Gay or Lesbian;Queer',
#        'Bisexual;Straight / Heterosexual;Prefer to self-describe:;Gay or Lesbian',
#        'Bisexual;Prefer to self-describe:;Gay or Lesbian;Queer',
#        'Straight / Heterosexual;Prefer to self-describe:;Gay or Lesbian'],
#       dtype=object)

# %%
df['Sexuality'] = df['Sexuality'].str.replace('Straight / Heterosexual', 'heterosexual', regex=True)
df['Sexuality'] = df['Sexuality'].str.replace('Gay or Lesbian', 'homosexual', regex=True)
df['Sexuality'] = df['Sexuality'].str.replace('Prefer to self-describe:', 'other', regex=True)
df['Sexuality'] = df['Sexuality'].str.replace('Prefer not to say', 'opt_out', regex=True)

df['Sexuality'] = df['Sexuality'].str.lower().str.replace(', ', '_').str.replace('-', '_').str.replace(' ', '_')
df['Sexuality'].unique()
# Out:
# array([nan, 'bisexual', 'heterosexual', 'other', 'bisexual;heterosexual',
#        'homosexual', 'other;queer', 'opt_out', 'queer',
#        'heterosexual;queer', 'heterosexual;other', 'bisexual;queer',
#        'bisexual;homosexual', 'homosexual;queer',
#        'bisexual;heterosexual;other;queer', 'bisexual;other',
#        'other;homosexual;queer', 'heterosexual;other;queer',
#        'bisexual;heterosexual;homosexual',
#        'bisexual;heterosexual;other;homosexual;queer',
#        'bisexual;heterosexual;queer', 'bisexual;homosexual;queer',
#        'bisexual;other;queer', 'bisexual;other;homosexual',
#        'heterosexual;homosexual', 'other;homosexual',
#        'bisexual;heterosexual;other',
#        'bisexual;heterosexual;homosexual;queer',
#        'heterosexual;homosexual;queer',
#        'heterosexual;other;homosexual;queer',
#        'bisexual;heterosexual;other;homosexual',
#        'bisexual;other;homosexual;queer', 'heterosexual;other;homosexual'],
#       dtype=object)

# %%
df['Ethnicity'].unique()
# Out:
# array([nan, 'White', 'Or, in your own words:', ...,
#        'White;European;North American;Middle Eastern;Asian;Multiracial',
#        'White;Middle Eastern;Central American;Hispanic or Latino/a',
#        'White;European;North African;Hispanic or Latino/a'], dtype=object)

# %%
df['Ethnicity'] = df['Ethnicity'].str.replace("Hispanic or Latino/a", 'hispanic_or_latino', regex=True)
df['Ethnicity'] = df['Ethnicity'].str.replace("I don't know", 'dont_know', regex=True)
df['Ethnicity'] = df['Ethnicity'].str.replace('Or, in your own words:', 'other', regex=True)
df['Ethnicity'] = df['Ethnicity'].str.replace('Prefer not to say', 'opt_out', regex=True)
# remove os parênteses e tudo que tem dentro
df['Ethnicity'] = df['Ethnicity'].str.replace(r"\(.*\)","")

df['Ethnicity'] = df['Ethnicity'].str.lower().str.replace(', ', '_').str.replace('-', '_').str.replace(' ', '_')
# Out:
# C:\Users\nicbu\AppData\Local\Temp\ipykernel_18592\1922211337.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Ethnicity'] = df['Ethnicity'].str.replace(r"\(.*\)","")

# %%
df['Accessibility'].unique()
# Out:
# array([nan, 'None of the above', 'Or, in your own words:',
#        'I am deaf / hard of hearing', 'Prefer not to say',
#        'I am blind / have difficulty seeing',
#        'I am unable to / find it difficult to type',
#        'I am unable to / find it difficult to walk or stand without assistance',
#        'Or, in your own words:;I am blind / have difficulty seeing',
#        'I am unable to / find it difficult to type;I am unable to / find it difficult to walk or stand without assistance',
#        'I am deaf / hard of hearing;I am unable to / find it difficult to walk or stand without assistance',
#        'I am deaf / hard of hearing;I am blind / have difficulty seeing',
#        'I am deaf / hard of hearing;I am blind / have difficulty seeing;I am unable to / find it difficult to type;I am unable to / find it difficult to walk or stand without assistance',
#        'Or, in your own words:;I am deaf / hard of hearing;I am blind / have difficulty seeing',
#        'I am blind / have difficulty seeing;I am unable to / find it difficult to walk or stand without assistance',
#        'I am deaf / hard of hearing;I am unable to / find it difficult to type',
#        'Or, in your own words:;I am unable to / find it difficult to walk or stand without assistance',
#        'I am blind / have difficulty seeing;I am unable to / find it difficult to type',
#        'Or, in your own words:;I am deaf / hard of hearing',
#        'Or, in your own words:;I am deaf / hard of hearing;I am blind / have difficulty seeing;I am unable to / find it difficult to type;I am unable to / find it difficult to walk or stand without assistance',
#        'I am deaf / hard of hearing;I am blind / have difficulty seeing;I am unable to / find it difficult to walk or stand without assistance',
#        'Or, in your own words:;I am blind / have difficulty seeing;I am unable to / find it difficult to type;I am unable to / find it difficult to walk or stand without assistance',
#        'I am deaf / hard of hearing;I am blind / have difficulty seeing;I am unable to / find it difficult to type',
#        'Or, in your own words:;I am deaf / hard of hearing;I am blind / have difficulty seeing;I am unable to / find it difficult to type',
#        'Or, in your own words:;I am unable to / find it difficult to type',
#        'Or, in your own words:;I am blind / have difficulty seeing;I am unable to / find it difficult to type',
#        'I am deaf / hard of hearing;I am unable to / find it difficult to type;I am unable to / find it difficult to walk or stand without assistance',
#        'Or, in your own words:;I am unable to / find it difficult to type;I am unable to / find it difficult to walk or stand without assistance'],
#       dtype=object)

# %%
df['Accessibility'] = df['Accessibility'].str.replace("I am deaf / hard of hearing", 'hearing', regex=True)
df['Accessibility'] = df['Accessibility'].str.replace("I am blind / have difficulty seeing", 'seeing', regex=True)
df['Accessibility'] = df['Accessibility'].str.replace("I am unable to / find it difficult to type", 'typing', regex=True)
df['Accessibility'] = df['Accessibility'].str.replace("I am unable to / find it difficult to walk or stand without assistance", 'walking', regex=True)
df['Accessibility'] = df['Accessibility'].str.replace("None of the above", 'none', regex=True)
df['Accessibility'] = df['Accessibility'].str.replace('Or, in your own words:', 'other', regex=True)
df['Accessibility'] = df['Accessibility'].str.replace('Prefer not to say', 'opt_out', regex=True)

df['Accessibility'] = df['Accessibility'].str.lower().str.replace(', ', '_').str.replace('-', '_').str.replace(' ', '_')

df['Accessibility'].unique()
# Out:
# array([nan, 'none', 'other', 'hearing', 'opt_out', 'seeing', 'typing',
#        'walking', 'other;seeing', 'typing;walking', 'hearing;walking',
#        'hearing;seeing', 'hearing;seeing;typing;walking',
#        'other;hearing;seeing', 'seeing;walking', 'hearing;typing',
#        'other;walking', 'seeing;typing', 'other;hearing',
#        'other;hearing;seeing;typing;walking', 'hearing;seeing;walking',
#        'other;seeing;typing;walking', 'hearing;seeing;typing',
#        'other;hearing;seeing;typing', 'other;typing',
#        'other;seeing;typing', 'hearing;typing;walking',
#        'other;typing;walking'], dtype=object)

# %%
df['MentalHealth'].unique()
# Out:
# array([nan,
#        'I have a mood or emotional disorder (e.g., depression, bipolar disorder, etc.);I have an anxiety disorder',
#        'None of the above', 'Or, in your own words:',
#        'I have a mood or emotional disorder (e.g., depression, bipolar disorder, etc.)',
#        'I have a mood or emotional disorder (e.g., depression, bipolar disorder, etc.);I have an anxiety disorder;I have a concentration and/or memory disorder (e.g., ADHD, etc.)',
#        'I have a concentration and/or memory disorder (e.g., ADHD, etc.);I have learning differences (e.g., Dyslexic, Dyslexia, etc.)',
#        'I have an anxiety disorder',
#        "I have autism / an autism spectrum disorder (e.g. Asperger's, etc.)",
#        'I have learning differences (e.g., Dyslexic, Dyslexia, etc.)',
#        'I have a concentration and/or memory disorder (e.g., ADHD, etc.)',
#        'I have an anxiety disorder;I have a concentration and/or memory disorder (e.g., ADHD, etc.)',
#        'Prefer not to say',
#        "I have a concentration and/or memory disorder (e.g., ADHD, etc.);I have learning differences (e.g., Dyslexic, Dyslexia, etc.);I have autism / an autism spectrum disorder (e.g. Asperger's, etc.)",
#        "I have a mood or emotional disorder (e.g., depression, bipolar disorder, etc.);I have a concentration and/or memory disorder (e.g., ADHD, etc.);I have autism / an autism spectrum disorder (e.g. Asperger's, etc.)",
#        'I have an anxiety disorder;Or, in your own words:',
#        "I have a mood or emotional disorder (e.g., depression, bipolar disorder, etc.);I have an anxiety disorder;I have a concentration and/or memory disorder (e.g., ADHD, etc.);I have autism / an autism spectrum disorder (e.g. Asperger's, etc.)",
#        "I have a mood or emotional disorder (e.g., depression, bipolar disorder, etc.);I have autism / an autism spectrum disorder (e.g. Asperger's, etc.)",
#        "I have a concentration and/or memory disorder (e.g., ADHD, etc.);I have autism / an autism spectrum disorder (e.g. Asperger's, etc.)",
#        'Or, in your own words:;I have a concentration and/or memory disorder (e.g., ADHD, etc.)',
#        'I have a mood or emotional disorder (e.g., depression, bipolar disorder, etc.);I have an anxiety disorder;I have a concentration and/or memory disorder (e.g., ADHD, etc.);I have learning differences (e.g., Dyslexic, Dyslexia, etc.)',
#        "I have a mood or emotional disorder (e.g., depression, bipolar disorder, etc.);I have an anxiety disorder;I have autism / an autism spectrum disorder (e.g. Asperger's, etc.)",
#        'I have a mood or emotional disorder (e.g., depression, bipolar disorder, etc.);I have a concentration and/or memory disorder (e.g., ADHD, etc.)',
#        "I have an anxiety disorder;I have a concentration and/or memory disorder (e.g., ADHD, etc.);I have learning differences (e.g., Dyslexic, Dyslexia, etc.);I have autism / an autism spectrum disorder (e.g. Asperger's, etc.)",
#        "I have an anxiety disorder;I have a concentration and/or memory disorder (e.g., ADHD, etc.);I have autism / an autism spectrum disorder (e.g. Asperger's, etc.)",
#        "I have an anxiety disorder;I have autism / an autism spectrum disorder (e.g. Asperger's, etc.)",
#        'I have an anxiety disorder;I have learning differences (e.g., Dyslexic, Dyslexia, etc.)',
#        'I have a mood or emotional disorder (e.g., depression, bipolar disorder, etc.);I have an anxiety disorder;I have learning differences (e.g., Dyslexic, Dyslexia, etc.)',
#        "Or, in your own words:;I have autism / an autism spectrum disorder (e.g. Asperger's, etc.)",
#        'I have a mood or emotional disorder (e.g., depression, bipolar disorder, etc.);I have learning differences (e.g., Dyslexic, Dyslexia, etc.)',
#        "I have learning differences (e.g., Dyslexic, Dyslexia, etc.);I have autism / an autism spectrum disorder (e.g. Asperger's, etc.)",
#        "I have a mood or emotional disorder (e.g., depression, bipolar disorder, etc.);I have an anxiety disorder;I have a concentration and/or memory disorder (e.g., ADHD, etc.);I have learning differences (e.g., Dyslexic, Dyslexia, etc.);I have autism / an autism spectrum disorder (e.g. Asperger's, etc.)",
#        'I have a mood or emotional disorder (e.g., depression, bipolar disorder, etc.);I have an anxiety disorder;Or, in your own words:',
#        'I have a mood or emotional disorder (e.g., depression, bipolar disorder, etc.);Or, in your own words:',
#        "I have a mood or emotional disorder (e.g., depression, bipolar disorder, etc.);I have learning differences (e.g., Dyslexic, Dyslexia, etc.);I have autism / an autism spectrum disorder (e.g. Asperger's, etc.)",
#        'I have a mood or emotional disorder (e.g., depression, bipolar disorder, etc.);I have a concentration and/or memory disorder (e.g., ADHD, etc.);I have learning differences (e.g., Dyslexic, Dyslexia, etc.)',
#        'I have an anxiety disorder;I have a concentration and/or memory disorder (e.g., ADHD, etc.);I have learning differences (e.g., Dyslexic, Dyslexia, etc.)',
#        "I have a mood or emotional disorder (e.g., depression, bipolar disorder, etc.);I have an anxiety disorder;I have learning differences (e.g., Dyslexic, Dyslexia, etc.);I have autism / an autism spectrum disorder (e.g. Asperger's, etc.)",
#        'I have a mood or emotional disorder (e.g., depression, bipolar disorder, etc.);I have an anxiety disorder;Or, in your own words:;I have a concentration and/or memory disorder (e.g., ADHD, etc.)',
#        "I have a mood or emotional disorder (e.g., depression, bipolar disorder, etc.);I have an anxiety disorder;Or, in your own words:;I have a concentration and/or memory disorder (e.g., ADHD, etc.);I have autism / an autism spectrum disorder (e.g. Asperger's, etc.)",
#        "I have a mood or emotional disorder (e.g., depression, bipolar disorder, etc.);I have a concentration and/or memory disorder (e.g., ADHD, etc.);I have learning differences (e.g., Dyslexic, Dyslexia, etc.);I have autism / an autism spectrum disorder (e.g. Asperger's, etc.)",
#        "I have a mood or emotional disorder (e.g., depression, bipolar disorder, etc.);Or, in your own words:;I have autism / an autism spectrum disorder (e.g. Asperger's, etc.)",
#        'I have a mood or emotional disorder (e.g., depression, bipolar disorder, etc.);Or, in your own words:;I have a concentration and/or memory disorder (e.g., ADHD, etc.)',
#        "I have a mood or emotional disorder (e.g., depression, bipolar disorder, etc.);I have an anxiety disorder;Or, in your own words:;I have autism / an autism spectrum disorder (e.g. Asperger's, etc.)",
#        'I have a mood or emotional disorder (e.g., depression, bipolar disorder, etc.);Or, in your own words:;I have learning differences (e.g., Dyslexic, Dyslexia, etc.)',
#        "I have an anxiety disorder;I have learning differences (e.g., Dyslexic, Dyslexia, etc.);I have autism / an autism spectrum disorder (e.g. Asperger's, etc.)",
#        "I have a mood or emotional disorder (e.g., depression, bipolar disorder, etc.);I have an anxiety disorder;Or, in your own words:;I have a concentration and/or memory disorder (e.g., ADHD, etc.);I have learning differences (e.g., Dyslexic, Dyslexia, etc.);I have autism / an autism spectrum disorder (e.g. Asperger's, etc.)",
#        "I have a mood or emotional disorder (e.g., depression, bipolar disorder, etc.);Or, in your own words:;I have a concentration and/or memory disorder (e.g., ADHD, etc.);I have autism / an autism spectrum disorder (e.g. Asperger's, etc.)",
#        "Or, in your own words:;I have learning differences (e.g., Dyslexic, Dyslexia, etc.);I have autism / an autism spectrum disorder (e.g. Asperger's, etc.)",
#        "I have an anxiety disorder;Or, in your own words:;I have a concentration and/or memory disorder (e.g., ADHD, etc.);I have autism / an autism spectrum disorder (e.g. Asperger's, etc.)",
#        'I have a mood or emotional disorder (e.g., depression, bipolar disorder, etc.);I have an anxiety disorder;Or, in your own words:;I have learning differences (e.g., Dyslexic, Dyslexia, etc.)',
#        'Or, in your own words:;I have learning differences (e.g., Dyslexic, Dyslexia, etc.)',
#        "Or, in your own words:;I have a concentration and/or memory disorder (e.g., ADHD, etc.);I have autism / an autism spectrum disorder (e.g. Asperger's, etc.)",
#        'I have an anxiety disorder;Or, in your own words:;I have learning differences (e.g., Dyslexic, Dyslexia, etc.)',
#        'I have a mood or emotional disorder (e.g., depression, bipolar disorder, etc.);I have an anxiety disorder;Or, in your own words:;I have a concentration and/or memory disorder (e.g., ADHD, etc.);I have learning differences (e.g., Dyslexic, Dyslexia, etc.)',
#        "Or, in your own words:;I have a concentration and/or memory disorder (e.g., ADHD, etc.);I have learning differences (e.g., Dyslexic, Dyslexia, etc.);I have autism / an autism spectrum disorder (e.g. Asperger's, etc.)",
#        'I have an anxiety disorder;Or, in your own words:;I have a concentration and/or memory disorder (e.g., ADHD, etc.)',
#        'Or, in your own words:;I have a concentration and/or memory disorder (e.g., ADHD, etc.);I have learning differences (e.g., Dyslexic, Dyslexia, etc.)'],
#       dtype=object)

# %%
df['MentalHealth'] = df['MentalHealth'].str.replace("I have a mood or emotional disorder \(e.g., depression, bipolar disorder, etc.\)", 'emotional', regex=True)
df['MentalHealth'] = df['MentalHealth'].str.replace("I have an anxiety disorder", 'anxiety', regex=True)
df['MentalHealth'] = df['MentalHealth'].str.replace("I have a concentration and/or memory disorder \(e.g., ADHD, etc.\)", 'concentration', regex=True)
df['MentalHealth'] = df['MentalHealth'].str.replace("I have learning differences \(e.g., Dyslexic, Dyslexia, etc.\)", 'learning', regex=True)
df['MentalHealth'] = df['MentalHealth'].str.replace("I have autism / an autism spectrum disorder \(e.g. Asperger's, etc.\)", 'autism', regex=True)
df['MentalHealth'] = df['MentalHealth'].str.replace("None of the above", 'none', regex=True)
df['MentalHealth'] = df['MentalHealth'].str.replace('Or, in your own words:', 'other', regex=True)
df['MentalHealth'] = df['MentalHealth'].str.replace('Prefer not to say', 'opt_out', regex=True)

df['MentalHealth'] = df['MentalHealth'].str.lower().str.replace(', ', '_').str.replace('-', '_').str.replace(' ', '_')

df['MentalHealth'].unique()
# Out:
# array([nan, 'emotional;anxiety', 'none', 'other', 'emotional',
#        'emotional;anxiety;concentration', 'concentration;learning',
#        'anxiety', 'autism', 'learning', 'concentration',
#        'anxiety;concentration', 'opt_out',
#        'concentration;learning;autism', 'emotional;concentration;autism',
#        'anxiety;other', 'emotional;anxiety;concentration;autism',
#        'emotional;autism', 'concentration;autism', 'other;concentration',
#        'emotional;anxiety;concentration;learning',
#        'emotional;anxiety;autism', 'emotional;concentration',
#        'anxiety;concentration;learning;autism',
#        'anxiety;concentration;autism', 'anxiety;autism',
#        'anxiety;learning', 'emotional;anxiety;learning', 'other;autism',
#        'emotional;learning', 'learning;autism',
#        'emotional;anxiety;concentration;learning;autism',
#        'emotional;anxiety;other', 'emotional;other',
#        'emotional;learning;autism', 'emotional;concentration;learning',
#        'anxiety;concentration;learning',
#        'emotional;anxiety;learning;autism',
#        'emotional;anxiety;other;concentration',
#        'emotional;anxiety;other;concentration;autism',
#        'emotional;concentration;learning;autism',
#        'emotional;other;autism', 'emotional;other;concentration',
#        'emotional;anxiety;other;autism', 'emotional;other;learning',
#        'anxiety;learning;autism',
#        'emotional;anxiety;other;concentration;learning;autism',
#        'emotional;other;concentration;autism', 'other;learning;autism',
#        'anxiety;other;concentration;autism',
#        'emotional;anxiety;other;learning', 'other;learning',
#        'other;concentration;autism', 'anxiety;other;learning',
#        'emotional;anxiety;other;concentration;learning',
#        'other;concentration;learning;autism',
#        'anxiety;other;concentration', 'other;concentration;learning'],
#       dtype=object)

# %% [markdown]
# Aqui termina a limpeza da quarta seção do formulário
#
# -----

# %% [markdown]
# ## Quinta seção
#
# Questões 45 a 54

# %%
df.drop('TBranch', axis=1, inplace=True)

# %% [markdown]
# Notar que essa seção só foi respondida por quem é elegível, e optou que sim na questão anterior (TBranch)

# %%
df['ICorPM'].unique()
# Out:
# array([nan, 'Independent contributor', 'People manager'], dtype=object)

# %%
df['ICorPM'] = df['ICorPM'].str.lower().str.replace(' ', '_')

# %%
df['WorkExp'].unique()
# Out:
# array([nan,  6., 14.,  5., 15.,  4., 23.,  9., 22., 21.,  3., 28.,  7.,
#        12.,  8.,  2., 20., 27.,  1., 10., 19., 13., 30., 11., 18., 47.,
#        17., 46., 25., 24., 31.,  0., 41., 43., 40., 16., 42., 35., 32.,
#        34., 26., 36., 38., 29., 33., 44., 37., 50., 45., 39., 48., 49.])

# %%
df.drop('Knowledge_1', axis=1, inplace=True)
df.drop('Knowledge_2', axis=1, inplace=True)
df.drop('Knowledge_3', axis=1, inplace=True)
df.drop('Knowledge_4', axis=1, inplace=True)
df.drop('Knowledge_5', axis=1, inplace=True)
df.drop('Knowledge_6', axis=1, inplace=True)
df.drop('Knowledge_7', axis=1, inplace=True)

df.drop('Frequency_1', axis=1, inplace=True)
df.drop('Frequency_2', axis=1, inplace=True)
df.drop('Frequency_3', axis=1, inplace=True)

# %%
df['TimeSearching'].unique()
# Out:
# array([nan, '15-30 minutes a day', '30-60 minutes a day',
#        '60-120 minutes a day', 'Less than 15 minutes a day',
#        'Over 120 minutes a day'], dtype=object)

# %%
df['TimeAnswering'].unique()
# Out:
# array([nan, 'Over 120 minutes a day', '60-120 minutes a day',
#        'Less than 15 minutes a day', '30-60 minutes a day',
#        '15-30 minutes a day'], dtype=object)

# %%
df.drop('Onboarding', axis=1, inplace=True)

# %%
df['ProfessionalTech'].unique()
# Out:
# array([nan,
#        'Innersource initiative;DevOps function;Microservices;Developer portal or other central places to find tools/services;Continuous integration (CI) and (more often) continuous delivery;Automated testing;Observability tools',
#        'Innersource initiative;DevOps function;Microservices;Continuous integration (CI) and (more often) continuous delivery;Automated testing;Observability tools',
#        'DevOps function;Microservices',
#        'Continuous integration (CI) and (more often) continuous delivery;Automated testing',
#        'DevOps function;Continuous integration (CI) and (more often) continuous delivery;Automated testing',
#        'None of these',
#        'DevOps function;Microservices;Continuous integration (CI) and (more often) continuous delivery;Automated testing;Observability tools',
#        'Developer portal or other central places to find tools/services;Continuous integration (CI) and (more often) continuous delivery;Automated testing',
#        'DevOps function;Continuous integration (CI) and (more often) continuous delivery;Automated testing;Observability tools',
#        'DevOps function',
#        'DevOps function;Developer portal or other central places to find tools/services;Continuous integration (CI) and (more often) continuous delivery;Automated testing;Observability tools',
#        'Microservices',
#        'DevOps function;Microservices;Developer portal or other central places to find tools/services;Automated testing;Observability tools',
#        'Continuous integration (CI) and (more often) continuous delivery;Automated testing;Observability tools',
#        'DevOps function;Microservices;Developer portal or other central places to find tools/services;Continuous integration (CI) and (more often) continuous delivery;Automated testing;Observability tools',
#        'DevOps function;Developer portal or other central places to find tools/services;Continuous integration (CI) and (more often) continuous delivery;Automated testing',
#        'Microservices;Developer portal or other central places to find tools/services;Continuous integration (CI) and (more often) continuous delivery;Automated testing',
#        'Microservices;Continuous integration (CI) and (more often) continuous delivery;Automated testing;Observability tools',
#        'Microservices;Continuous integration (CI) and (more often) continuous delivery',
#        'DevOps function;Microservices;Continuous integration (CI) and (more often) continuous delivery',
#        'Developer portal or other central places to find tools/services;Continuous integration (CI) and (more often) continuous delivery;Observability tools',
#        'Automated testing',
#        'DevOps function;Microservices;Continuous integration (CI) and (more often) continuous delivery;Automated testing',
#        'DevOps function;Developer portal or other central places to find tools/services;Observability tools',
#        'Innersource initiative;DevOps function;Microservices;Developer portal or other central places to find tools/services;Continuous integration (CI) and (more often) continuous delivery;Automated testing',
#        'DevOps function;Continuous integration (CI) and (more often) continuous delivery',
#        'Innersource initiative;DevOps function;Developer portal or other central places to find tools/services',
#        'Microservices;Continuous integration (CI) and (more often) continuous delivery;Automated testing',
#        'DevOps function;Developer portal or other central places to find tools/services;Continuous integration (CI) and (more often) continuous delivery',
#        'Developer portal or other central places to find tools/services;Continuous integration (CI) and (more often) continuous delivery;Automated testing;Observability tools',
#        'DevOps function;Microservices;Developer portal or other central places to find tools/services;Continuous integration (CI) and (more often) continuous delivery;Automated testing',
#        'Microservices;Automated testing;Observability tools',
#        'DevOps function;Microservices;Automated testing',
#        'Continuous integration (CI) and (more often) continuous delivery',
#        'DevOps function;Microservices;Continuous integration (CI) and (more often) continuous delivery;Observability tools',
#        'Microservices;Developer portal or other central places to find tools/services;Continuous integration (CI) and (more often) continuous delivery;Automated testing;Observability tools',
#        'DevOps function;Microservices;Automated testing;Observability tools',
#        'Innersource initiative;DevOps function;Continuous integration (CI) and (more often) continuous delivery;Automated testing',
#        'Developer portal or other central places to find tools/services',
#        'Microservices;Developer portal or other central places to find tools/services;Continuous integration (CI) and (more often) continuous delivery',
#        'Innersource initiative;DevOps function;Microservices;Automated testing',
#        'Developer portal or other central places to find tools/services;Automated testing;Observability tools',
#        'Innersource initiative;DevOps function;Developer portal or other central places to find tools/services;Continuous integration (CI) and (more often) continuous delivery;Automated testing;Observability tools',
#        'DevOps function;Automated testing',
#        'DevOps function;Developer portal or other central places to find tools/services',
#        'Automated testing;None of these',
#        'DevOps function;Continuous integration (CI) and (more often) continuous delivery;Observability tools',
#        'Continuous integration (CI) and (more often) continuous delivery;Observability tools',
#        'Microservices;Continuous integration (CI) and (more often) continuous delivery;Observability tools',
#        'Innersource initiative;DevOps function;Microservices;Continuous integration (CI) and (more often) continuous delivery;Automated testing',
#        'DevOps function;Developer portal or other central places to find tools/services;Continuous integration (CI) and (more often) continuous delivery;Observability tools',
#        'Innersource initiative;DevOps function;Continuous integration (CI) and (more often) continuous delivery;Automated testing;Observability tools',
#        'DevOps function;Microservices;Developer portal or other central places to find tools/services;Continuous integration (CI) and (more often) continuous delivery;Observability tools',
#        'Innersource initiative;Continuous integration (CI) and (more often) continuous delivery;Automated testing;Observability tools',
#        'DevOps function;Microservices;Developer portal or other central places to find tools/services;Continuous integration (CI) and (more often) continuous delivery',
#        'Developer portal or other central places to find tools/services;Observability tools',
#        'Microservices;Observability tools',
#        'Innersource initiative;Developer portal or other central places to find tools/services;Continuous integration (CI) and (more often) continuous delivery;Automated testing',
#        'Innersource initiative;DevOps function',
#        'Microservices;Developer portal or other central places to find tools/services;Automated testing',
#        'Microservices;Automated testing',
#        'Developer portal or other central places to find tools/services;Automated testing',
#        'Innersource initiative;DevOps function;Continuous integration (CI) and (more often) continuous delivery',
#        'Innersource initiative;DevOps function;Microservices;Observability tools',
#        'Microservices;Developer portal or other central places to find tools/services',
#        'Developer portal or other central places to find tools/services;Continuous integration (CI) and (more often) continuous delivery',
#        'DevOps function;Microservices;Developer portal or other central places to find tools/services',
#        'Observability tools', 'DevOps function;Observability tools',
#        'Innersource initiative;DevOps function;Microservices;Developer portal or other central places to find tools/services;Continuous integration (CI) and (more often) continuous delivery;Observability tools',
#        'Innersource initiative;Microservices;Continuous integration (CI) and (more often) continuous delivery;Automated testing;Observability tools',
#        'Innersource initiative', 'Innersource initiative;Microservices',
#        'DevOps function;Microservices;Developer portal or other central places to find tools/services;Automated testing',
#        'Innersource initiative;DevOps function;Developer portal or other central places to find tools/services;Continuous integration (CI) and (more often) continuous delivery;Automated testing',
#        'Innersource initiative;DevOps function;Microservices;Developer portal or other central places to find tools/services;Continuous integration (CI) and (more often) continuous delivery',
#        'Innersource initiative;DevOps function;Microservices;Automated testing;Observability tools',
#        'Innersource initiative;DevOps function;Automated testing',
#        'DevOps function;Developer portal or other central places to find tools/services;Automated testing',
#        'Innersource initiative;DevOps function;Microservices;Developer portal or other central places to find tools/services',
#        'DevOps function;Developer portal or other central places to find tools/services;Automated testing;Observability tools',
#        'DevOps function;Automated testing;Observability tools',
#        'Innersource initiative;Automated testing',
#        'Innersource initiative;DevOps function;Developer portal or other central places to find tools/services;Continuous integration (CI) and (more often) continuous delivery',
#        'Innersource initiative;Microservices;Developer portal or other central places to find tools/services;Continuous integration (CI) and (more often) continuous delivery;Automated testing',
#        'Innersource initiative;Microservices;Continuous integration (CI) and (more often) continuous delivery;Observability tools',
#        'Innersource initiative;DevOps function;Developer portal or other central places to find tools/services;Continuous integration (CI) and (more often) continuous delivery;Observability tools',
#        'Innersource initiative;Microservices;Developer portal or other central places to find tools/services;Continuous integration (CI) and (more often) continuous delivery;Automated testing;Observability tools',
#        'Innersource initiative;DevOps function;Microservices;Continuous integration (CI) and (more often) continuous delivery',
#        'Innersource initiative;Continuous integration (CI) and (more often) continuous delivery;Automated testing',
#        'Innersource initiative;DevOps function;Continuous integration (CI) and (more often) continuous delivery;Observability tools',
#        'Innersource initiative;DevOps function;Microservices',
#        'Innersource initiative;Developer portal or other central places to find tools/services',
#        'DevOps function;Microservices;Observability tools',
#        'Innersource initiative;Developer portal or other central places to find tools/services;Continuous integration (CI) and (more often) continuous delivery;Automated testing;Observability tools',
#        'Microservices;Developer portal or other central places to find tools/services;Automated testing;Observability tools',
#        'Automated testing;Observability tools',
#        'Microservices;Developer portal or other central places to find tools/services;Observability tools',
#        'Innersource initiative;DevOps function;Developer portal or other central places to find tools/services;Automated testing',
#        'Innersource initiative;Microservices;Developer portal or other central places to find tools/services;Automated testing',
#        'Innersource initiative;Microservices;Continuous integration (CI) and (more often) continuous delivery',
#        'Innersource initiative;Microservices;Observability tools',
#        'Innersource initiative;Microservices;Developer portal or other central places to find tools/services;Continuous integration (CI) and (more often) continuous delivery',
#        'Innersource initiative;DevOps function;Microservices;Continuous integration (CI) and (more often) continuous delivery;Observability tools',
#        'Innersource initiative;Developer portal or other central places to find tools/services;Continuous integration (CI) and (more often) continuous delivery',
#        'Innersource initiative;Continuous integration (CI) and (more often) continuous delivery',
#        'Innersource initiative;DevOps function;Microservices;Developer portal or other central places to find tools/services;Automated testing;Observability tools',
#        'Innersource initiative;DevOps function;Automated testing;Observability tools',
#        'Innersource initiative;Developer portal or other central places to find tools/services;Continuous integration (CI) and (more often) continuous delivery;Observability tools',
#        'Continuous integration (CI) and (more often) continuous delivery;None of these',
#        'DevOps function;Microservices;Developer portal or other central places to find tools/services;Observability tools',
#        'Innersource initiative;Observability tools',
#        'Innersource initiative;Microservices;Automated testing',
#        'Innersource initiative;DevOps function;Microservices;Developer portal or other central places to find tools/services;Continuous integration (CI) and (more often) continuous delivery;Automated testing;Observability tools;None of these',
#        'Developer portal or other central places to find tools/services;Continuous integration (CI) and (more often) continuous delivery;Automated testing;None of these',
#        'Microservices;Developer portal or other central places to find tools/services;Continuous integration (CI) and (more often) continuous delivery;Observability tools',
#        'Innersource initiative;DevOps function;Developer portal or other central places to find tools/services;Observability tools',
#        'Innersource initiative;Microservices;Developer portal or other central places to find tools/services',
#        'Innersource initiative;Continuous integration (CI) and (more often) continuous delivery;Observability tools',
#        'Innersource initiative;Microservices;Developer portal or other central places to find tools/services;Observability tools',
#        'Developer portal or other central places to find tools/services;None of these',
#        'Innersource initiative;Microservices;Continuous integration (CI) and (more often) continuous delivery;Automated testing',
#        'Microservices;None of these',
#        'Innersource initiative;Developer portal or other central places to find tools/services;Observability tools',
#        'Observability tools;None of these',
#        'Innersource initiative;DevOps function;Microservices;Developer portal or other central places to find tools/services;Observability tools',
#        'Innersource initiative;DevOps function;Microservices;Developer portal or other central places to find tools/services;Automated testing',
#        'Innersource initiative;Automated testing;Observability tools',
#        'DevOps function;None of these',
#        'Innersource initiative;DevOps function;Observability tools',
#        'Innersource initiative;Developer portal or other central places to find tools/services;Automated testing;Observability tools',
#        'Microservices;Continuous integration (CI) and (more often) continuous delivery;None of these',
#        'Innersource initiative;Developer portal or other central places to find tools/services;Automated testing',
#        'Developer portal or other central places to find tools/services;Continuous integration (CI) and (more often) continuous delivery;None of these',
#        'Innersource initiative;DevOps function;Developer portal or other central places to find tools/services;Automated testing;Observability tools',
#        'Innersource initiative;Microservices;Developer portal or other central places to find tools/services;Automated testing;Observability tools',
#        'Microservices;Automated testing;None of these',
#        'Innersource initiative;Developer portal or other central places to find tools/services;Automated testing;Observability tools;None of these',
#        'Innersource initiative;None of these',
#        'DevOps function;Developer portal or other central places to find tools/services;None of these',
#        'Innersource initiative;Microservices;Developer portal or other central places to find tools/services;Continuous integration (CI) and (more often) continuous delivery;Observability tools',
#        'Continuous integration (CI) and (more often) continuous delivery;Automated testing;None of these',
#        'Innersource initiative;Microservices;Developer portal or other central places to find tools/services;None of these',
#        'DevOps function;Observability tools;None of these',
#        'DevOps function;Developer portal or other central places to find tools/services;Continuous integration (CI) and (more often) continuous delivery;Automated testing;Observability tools;None of these',
#        'Innersource initiative;Microservices;Automated testing;Observability tools',
#        'Innersource initiative;DevOps function;Microservices;Developer portal or other central places to find tools/services;Continuous integration (CI) and (more often) continuous delivery;Automated testing;None of these',
#        'DevOps function;Continuous integration (CI) and (more often) continuous delivery;Automated testing;None of these',
#        'DevOps function;Microservices;Automated testing;None of these',
#        'Innersource initiative;Microservices;Automated testing;Observability tools;None of these',
#        'Innersource initiative;Microservices;Continuous integration (CI) and (more often) continuous delivery;None of these',
#        'DevOps function;Continuous integration (CI) and (more often) continuous delivery;None of these',
#        'Innersource initiative;DevOps function;None of these',
#        'DevOps function;Microservices;None of these',
#        'Innersource initiative;DevOps function;Microservices;Continuous integration (CI) and (more often) continuous delivery;None of these'],
#       dtype=object)

# %%
df['ProfessionalTech'] = df['ProfessionalTech'].str.replace('Developer portal or other central places to find tools/services', 'developer_portal', regex=True)
df['ProfessionalTech'] = df['ProfessionalTech'].str.replace('Continuous integration (CI) and (more often) continuous delivery', 'ci_cd', regex=True)
df['ProfessionalTech'] = df['ProfessionalTech'].str.replace('None of these', 'none', regex=True)
df['ProfessionalTech'] = df['ProfessionalTech'].str.lower().str.replace(', ', '_').str.replace('-', '_').str.replace(' ', '_')
# remove os parênteses e tudo que tem dentro
df['ProfessionalTech'] = df['ProfessionalTech'].str.replace(r"\(.*\)","")
# Out:
# C:\Users\nicbu\AppData\Local\Temp\ipykernel_18592\82060220.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['ProfessionalTech'] = df['ProfessionalTech'].str.replace(r"\(.*\)","")

# %%
df.drop('TrueFalse_1', axis=1, inplace=True)
df.drop('TrueFalse_2', axis=1, inplace=True)
df.drop('TrueFalse_3', axis=1, inplace=True)

# %% [markdown]
# Aqui termina a limpeza da quinta seção do formulário
#
# -----

# %% [markdown]
# ## Sexta seção
#
# Questões 55 a 56

# %%
df.drop('SurveyLength', axis=1, inplace=True)

# %%
df.drop('SurveyEase', axis=1, inplace=True)

# %% [markdown]
# Aqui termina a limpeza da sexta seção do formulário
#
# -----

# %% [markdown]
# ## Finalização

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73268 entries, 0 to 73267
# Data columns (total 56 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   ResponseId                      73268 non-null  int64
#  1   MainBranch                      73268 non-null  object
#  2   Employment                      71709 non-null  object
#  3   RemoteWork                      58958 non-null  object
#  4   CodingActivities                58899 non-null  object
#  5   EdLevel                         71571 non-null  object
#  6   LearnCode                       71580 non-null  object
#  7   LearnCodeOnline                 50685 non-null  object
#  8   LearnCodeCoursesCert            29389 non-null  object
#  9   YearsCode                       71331 non-null  object
#  10  YearsCodePro                    51833 non-null  object
#  11  DevType                         61302 non-null  object
#  12  OrgSize                         51039 non-null  object
#  13  Country                         71771 non-null  object
#  14  Currency                        51264 non-null  object
#  15  GrossWage                       38422 non-null  float64
#  16  WageFreq                        44425 non-null  object
#  17  LanguageHaveWorkedWith          70975 non-null  object
#  18  LanguageWantToWorkWith          67027 non-null  object
#  19  DatabaseHaveWorkedWith          60121 non-null  object
#  20  DatabaseWantToWorkWith          51014 non-null  object
#  21  PlatformHaveWorkedWith          49924 non-null  object
#  22  PlatformWantToWorkWith          40415 non-null  object
#  23  WebframeHaveWorkedWith          53544 non-null  object
#  24  WebframeWantToWorkWith          46122 non-null  object
#  25  MiscTechHaveWorkedWith          44992 non-null  object
#  26  MiscTechWantToWorkWith          36810 non-null  object
#  27  ToolsTechHaveWorkedWith         54171 non-null  object
#  28  ToolsTechWantToWorkWith         46566 non-null  object
#  29  NEWCollabToolsHaveWorkedWith    70347 non-null  object
#  30  NEWCollabToolsWantToWorkWith    64108 non-null  object
#  31  OpSysProfessionalUse            65503 non-null  object
#  32  OpSysPersonalUse                70963 non-null  object
#  33  VersionControlSystem            71379 non-null  object
#  34  VCInteraction                   68156 non-null  object
#  35  OfficeStackAsyncHaveWorkedWith  46223 non-null  object
#  36  OfficeStackAsyncWantToWorkWith  32072 non-null  object
#  37  OfficeStackSyncHaveWorkedWith   62128 non-null  object
#  38  OfficeStackSyncWantToWorkWith   47688 non-null  object
#  39  Blockchain                      71071 non-null  object
#  40  SOVisitFreq                     70961 non-null  object
#  41  Age                             70946 non-null  object
#  42  Gender                          70853 non-null  object
#  43  Trans                           70315 non-null  object
#  44  Sexuality                       66565 non-null  object
#  45  Ethnicity                       69474 non-null  object
#  46  Accessibility                   67244 non-null  object
#  47  MentalHealth                    66447 non-null  object
#  48  ICorPM                          36283 non-null  object
#  49  WorkExp                         36769 non-null  float64
#  50  TimeSearching                   36198 non-null  object
#  51  TimeAnswering                   36022 non-null  object
#  52  ProfessionalTech                34906 non-null  object
#  53  YearlyWageInDollar              38071 non-null  float64
#  54  YearsCodeNumber                 73268 non-null  float64
#  55  YearsCodeProNumber              73268 non-null  float64
# dtypes: float64(5), int64(1), object(50)
# memory usage: 31.3+ MB

# %%
df.to_csv('dataset/survey_results_public_clean.csv', sep=',', encoding='utf-8')
